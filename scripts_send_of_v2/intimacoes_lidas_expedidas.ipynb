# %%
# for tag in soup.find_all(string=lambda x: x and 'Domicílio Eletrônico' in x):
#     print(tag)
#     print(tag.parent)
import re
import json
from pathlib import Path
import pandas as pd
from pprint import pprint

# %%
def extrair_meio(texto):

    texto = texto.lower()

    if any(x in texto for x in ('advgs', '(P/ Advgs.', 'advgs.', 'advogado')):
        return 'advogado'

    if 'ofício' in texto or 'oficio' in texto:
        return 'oficio'

    if 'mandado' in texto:
        return 'mandado'
    # if 'prazo' in texto:
    #     return 'mandado'

    # if 'ofício' in texto:
    #     return 'oficio'

    if ('aviso de recebimento' in texto or 'juntada de ar' in texto):
        return 'ar'
    # if '(para ' in texto:
    #     return 'pessoal'
    if re.search(r'\bpara\b', texto):
        return 'pessoal'

    return None

def situacao_comunicacao(texto):

    texto = str(texto).lower()

    if 'lido(a)' in texto:
        return 'lida'

    if 'expedido(a)' in texto:
        return 'expedida'

    if 'devolução sem leitura' in texto:
        return 'devolvida_sem_leitura'

    if 'juntada de ar' in texto:
        return 'ar_juntado'

    if 'mandado devolvido' in texto:
        return 'mandado_devolvido'

    if 'mandado assinado' in texto:
        return 'mandado_assinado'

    if 'mandado à disposição' in texto:
        return 'mandado_disponivel'

    if 'solicitada a expedição de mandado' in texto:
        return 'mandado_solicitado'

    return None

def tipo_comunicacao(texto):
    texto = texto.lower()

    if 'citação' in texto:
        return 'citacao'

    if 'intimação' in texto:
        return 'intimacao'

    if 'certidão' in texto:
        return 'certidao'
    if 'juntada de ar' in texto:
        return 'certidao'

    return 'outro'

def expedidas(df):
    expedidas = df[df['situacao_comunicacao'] == 'expedida'].copy()
    expedidas['meio_real'] = expedidas['ato'].apply(extrair_meio)
    return expedidas

def referenciados(df):
    return df[df['observacao'].str.contains('Referente ao evento', case=False, na=False)].copy()

def lidas (df):

    lida = (df[df['situacao_comunicacao'] == 'lida']).copy()

    devolvida_sl = (
        df['ato'].str.contains(
            r'devolução sem leitura',
            case=False,
            na=False
        )
    )

    return df[lida | devolvida_sl].copy()
    
    # return lidas
def lidas(df):

    mask_lida = (
        df['situacao_comunicacao'] == 'lida'
    )

    mask_devolvida_sl = (
        df['ato'].str.contains(
            r'devolução sem leitura',
            case=False,
            na=False
        )
    )

    return df[mask_lida | mask_devolvida_sl].copy()

def chave(df_expedidas, df_lidas):
    df_expedidas['chave'] = (
        df_expedidas['destinatario']
        .str.lower()
        .str.strip()
        + '|'
        + df_expedidas['data_texto']
    )

    df_lidas['chave'] = (
       df_lidas['destinatario']
        .str.lower()
        .str.strip()
        + '|'
        + df_lidas['data_referencia_str']
    )

# print(len(expedidas), len(lidas))

def relacoes(df_expedidas, df_lidas):
    relacoes = df_lidas.merge(
        df_expedidas,
        on=['chave', 'destinatario', 'tipo'],
        suffixes=(
            '_lido',
            '_expedido'
        )
    )
    return relacoes

# def origem(df_relacoes):
#     relacoes['ato_origem'] = relacoes['ato_lido'].str.extract(
#         r'Referente ao evento\s+(.*?)\('
#     )

#     relacoes['data_origem'] = relacoes['ato_lido'].str.extract(
#         r'\((\d{2}/\d{2}/\d{2})\)'
#     )
def origem(df_relacoes):

    df_relacoes['ato_origem'] = (
        df_relacoes['ato_lido']
        .str.extract(
            r'Referente ao evento\s+(.*?)\(',
            expand=False
        )
    )

    df_relacoes['data_origem'] = (
        df_relacoes['ato_lido']
        .str.extract(
            r'\((\d{2}/\d{2}/\d{2})\)',
            expand=False
        )
    )

    return df_relacoes
# def canais_disponiveis(row):

#     canais = []

#     if row['tem_advogado']:
#         canais.append('advogado')

#     if row['domicilio_cnj']:
#         canais.append('domicilio_cnj')

#     if pd.notna(row['email']):
#         canais.append('email')

#     return ', '.join(canais)
def canais_disponiveis(row):

    canais = []

    if row['tem_advogado']:
        canais.append('advogado')

    if row['domicilio_cnj']:
        canais.append('domicilio_cnj')

    if row['recebe_intimacao_email']:
        canais.append('email_autorizado')

    elif pd.notna(row['email']):
        canais.append('email_cadastrado')

    if pd.notna(row['tel']):
        canais.append('telefone')

    return ', '.join(canais)


def lista_canais_disponiveis(row):

    canais = []

    if row['tem_advogado']:
        canais.append('advogado')

    if row['domicilio_cnj']:
        canais.append('domicilio_cnj')

    if row['recebe_intimacao_email']:
        canais.append('email_autorizado')

    elif pd.notna(row['email']):
        canais.append('email_cadastrado')

    if pd.notna(row['tel']):
        canais.append('telefone')

    return canais


def status_comunicacao(row):

    if row['tem_advogado']:
        return 'alta_advogado'

    if row['domicilio_cnj']:
        return 'alta_domicilio_cnj'

    if row['recebe_intimacao_email']:
        return 'alta_email_autorizado'

    if pd.notna(row['email']):
        return 'media_email_cadastrado'

    return 'baixa_sem_canal_eletronico'

# def status_comunicacao(row):

#     canais = row['canais_disponiveis']

#     if not canais:
#         return 'baixa'

#     if all(x in canais for x in ['advogado', 'domicilio_cnj', 'email']):
#         return 'muito_alta'

#     if 'advogado' in canais and 'domicilio_cnj' in canais:
#         return 'alta_adv_djen'

#     if 'domicilio_cnj' in canais and 'email' in canais:
#         return 'alta_djen_email'

#     if 'advogado' in canais:
#         return 'media_advogado'

#     if 'domicilio_cnj' in canais:
#         return 'media_djen'

#     if 'email' in canais:
#         return 'media_email'

#     return 'baixa'

# def status_processo(processo_ok, autores_ok, acusados_ok):
#     if processo_ok:
#         return 'automatizar'

#     if autores_ok and not acusados_ok:
#         return 'pendencia_promovido'

#     if acusados_ok and not autores_ok:
#         return 'pendencia_promovente'

#     return 'pendencia_geral'
def status_processo(autores_ok, acusados_ok):

    if autores_ok and acusados_ok:
        return 'automatizar'

    if not autores_ok and acusados_ok:
        return 'autor_pendente'

    if autores_ok and not acusados_ok:
        return 'reu_pendente'

    return 'ambos_pendentes'


def normalizar_nome(x):
    if pd.isna(x):
        return None

    x = x.lower().strip()
    x = re.sub(r'\(rev\.\s*arg\.?\)', '', x, flags=re.I)
    x = re.sub(r'\s+', ' ', x)
    return x

def marcar_revelia(nome):
    if pd.isna(nome):
        return False
    return bool(re.search(r'\((?:revel|rev\.?\s*arg\.?)\)', nome, re.I))# bool(re.search(r'\(rev\.\s*arg\.?\)', nome, re.I))

def status_processo(df_partes):

    autores_ok = df_partes.loc[
        df_partes['papel'] == 'PROMOVENTE',
        'habilitada_receber'
    ].all()

    acusados_ok = df_partes.loc[
        df_partes['papel'] == 'PROMOVIDO',
        'habilitada_receber'
    ].all()

    if autores_ok and acusados_ok:
        return True, 'automatizar'

    if autores_ok and not acusados_ok:
        return False, 'autor_pendente'

    if not autores_ok and acusados_ok:
        return False, 'reu_pendente'

    return False, 'ambos_pendentes'

padrao_revelia = re.compile(r'\(rev\.\s*arg\.?\)', re.I)

def tratar_parte(parte):
    nome_original = parte['nome']
    nome_norm_original = parte.get('nome_normalizado', nome_original)

    revelia = bool(padrao_revelia.search(nome_original))

    return {
        **parte,
        "revelia": revelia,
        "nome_limpo": padrao_revelia.sub("", nome_original).strip(),
        "nome_normalizado_limpo": padrao_revelia.sub("", nome_norm_original).strip()
    }

# %%
pasta = Path("C:\\Users\\igusilva\\OneDrive - Tribunal de Justiça do Estado da Bahia\\Área de Trabalho\\assets\\apps\\vitoria_secret\\udemy\\data_science\\nlp_spacy\\processos_movs_json")

# %%
arquivos = list(pasta.glob('*.json'))

print(len(arquivos))
# Out:
# 44

# %%
partes_processos = {}
for arquivo in pasta.glob("*.json"):
    processo = arquivo.stem

    # print("Lendo:", arquivo)

    try:

        with open(arquivo, "r", encoding="utf-8") as f:
            dados = json.load(f)

            partes = [tratar_parte(p) for p in dados['partes']]
            print(partes[0])
            df_partes = pd.DataFrame(partes)
           
    except Exception as e:

        print("ERRO:", e)
# Out:
# ERRO: list indices must be integers or slices, not str
# {'nome': 'DANILO AUGUSTO E ARAUJO FRANCA', 'nome_normalizado': 'danilo augusto e araujo franca', 'cpf/cnpj': '891.424.205-63', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'FRANCA_DANILO@HOTMAIL.COM', 'tel': '71996123344', 'logradouro': 'ENDEREÇO RUA NELSON RODRIGUES DO NASCIMENTO', 'numero': '45', 'complemento': 'PANORAMA', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48605041', 'revelia': False, 'nome_limpo': 'DANILO AUGUSTO E ARAUJO FRANCA', 'nome_normalizado_limpo': 'danilo augusto e araujo franca'}
# {'nome': 'RAQUEL LEMOS DE OLIVEIRA', 'nome_normalizado': 'raquel lemos de oliveira', 'cpf/cnpj': '013.679.775-09', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'BRENDA.SMACIEL@GMAIL.COM', 'tel': '71991363206', 'logradouro': 'ENDEREÇO RUA PRESIDENTE PRUDENTE DE MORAES', 'numero': '108', 'complemento': 'CLERISTON ANDRADE', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48603420', 'revelia': False, 'nome_limpo': 'RAQUEL LEMOS DE OLIVEIRA', 'nome_normalizado_limpo': 'raquel lemos de oliveira'}
# {'nome': 'EDILEIDE DA SILVA LIMA', 'nome_normalizado': 'edileide da silva lima', 'cpf/cnpj': '109.759.105-07', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'LEANAEVANGELISTA.ADV@GMAIL.COM', 'tel': '75988070152', 'logradouro': 'ENDEREÇO AREA RURAL', 'numero': 'SN', 'complemento': 'POVOADO SAO JOSE', 'bairro': 'AREA RURAL DE PAULO AFONSO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48619899', 'revelia': False, 'nome_limpo': 'EDILEIDE DA SILVA LIMA', 'nome_normalizado_limpo': 'edileide da silva lima'}
# {'nome': 'O MEIO AMBIENTE', 'nome_normalizado': 'o meio ambiente', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO ENDEREÇO NÃO INFORMADO.', 'numero': None, 'complemento': None, 'bairro': None, 'cidade': None, 'uf': None, 'cep': None, 'revelia': False, 'nome_limpo': 'O MEIO AMBIENTE', 'nome_normalizado_limpo': 'o meio ambiente'}
# {'nome': 'MARIA LUCIA TEIXEIRA DE OLIVEIRA', 'nome_normalizado': 'maria lucia teixeira de oliveira', 'cpf/cnpj': '042.465.915-80', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'KALYF.JUS@HOTMAIL.COM', 'tel': '75988045757', 'logradouro': 'ENDEREÇO SERRA DO GALEAO', 'numero': 'S N', 'complemento': 'CASA', 'bairro': 'CENTRO', 'cidade': 'SANTA BRIGIDA', 'uf': 'BA', 'cep': '48570000', 'revelia': False, 'nome_limpo': 'MARIA LUCIA TEIXEIRA DE OLIVEIRA', 'nome_normalizado_limpo': 'maria lucia teixeira de oliveira'}
# {'nome': 'PAULO CESAR AGUIAR NETO', 'nome_normalizado': 'paulo cesar aguiar neto', 'cpf/cnpj': '048.697.945-86', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'CONTATO@CHIOZZO.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO RUA SAO MIGUEL', 'numero': '95', 'complemento': 'JARDIM BAHIA', 'bairro': '(CONTATO: 55 21 99591 65', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48604120', 'revelia': False, 'nome_limpo': 'PAULO CESAR AGUIAR NETO', 'nome_normalizado_limpo': 'paulo cesar aguiar neto'}
# {'nome': 'BRUNO HENRIQUE GOMES BEZERRA', 'nome_normalizado': 'bruno henrique gomes bezerra', 'cpf/cnpj': '081.882.794-71', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': True, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'BGOMESBEZERRA@GMAIL.COM', 'tel': '87996033472', 'logradouro': 'ENDEREÇO RUA PADRE JOAO EVANGELISTA', 'numero': '353', 'complemento': 'CASA', 'bairro': 'NOSSA SENHORA DE FATIMA', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601055', 'revelia': False, 'nome_limpo': 'BRUNO HENRIQUE GOMES BEZERRA', 'nome_normalizado_limpo': 'bruno henrique gomes bezerra'}
# {'nome': 'JOSE HILTON MATOS DOS SANTOS', 'nome_normalizado': 'jose hilton matos dos santos', 'cpf/cnpj': '486.435.485-53', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'INTIMACOESBANCOS@GMAIL.COM', 'tel': '74988739031', 'logradouro': 'ENDEREÇO RUA CHICO MENDES', 'numero': '1430', 'complemento': 'BTN 2', 'bairro': 'TANCREDO NEVES II', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48609310', 'revelia': False, 'nome_limpo': 'JOSE HILTON MATOS DOS SANTOS', 'nome_normalizado_limpo': 'jose hilton matos dos santos'}
# {'nome': 'DIOGLEIRY CRISTIANE FARIAS GONZAGA', 'nome_normalizado': 'diogleiry cristiane farias gonzaga', 'cpf/cnpj': '080.361.147-12', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'DIOGLEIRYFARIAS10@HOTMAIL.COM', 'tel': '87981413213', 'logradouro': 'ENDEREÇO RUA SANTO ANTONIO', 'numero': 'S N', 'complemento': 'CENTRO', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601465', 'revelia': False, 'nome_limpo': 'DIOGLEIRY CRISTIANE FARIAS GONZAGA', 'nome_normalizado_limpo': 'diogleiry cristiane farias gonzaga'}
# {'nome': 'LUIZ ANTONIO DE ANDRADE', 'nome_normalizado': 'luiz antonio de andrade', 'cpf/cnpj': '249.597.824-04', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'MAYARALIMA.ADVOGADA@GMAIL.COM', 'tel': '75991746245', 'logradouro': 'ENDEREÇO RUA ADAUTO PEREIRA DE SOUZA', 'numero': '402', 'complemento': 'TANCREDO NEVES II', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48609155', 'revelia': False, 'nome_limpo': 'LUIZ ANTONIO DE ANDRADE', 'nome_normalizado_limpo': 'luiz antonio de andrade'}
# {'nome': 'ERICK ERNANDES SANDES', 'nome_normalizado': 'erick ernandes sandes', 'cpf/cnpj': '842.734.375-20', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'THAYSA_AH@HOTMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA JUAZEIRO', 'numero': '95', 'complemento': 'ALVES DE SOUZA', 'bairro': '(CONTATO: 98853 8039', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48608440', 'revelia': False, 'nome_limpo': 'ERICK ERNANDES SANDES', 'nome_normalizado_limpo': 'erick ernandes sandes'}
# {'nome': 'A SOCIEDADE', 'nome_normalizado': 'a sociedade', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO BA 210', 'numero': 'S N', 'complemento': 'BTN', 'bairro': 'XXXX', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48600000', 'revelia': False, 'nome_limpo': 'A SOCIEDADE', 'nome_normalizado_limpo': 'a sociedade'}
# {'nome': 'SELMA PEREIRA DIAS', 'nome_normalizado': 'selma pereira dias', 'cpf/cnpj': '697.688.465-34', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': True, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'SPDIAS1@HOTMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA DIONISIO PEREIRA', 'numero': '102 B', 'complemento': '75 988899689', 'bairro': 'VILA NOBRE', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48608586', 'revelia': False, 'nome_limpo': 'SELMA PEREIRA DIAS', 'nome_normalizado_limpo': 'selma pereira dias'}
# {'nome': 'ANDREA CARLA CARDOSO DE BRITO SILVA', 'nome_normalizado': 'andrea carla cardoso de brito silva', 'cpf/cnpj': '038.590.154-27', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': True, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ANDREAJPW@HOTMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA CEARA', 'numero': '18', 'complemento': '75 988675885', 'bairro': 'OLIVEIRA LOPES', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48607310', 'revelia': False, 'nome_limpo': 'ANDREA CARLA CARDOSO DE BRITO SILVA', 'nome_normalizado_limpo': 'andrea carla cardoso de brito silva'}
# {'nome': 'MARCELO DANIEL MELO ALENCAR', 'nome_normalizado': 'marcelo daniel melo alencar', 'cpf/cnpj': '025.132.555-50', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'MARCELOALENCAR@HOTMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA RUI BARBOSA', 'numero': '31', 'complemento': 'CENTRO', 'bairro': '(CONTATO: 75 988650273', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48602190', 'revelia': False, 'nome_limpo': 'MARCELO DANIEL MELO ALENCAR', 'nome_normalizado_limpo': 'marcelo daniel melo alencar'}
# {'nome': 'ROGERIO FREITAS CAVALCANTI', 'nome_normalizado': 'rogerio freitas cavalcanti', 'cpf/cnpj': '624.967.784-49', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ROGERIOFREITAS@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA SANTO AMARO', 'numero': '230', 'complemento': 'CASA 11', 'bairro': 'JARDIM BAHIA', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48604125', 'revelia': False, 'nome_limpo': 'ROGERIO FREITAS CAVALCANTI', 'nome_normalizado_limpo': 'rogerio freitas cavalcanti'}
# {'nome': 'FLORISVALDO CARVALHO LIMA', 'nome_normalizado': 'florisvaldo carvalho lima', 'cpf/cnpj': '004.499.385-49', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'LEANAEVANGELISTA.ADV@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA OTAVIANO LEANDRO DE MORAES', 'numero': '722', 'complemento': 'CENTRO', 'bairro': '(CONTATO: 75 98861 2283', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48602595', 'revelia': False, 'nome_limpo': 'FLORISVALDO CARVALHO LIMA', 'nome_normalizado_limpo': 'florisvaldo carvalho lima'}
# {'nome': 'MARIA DO SOCORRO LIMA SANTOS', 'nome_normalizado': 'maria do socorro lima santos', 'cpf/cnpj': '443.391.945-49', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'MARIASANTOSADVOGADA@HOTMAIL.COM', 'tel': '75991882995', 'logradouro': 'ENDEREÇO RUA LAGO HORIZONTE', 'numero': '494', 'complemento': 'CAMINHO DOS LAGOS', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48605390', 'revelia': False, 'nome_limpo': 'MARIA DO SOCORRO LIMA SANTOS', 'nome_normalizado_limpo': 'maria do socorro lima santos'}
# {'nome': 'JOSE CARLOS DO NASCIMENTO', 'nome_normalizado': 'jose carlos do nascimento', 'cpf/cnpj': '080.752.205-87', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ADVMARCOSMOTA287@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA DO SOL', 'numero': '88', 'complemento': 'CASA', 'bairro': 'CENTRO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601540', 'revelia': False, 'nome_limpo': 'JOSE CARLOS DO NASCIMENTO', 'nome_normalizado_limpo': 'jose carlos do nascimento'}
# {'nome': 'EDUARDO PEREIRA DOS SANTOS ALVES', 'nome_normalizado': 'eduardo pereira dos santos alves', 'cpf/cnpj': '064.814.925-05', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': True, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'EP69954@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA BELA VISTA', 'numero': '70', 'complemento': '75 988684830', 'bairro': 'RODOVIARIOS', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48609482', 'revelia': False, 'nome_limpo': 'EDUARDO PEREIRA DOS SANTOS ALVES', 'nome_normalizado_limpo': 'eduardo pereira dos santos alves'}
# {'nome': 'RAFAELA DANTAS SANTANA', 'nome_normalizado': 'rafaela dantas santana', 'cpf/cnpj': '047.167.815-50', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'DANIELFARIAS@DANTASEFARIAS.COM.BR', 'tel': '75999977723', 'logradouro': 'ENDEREÇO RUA GARANHUNS', 'numero': '01', 'complemento': 'GENERAL DUTRA', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48607262', 'revelia': False, 'nome_limpo': 'RAFAELA DANTAS SANTANA', 'nome_normalizado_limpo': 'rafaela dantas santana'}
# {'nome': 'DIODATO OLIVEIRA GAMA', 'nome_normalizado': 'diodato oliveira gama', 'cpf/cnpj': '064.948.115-15', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA GETULIO VARGAS', 'numero': '1 111', 'complemento': 'EDIFICIO ORQUIDEA AP 2003', 'bairro': 'CENTRO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601001', 'revelia': False, 'nome_limpo': 'DIODATO OLIVEIRA GAMA', 'nome_normalizado_limpo': 'diodato oliveira gama'}
# {'nome': 'FLORIZA MARIA SENA FERNANDES', 'nome_normalizado': 'floriza maria sena fernandes', 'cpf/cnpj': '483.125.765-68', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA\xa0\r\n                            DA ALEGRIA', 'numero': '178', 'complemento': '1º ANDAR', 'bairro': 'VILA POTY', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601470', 'revelia': False, 'nome_limpo': 'FLORIZA MARIA SENA FERNANDES', 'nome_normalizado_limpo': 'floriza maria sena fernandes'}
# {'nome': 'GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA', 'nome_normalizado': 'gjt paulo afonso aluguel de equipamentos ltda', 'cpf/cnpj': '41.407.173/0001-06', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': True, 'tem_advogado': True, 'email': 'PAULOAFONSO@CASADOCONSTRUTOR.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA APOLONIO SALES', 'numero': '1556', 'complemento': 'CENTRO', 'bairro': '(CONTATO: 75 3501 6755', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601208', 'revelia': False, 'nome_limpo': 'GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA', 'nome_normalizado_limpo': 'gjt paulo afonso aluguel de equipamentos ltda'}
# {'nome': 'SANDRA PATRICIA RESTREPO PONTES', 'nome_normalizado': 'sandra patricia restrepo pontes', 'cpf/cnpj': '859.312.835-10', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'XITARERA@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA SAO VICENTE', 'numero': '29', 'complemento': 'JARDIM BAHIA', 'bairro': '(CONTATO: 75 9 8155 2823', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48604150', 'revelia': False, 'nome_limpo': 'SANDRA PATRICIA RESTREPO PONTES', 'nome_normalizado_limpo': 'sandra patricia restrepo pontes'}
# {'nome': 'KAMILLA SOUZA GOMES DA COSTA', 'nome_normalizado': 'kamilla souza gomes da costa', 'cpf/cnpj': '064.500.785-45', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'CONTATO@HFASSOCIADOS.ADV.BR', 'tel': '71982016682', 'logradouro': 'ENDEREÇO RUA JOSE VOLPI', 'numero': '01', 'complemento': 'VILA NOVA', 'bairro': '(CONTATO:', 'cidade': 'JOÃO NEIVA', 'uf': 'ES', 'cep': '29680000', 'revelia': False, 'nome_limpo': 'KAMILLA SOUZA GOMES DA COSTA', 'nome_normalizado_limpo': 'kamilla souza gomes da costa'}
# {'nome': 'ALESSANDRO DA SILVA FEITOSA', 'nome_normalizado': 'alessandro da silva feitosa', 'cpf/cnpj': '649.972.945-00', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'FEITOSA.ALESSANDRO@BOL.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO RUA PEDRO MENDES', 'numero': '41', 'complemento': '1 ANDAR', 'bairro': 'CENTRO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601190', 'revelia': False, 'nome_limpo': 'ALESSANDRO DA SILVA FEITOSA', 'nome_normalizado_limpo': 'alessandro da silva feitosa'}
# {'nome': 'CONDOMINIO RESIDENCIAL BRISAS DO LAGO', 'nome_normalizado': 'condominio residencial brisas do lago', 'cpf/cnpj': '32.377.504/0001-11', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA NOSSA SENHORA APARECIDA', 'numero': 'S N', 'complemento': 'OLIVEIRA BRITO', 'bairro': None, 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48604564', 'revelia': False, 'nome_limpo': 'CONDOMINIO RESIDENCIAL BRISAS DO LAGO', 'nome_normalizado_limpo': 'condominio residencial brisas do lago'}
# {'nome': 'O MEIO AMBIENTE', 'nome_normalizado': 'o meio ambiente', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA\xa0\r\n                            XXXXXXXXX', 'numero': '0', 'complemento': 'XXXXXXXX', 'bairro': 'SALVADOR\r\n                                \r\n                                \r\n                            \r\n                            \r\n                                \r\n                                    \xa0-\xa0BA', 'cidade': None, 'uf': None, 'cep': '00000000', 'revelia': False, 'nome_limpo': 'O MEIO AMBIENTE', 'nome_normalizado_limpo': 'o meio ambiente'}
# {'nome': 'HEVITON OLIVEIRA RODRIGUES', 'nome_normalizado': 'heviton oliveira rodrigues', 'cpf/cnpj': '955.746.705-34', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'NEVO.PV@GMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA LAGO DOURADO', 'numero': '371', 'complemento': 'CAMINHO DOS LAGOS', 'bairro': '(CONTATO: 75 988774829', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48605410', 'revelia': False, 'nome_limpo': 'HEVITON OLIVEIRA RODRIGUES', 'nome_normalizado_limpo': 'heviton oliveira rodrigues'}
# {'nome': 'FABIANA DOS SANTOS SILVA GOMES MARMORARIA', 'nome_normalizado': 'fabiana dos santos silva gomes marmoraria', 'cpf/cnpj': '20.372.219/0001-29', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA ERALDO ROCHA', 'numero': '285', 'complemento': 'SAO VICENTE', 'bairro': None, 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48603500', 'revelia': False, 'nome_limpo': 'FABIANA DOS SANTOS SILVA GOMES MARMORARIA', 'nome_normalizado_limpo': 'fabiana dos santos silva gomes marmoraria'}
# {'nome': 'WENDEL CORDEIRO MARQUES', 'nome_normalizado': 'wendel cordeiro marques', 'cpf/cnpj': '033.283.835-81', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': '79991593686', 'logradouro': 'ENDEREÇO RUA PRESIDENTE PRUDENTE DE MORAES', 'numero': '222', 'complemento': 'CLERISTON ANDRADE', 'bairro': 'NÃO INFORMADO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48603420', 'revelia': False, 'nome_limpo': 'WENDEL CORDEIRO MARQUES', 'nome_normalizado_limpo': 'wendel cordeiro marques'}
# {'nome': 'O MEIO AMBIENTE', 'nome_normalizado': 'o meio ambiente', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO ENDEREÇO NÃO INFORMADO.', 'numero': None, 'complemento': None, 'bairro': None, 'cidade': None, 'uf': None, 'cep': None, 'revelia': False, 'nome_limpo': 'O MEIO AMBIENTE', 'nome_normalizado_limpo': 'o meio ambiente'}
# {'nome': 'LUANY GABRIELY BARBOZA DOS SANTOS', 'nome_normalizado': 'luany gabriely barboza dos santos', 'cpf/cnpj': '098.678.465-67', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA PADRE JOAO EVANGELISTA', 'numero': '505', 'complemento': 'CENTRO', 'bairro': '(CONTATO: 75 9 8806 842', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601315', 'revelia': False, 'nome_limpo': 'LUANY GABRIELY BARBOZA DOS SANTOS', 'nome_normalizado_limpo': 'luany gabriely barboza dos santos'}
# {'nome': 'LUIZ RICARDO DA SILVA SANTANA', 'nome_normalizado': 'luiz ricardo da silva santana', 'cpf/cnpj': '026.693.885-07', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'IRSANTANAA@HOTMAIL.COM', 'tel': '75988076442', 'logradouro': 'ENDEREÇO RUA SANTOS DUMONT', 'numero': '575', 'complemento': 'CENTRO', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48602500', 'revelia': False, 'nome_limpo': 'LUIZ RICARDO DA SILVA SANTANA', 'nome_normalizado_limpo': 'luiz ricardo da silva santana'}
# {'nome': 'MARIA JOSE BEZERRA', 'nome_normalizado': 'maria jose bezerra', 'cpf/cnpj': '905.623.308-44', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ELIZABETELEAL.ADV@GMAIL.COM', 'tel': '75988581206', 'logradouro': 'ENDEREÇO POVOADO BARRIGUDA', 'numero': 'SN', 'complemento': 'CASA', 'bairro': 'ZONA RURAL', 'cidade': 'SANTA BRIGIDA', 'uf': 'BA', 'cep': '48570000', 'revelia': False, 'nome_limpo': 'MARIA JOSE BEZERRA', 'nome_normalizado_limpo': 'maria jose bezerra'}
# {'nome': 'DIOGLEIRY CRISTIANE FARIAS GONZAGA', 'nome_normalizado': 'diogleiry cristiane farias gonzaga', 'cpf/cnpj': '080.361.147-12', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'DIOGLEIRYFARIAS10@HOTMAIL.COM', 'tel': None, 'logradouro': 'ENDEREÇO RUA MONSENHOR MAGALHAES', 'numero': '244', 'complemento': 'CENTRO', 'bairro': '(CONTATO: 75 98858 0985', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48602015', 'revelia': False, 'nome_limpo': 'DIOGLEIRY CRISTIANE FARIAS GONZAGA', 'nome_normalizado_limpo': 'diogleiry cristiane farias gonzaga'}
# {'nome': 'ENIVALDA AUREA DE MATOS', 'nome_normalizado': 'enivalda aurea de matos', 'cpf/cnpj': '329.475.425-68', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA DO SOL', 'numero': '104', 'complemento': 'CENTRO', 'bairro': None, 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48601540', 'revelia': False, 'nome_limpo': 'ENIVALDA AUREA DE MATOS', 'nome_normalizado_limpo': 'enivalda aurea de matos'}
# {'nome': 'EDMILSON LOPES CABRAL', 'nome_normalizado': 'edmilson lopes cabral', 'cpf/cnpj': '176.478.195-34', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ADV.BRUNAPSS@GMAIL.COM', 'tel': '75988696615', 'logradouro': 'ENDEREÇO RUA ARARI', 'numero': '122', 'complemento': 'FAZENDA CHESF', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48606520', 'revelia': False, 'nome_limpo': 'EDMILSON LOPES CABRAL', 'nome_normalizado_limpo': 'edmilson lopes cabral'}
# {'nome': 'ADAILTON PEREIRA DA SILVA', 'nome_normalizado': 'adailton pereira da silva', 'cpf/cnpj': '003.098.125-50', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': '7591252909', 'logradouro': 'ENDEREÇO ZONA RURAL POVOADO LUDOVICO TIGRRE', 'numero': '10', 'complemento': 'TIGRE', 'bairro': 'NÃO POSSUI', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48600000', 'revelia': False, 'nome_limpo': 'ADAILTON PEREIRA DA SILVA', 'nome_normalizado_limpo': 'adailton pereira da silva'}
# {'nome': 'MEIO AMBIENTE', 'nome_normalizado': 'meio ambiente', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': '00000000000', 'logradouro': 'ENDEREÇO FAZENDA IZIDIO', 'numero': 'S N', 'complemento': 'CASA', 'bairro': 'AREA RURAL', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48600000', 'revelia': False, 'nome_limpo': 'MEIO AMBIENTE', 'nome_normalizado_limpo': 'meio ambiente'}
# {'nome': 'A sociedade (CRIME AMBIENTAL)', 'nome_normalizado': 'a sociedade (crime ambiental)', 'cpf/cnpj': 'Não cadastrado', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO ENDEREÇO NÃO INFORMADO.', 'numero': None, 'complemento': None, 'bairro': None, 'cidade': None, 'uf': None, 'cep': None, 'revelia': False, 'nome_limpo': 'A sociedade (CRIME AMBIENTAL)', 'nome_normalizado_limpo': 'a sociedade (crime ambiental)'}
# {'nome': 'SEVERINO ALVES DE OLIVEIRA LIMA', 'nome_normalizado': 'severino alves de oliveira lima', 'cpf/cnpj': '010.080.565-53', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA\xa0\r\n                            RORAIMA', 'numero': '75', 'complemento': '(75 3281-3954', 'bairro': 'PANORAMA', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48600000', 'revelia': False, 'nome_limpo': 'SEVERINO ALVES DE OLIVEIRA LIMA', 'nome_normalizado_limpo': 'severino alves de oliveira lima'}

# %%
processos = {}
df_relacoes_total = []

for process_json in pasta.glob('*.json'):

    with open(process_json, 'r', encoding='utf-8') as f:
        dados = json.load(f)

    p = process_json.stem

    # =========================
    # MOVIMENTAÇÕES
    # =========================
    try:
        df = pd.DataFrame(dados['movimentacoes'])
        processos[p] = df
        display(df)
    except:
        df = pd.DataFrame(dados)
        display(df)
    # finally:
    #     print('não foi possível fazer o df')

    origem_map = {
       str(m["evento"]).strip(): {
        "documentos": m.get("documentos", []) or []
        }
        for m in df.to_dict("records")
    }
    expedicao_map = {
        str(m["evento"]).strip(): {
            "observacao": m.get("observacao", "") or ""
        }
        for m in df.to_dict("records")
    }
    

    
    # df_expedidas = df[df["tipo"] == "expedida"].copy()
    # df_lidas = df[df["tipo"] == "lida"].copy()
    df_expedidas = expedidas(df).copy()
    df_lidas = lidas(df).copy()
   

    df_outros_referenciados = referenciados(df)

    df_expedidas['tipo'] = df_expedidas['ato'].apply(tipo_comunicacao)
    df_lidas['tipo'] = df_lidas['ato'].apply(tipo_comunicacao)

    chave(df_expedidas, df_lidas)
    _relacoes = relacoes(df_expedidas, df_lidas)

    df_relacoes = pd.DataFrame({
        'evento_expedido': _relacoes['evento_expedido'],
        'data_expedicao': _relacoes['data_texto_expedido'],
        'ato_expedido': _relacoes['ato_expedido'],
        'destinatario': _relacoes['destinatario'],
        'meio': _relacoes['meio_real'],
        'canal': _relacoes['meio_comunicacao_expedido'],
        'ato_lido': _relacoes['ato_lido'],
        'data_leitura': _relacoes.get('data_leitura_str_lido'),
        # 'data_leitura': _relacoes['data_leitura_str_lido'],
        'evento_lido': _relacoes['evento_lido'],
        'prazo': _relacoes['ato_expedido'].str.extract(r'(\d+\s*dias?)', expand=False),
    })
    # df_relacoes["documentos_origem"] = df_relacoes["evento_expedido"].map(docs_map)
    # df_relacoes["observacao_origem"] = df_relacoes["evento_expedido"].map(obs_map)
    # df_relacoes["documentos_origem"] = df_relacoes["evento_expedido"].map(
    #     lambda x: evento_extra.get(str(x), {}).get("documentos", []))

    # df_relacoes["observacao_origem"] = df_relacoes["evento_expedido"].map(
    #     lambda x: evento_extra.get(str(x), {}).get("observacao", ""))
    df_relacoes["documentos_origem"] = df_relacoes["evento_expedido"].map(
    lambda x: origem_map.get(str(x), {}).get("documentos", []))

    df_relacoes["observacao_expedicao"] = df_relacoes["evento_expedido"].map(
    lambda x: expedicao_map.get(str(x), {}).get("observacao", ""))

    df_relacoes = origem(df_relacoes)

    # 🔑 CHAVE ÚNICA GLOBAL
    df_relacoes['key'] = df_relacoes['destinatario'].apply(normalizar_nome)

    # =========================
    # PARTES
    # =========================
    # df_partes = pd.DataFrame(dados['partes'])

    df_partes['key'] = df_partes['nome_normalizado_limpo']#.apply(normalizar_nome)
    df_partes['revelia'] = df_partes['nome'].apply(marcar_revelia)
    print(df_partes['revelia'])

    df_partes['canais_disponiveis'] = df_partes.apply(canais_disponiveis, axis=1)
    df_partes['canais_disponiveis_lista'] = df_partes.apply(lista_canais_disponiveis, axis=1)

    df_partes['habilitada_receber'] = (
        df_partes['tem_advogado'].fillna(False) |
        df_partes['domicilio_cnj'].fillna(False) |
        df_partes['recebe_intimacao_email'].fillna(False)
    )

    # =========================
    # STATUS PROCESSO
    # =========================
    processo_ok, status = status_processo(df_partes)
    df_relacoes['automatiza'] = status

    # =========================
    # MERGE PARTES ↔ RELAÇÕES
    # =========================
    # df_relacoes = df_relacoes.merge(
    #     df_partes[[
    #         'key',
    #         'revelia',
    #         'email',
    #         'tel',
    #         'habilitada_receber'
    #     ]],
    #     on='key',
    #     how='left'
    # )
    df_relacoes.merge(df_partes, on='key', how='left')

    # =========================
    # CANAIS HISTÓRICOS (CORRETO)
    # =========================
    canais_historicos = (
        df_expedidas.groupby('destinatario')['meio_real']
        .apply(lambda x: ', '.join(sorted(set(filter(pd.notna, x)))))
        .reset_index()
    )

    canais_historicos['key'] = canais_historicos['destinatario'].apply(normalizar_nome)

    df_relacoes = df_relacoes.merge(
        canais_historicos[['key', 'meio_real']],
        on='key',
        how='left'
    )

    df_relacoes = df_relacoes.rename(columns={'meio_real': 'canais_historicos'})

    # =========================
    # CANAL CONFIRMADO (USO REAL)
    # =========================
    canais_confirmados = (
        df_relacoes.groupby('destinatario')['meio']
        .apply(lambda x: ', '.join(sorted(set(filter(pd.notna, x)))))
        .reset_index()
    )

    canais_confirmados['key'] = canais_confirmados['destinatario'].apply(normalizar_nome)

    df_partes = df_partes.merge(
        canais_confirmados[['key', 'meio']],
        on='key',
        how='left'
    )

    df_partes = df_partes.rename(columns={'meio': 'canal_confirmado'})

    # =========================
    # FINAL
    # =========================
    df_relacoes_total.append(df_relacoes)
    # print(
    #     f"Processo: {numero} | "
    #     f"Movimentações: {len(df)}"
    # )
    df_relacoes.drop(['automatiza', 'key'], axis=1, inplace=True)
    print(p)
    display(df_relacoes.set_index('evento_expedido'))
    print(len(df_relacoes))
# Out:
#     evento                                                ato  \
# 0      370  Disponibilização no Diário da Justiça Eletrôni...
# 1      369  Intimação expedido(a) (P/ Advgs. de MCT MEU TU...
# 2      368                                    Juntada de DAJE
# 3      367                          Ato ordinatório praticado
# 4      366              Proferido despacho de mero expediente
# ..     ...                                                ...
# 365      5  Audiência  de Conciliação Designada (Teleprese...
# 366      4                     Conclusos para Pedido Urgência
# 367      3  Autos incluídos no Juízo 100% Digital Este pro...
# 368      2  Distribuído por Sorteio 2ª Vara do Sistema dos...
# 369      1     Recebido pelo Distribuidor Origem: OAB69880NBA
#
#                                        ato_normalizado data_texto    data_obj  \
# 0    disponibilização no diário da justiça eletrôni...   17/06/26  2026-06-17
# 1    intimação expedido(a) (p/ advgs. de mct meu tu...   17/06/26  2026-06-17
# 2                                      juntada de daje   17/06/26  2026-06-17
# 3                            ato ordinatório praticado   17/06/26  2026-06-17
# 4                proferido despacho de mero expediente   16/06/26  2026-06-16
# ..                                                 ...        ...         ...
# 365  audiência  de conciliação designada (teleprese...   11/08/23  2023-08-11
# 366                     conclusos para pedido urgência   11/08/23  2023-08-11
# 367  autos incluídos no juízo 100% digital este pro...   11/08/23  2023-08-11
# 368  distribuído por sorteio 2ª vara do sistema dos...   11/08/23  2023-08-11
# 369     recebido pelo distribuidor origem: oab69880nba   11/08/23  2023-08-11
#
#     data_leitura_str data_referencia_str                                autor  \
# 0               None                None                             DJEN CNJ
# 1               None                None  MAURO EMILIO VIANA DA SILVA MOREIRA
# 2               None                None  MAURO EMILIO VIANA DA SILVA MOREIRA
# 3               None                None  MAURO EMILIO VIANA DA SILVA MOREIRA
# 4               None                None    MARTINHO FERRAZ DA NOBREGA JUNIOR
# ..               ...                 ...                                  ...
# 365             None                None                          SISTEMA CNJ
# 366             None                None                          SISTEMA CNJ
# 367             None                None                          SISTEMA CNJ
# 368             None                None                          SISTEMA CNJ
# 369             None                None      LEANA BEZERRA GOMES EVANGELISTA
#
#                    categoria meio_comunicacao situacao_comunicacao  \
# 0    disponibilizado no djen    domicilio_cnj                 None
# 1                  intimacao    domicilio_cnj             expedida
# 2                       None             None                 None
# 3                       None             None                 None
# 4                       None             None                 None
# ..                       ...              ...                  ...
# 365                audiencia             None                 None
# 366                     None             None                 None
# 367                     None             None                 None
# 368                     None             None                 None
# 369                     None             None                 None
#
#      destinatario data_leitura data_referencia   data_djen  \
# 0            None         None            None  2026-06-19
# 1    mct meu tudo         None            None        None
# 2            None         None            None        None
# 3            None         None            None        None
# 4            None         None            None        None
# ..            ...          ...             ...         ...
# 365          None         None            None        None
# 366          None         None            None        None
# 367          None         None            None        None
# 368          None         None            None        None
# 369          None         None            None        None
#
#     evento_referenciado  prazo_dias_ev_ref  \
# 0                  None                NaN
# 1                  None                NaN
# 2                  None                NaN
# 3                  None                NaN
# 4                  None                NaN
# ..                  ...                ...
# 365                None                NaN
# 366                None                NaN
# 367                None                NaN
# 368                None                NaN
# 369                None                NaN
#
#                                             observacao  \
# 0
# 1
# 2    Ev. 346: "Custas da execução, se existirem, pe...
# 3
# 4
# ..                                                 ...
# 365
# 366
# 367
# 368
# 369
#
#                                             documentos
# 0                                                   []
# 1                                                   []
# 2    [{'nome': 'daje mct tudo.pdf', 'url': 'https:/...
# 3                                                   []
# 4    [{'nome': 'online.html', 'url': 'https://proju...
# ..                                                 ...
# 365                                                 []
# 366                                                 []
# 367                                                 []
# 368                                                 []
# 369  [{'nome': 'INICIAL.pdf', 'url': 'https://proju...
#
# [370 rows x 19 columns]
# 0    False
# 1    False
# Name: revelia, dtype: bool
# 0002245-75.2023.8.05.0191
#                 data_expedicao  \
# evento_expedido
# 229                   10/03/25
# 230                   10/03/25
# 228                   10/03/25
# 209                   19/12/24
# 186                   16/08/24
# 179                   13/08/24
# 153                   25/07/24
# 153                   25/07/24
# 143                   25/07/24
# 143                   25/07/24
# 152                   25/07/24
# 142                   25/07/24
# 152                   25/07/24
# 142                   25/07/24
# 162                   31/07/24
# 151                   25/07/24
# 144                   25/07/24
# 151                   25/07/24
# 144                   25/07/24
# 133                   21/06/24
# 132                   21/06/24
# 134                   21/06/24
# 91                    01/04/24
# 90                    01/04/24
# 89                    01/04/24
# 71                    12/12/23
# 65                    08/11/23
# 51                    03/10/23
# 24                    18/08/23
# 20                    18/08/23
# 13                    14/08/23
#
#                                                       ato_expedido  \
# evento_expedido
# 229              Intimação expedido(a) (P/ Advgs. de MCT MEU TU...
# 230              Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 228              Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 209              Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 186              Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 179              Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 153              Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 153              Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 143              Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 143              Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 152              Intimação expedido(a) (P/ Advgs. de MCT MEU TU...
#
Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
# 71               Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
# 65               Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
# 51               Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
# 24               Intimação lido(a) (Para PARATI CREDITO FINANCI...
# 20               Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
# 13               Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...
#
#                 data_leitura evento_lido    prazo  \
# evento_expedido
# 229               2025-03-20         245   5 dias
# 230               2025-03-18         243   5 dias
# 228               2025-03-11         237   5 dias
# 209               2025-01-21         214  15 dias
# 186               2024-08-19         189   5 dias
# 179               2024-08-19         188   5 dias
# 153               2024-08-05         170   5 dias
# 153               2024-08-05         168   5 dias
# 143               2024-08-05         170      NaN
# 143               2024-08-05         168      NaN
# 152               2024-08-05         169   5 dias
# 142               2024-08-05         169      NaN
# 152               2024-08-05         167   5 dias
# 142               2024-08-05         167      NaN
# 162               2024-07-31         163   5 dias
# 151               2024-07-30         157   5 dias
# 144               2024-07-30         157      NaN
# 151               2024-07-29         156   5 dias
# 144               2024-07-29         156      NaN
# 133               2024-07-03         137  15 dias
# 132               2024-07-03         136  15 dias
# 134               2024-06-26         135  15 dias
# 91                2024-04-11         100  10 dias
# 90                2024-04-11          99  10 dias
# 89                2024-04-08          98  10 dias
# 71                2023-12-13          75      NaN
# 65                2023-11-20          66      NaN
# 51                2023-10-03          55      NaN
# 24                2023-08-28          28      NaN
# 20                2023-08-21          25   3 dias
# 13                2023-08-16          17   5 dias
#
#                                                  documentos_origem  \
# evento_expedido
# 229                                                             []
# 230                                                             []
# 228                                                             []
# 209                                                             []
# 186                                                             []
# 179                                                             []
# 153                                                             []
# 153                                                             []
# 143                                                             []
# 143                                                             []
# 152                                                             []
# 142                                                             []
# 152                                                             []
# 142                                                             []
# 162                                                             []
# 151                                                             []
# 144                                                             []
# 151                                                             []
# 144                                                             []
# 133                                                             []
# 132                                                             []
# 134                                                             []
# 91                                                              []
# 90                                                              []
# 89                                                              []
# 71                                                              []
# 65                                                              []
# 51                                                              []
# 24               [{'nome': 'online.html', 'url': 'https://proju...
# 20                                                              []
# 13                                                              []
#
#                 observacao_expedicao  \
# evento_expedido
# 229
# 230
# 228
# 209
# 186
# 179
# 153
# 153
# 143
# 143
# 152
# 142
# 152
# 142
# 162
# 151
# 144
# 151
# 144
# 133
# 132
# 134
# 91
# 90
# 89
# 71
# 65
# 51
# 24
# 20
# 13
#
#                                                         ato_origem  \
# evento_expedido
# 229                                            Documento analisado
# 230                                            Documento analisado
# 228                                            Documento analisado
# 209                                         Intimação à disposição
# 186                          Proferido despacho de mero expediente
# 179              Decisão de Saneamento e de Organização do Proc...
# 153                                         Intimação à disposição
# 153                                          Transitado em Julgado
# 143                                         Intimação à disposição
# 143                                          Transitado em Julgado
# 152                                         Intimação à disposição
# 142                                         Intimação à disposição
# 152                                          Transitado em Julgado
# 142                                          Transitado em Julgado
# 162                          Proferido despacho de mero expediente
# 151                                         Intimação à disposição
# 144                                         Intimação à disposição
# 151                                          Transitado em Julgado
# 144                                          Transitado em Julgado
# 133                             Provimento por decisão monocrática
# 132                             Provimento por decisão monocrática
# 134                             Provimento por decisão monocrática
# 91                              Julgada procedente em parte a ação
# 90                              Julgada procedente em parte a ação
#
#    observacao  categoria meio_comunicacao situacao_comunicacao  \
# 0              intimacao    domicilio_cnj             expedida
# 1              intimacao    domicilio_cnj             expedida
# 2              intimacao    domicilio_cnj             expedida
# 3              intimacao             None                 lida
# 4              intimacao             None                 lida
# 5              intimacao             None             expedida
# 6              intimacao             None             expedida
# 7              intimacao    domicilio_cnj             expedida
# 8              intimacao    domicilio_cnj             expedida
# 9              audiencia             None            realizada
# 10               citacao             None                 lida
# 11             intimacao             None                 lida
# 12               citacao             None                 lida
# 13             intimacao             None                 lida
# 14               citacao             None             expedida
# 15               citacao             None             expedida
# 16             intimacao             None             expedida
# 17             intimacao             None             expedida
# 18             intimacao    domicilio_cnj             expedida
# 19               citacao             None             expedida
# 20               citacao             None             expedida
# 21             intimacao             None                 lida
#
#                                        destinatario
# 0               payout pagamentos inteligentes ltda
# 1                    danilo augusto e araujo franca
# 2                    danilo augusto e araujo franca
# 3                                    tv vinhos ltda
# 4               payout pagamentos inteligentes ltda
# 5                                    tv vinhos ltda
# 6               payout pagamentos inteligentes ltda
# 7                    danilo augusto e araujo franca
# 8                    danilo augusto e araujo franca
# 9                    19/02/2026 16:46, paulo afonso
# 10  payout pagamentos inteligentes ltda em 04/02/26
# 11                                   tv vinhos ltda
# 12                       tv vinhos ltda em 05/02/26
# 13              payout pagamentos inteligentes ltda
# 14                                   tv vinhos ltda
# 15              payout pagamentos inteligentes ltda
# 16                                   tv vinhos ltda
# 17              payout pagamentos inteligentes ltda
# 18                   danilo augusto e araujo franca
# 19                                   tv vinhos ltda
# 20              payout pagamentos inteligentes ltda
# 21                   danilo augusto e araujo franca
# 0    False
# 1    False
# Name: revelia, dtype: bool
# processo_0000084-87.2026.8.05.0191
#                 data_expedicao  \
# evento_expedido
# 60                    28/04/26
# 58                    28/04/26
# 14                    21/01/26
#
#                                                       ato_expedido  \
# evento_expedido
# 60               Intimação expedido(a) Para TV VINHOS LTDA *Ref...
# 58               Intimação expedido(a) (Para PAYOUT PAGAMENTOS ...
# 14               Intimação expedido(a) (Para PAYOUT PAGAMENTOS ...
#
#                                         destinatario     meio canal  \
# evento_expedido
# 60                                    tv vinhos ltda  pessoal  None
# 58               payout pagamentos inteligentes ltda  pessoal  None
# 14               payout pagamentos inteligentes ltda  pessoal  None
#
#                                                           ato_lido  \
# evento_expedido
# 60               Intimação lido(a) (Para TV VINHOS LTDA) em 11/...
# 58               Intimação lido(a) (Para PAYOUT PAGAMENTOS INTE...
# 14               Intimação lido(a) (Para PAYOUT PAGAMENTOS INTE...
#
#                 data_leitura evento_lido    prazo documentos_origem  \
# evento_expedido
# 60                2026-05-11          62      NaN                []
# 58                2026-05-08          61  15 dias                []
# 14                2026-02-02          25      NaN                []
#
#                 observacao_expedicao                 ato_origem data_origem  \
# evento_expedido
# 60                                    Ato ordinatório praticado    28/04/26
# 58                                    Ato ordinatório praticado    28/04/26
# 14                                       Intimação à disposição    21/01/26
#
#                  canais_historicos
# evento_expedido
# 60                         pessoal
# 58               advogado, pessoal
# 14               advogado, pessoal
# 3
#    evento                                                ato  \
# 0     258  Disponibilização no Diário da Justiça Eletrôni...
# 1     257  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
# 2     256                              Intimação expedido(a)
# 3     247  Intimação expedido(a) (P/ Advgs. de AMIL ASSIS...
# 4     246  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
# 5     238  Intimação expedido(a) (P/ Advgs. de AMIL ASSIS...
# 6     237  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
# 7     230  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
# 8     223  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 9     219  Intimação expedido(a) (P/ Advgs. de AMIL ASSIS...
# 10    218  Intimação expedido(a) (Para AMIL ASSISTENCIA M...
# 11    217  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
# 12    209  Intimação expedido(a) (P/ Advgs. de RAQUEL LEM...
#
ITORIA YASMIN PEREIRA DE JESUS             intimacao
# 18                   WALKER LOPES RODRIGUES             audiencia
# 19                              SISTEMA CNJ             intimacao
# 20          VITORIA YASMIN PEREIRA DE JESUS             intimacao
#
#    meio_comunicacao situacao_comunicacao                       destinatario
# 0              None                 lida  núcleo de atuação mp paulo afonso
# 1              None             expedida  núcleo de atuação mp paulo afonso
# 2              None            realizada     17/03/2026 17:16, paulo afonso
# 3           mandado                 lida  núcleo de atuação mp paulo afonso
# 4              None             expedida  núcleo de atuação mp paulo afonso
# 5              None                 lida  núcleo de atuação mp paulo afonso
# 6              None             expedida  núcleo de atuação mp paulo afonso
# 7              None                 lida  núcleo de atuação mp paulo afonso
# 8              None             expedida  núcleo de atuação mp paulo afonso
# 9              None            realizada                               None
# 10             None                 lida  núcleo de atuação mp paulo afonso
# 11             None             expedida  núcleo de atuação mp paulo afonso
# 12             None                 lida  núcleo de atuação mp paulo afonso
# 13             None             expedida  núcleo de atuação mp paulo afonso
# 14             None                 lida  núcleo de atuação mp paulo afonso
# 15             None             expedida  núcleo de atuação mp paulo afonso
# 16             None                 lida  núcleo de atuação mp paulo afonso
# 17             None             expedida  núcleo de atuação mp paulo afonso
# 18             None            realizada                               None
# 19             None                 lida  núcleo de atuação mp paulo afonso
# 20             None             expedida  núcleo de atuação mp paulo afonso
# 0    False
# 1    False
# Name: revelia, dtype: bool
# processo_0004024-31.2024.8.05.0191
#                 data_expedicao  \
# evento_expedido
# 77                    15/12/25
# 64                    07/10/25
# 35                    12/08/25
#
#                                                       ato_expedido  \
# evento_expedido
# 77               Intimação expedido(a) P/ Núcleo de Atuação MP ...
# 64               Intimação expedido(a) P/ Núcleo de Atuação MP ...
# 35               Intimação expedido(a) P/ Núcleo de Atuação MP ...
#
#                                       destinatario  meio canal  \
# evento_expedido
# 77               núcleo de atuação mp paulo afonso  None  None
# 64               núcleo de atuação mp paulo afonso  None  None
# 35               núcleo de atuação mp paulo afonso  None  None
#
#                                                           ato_lido  \
# evento_expedido
# 77               Intimação lido(a) (Para Núcleo de Atuação MP P...
# 64               Intimação lido(a) (Para Núcleo de Atuação MP P...
# 35               Intimação lido(a) (Para Núcleo de Atuação MP P...
#
#                 data_leitura evento_lido prazo documentos_origem  \
# evento_expedido
# 77                2026-01-21          79   NaN                []
# 64                2025-10-09          65   NaN                []
# 35                2025-08-14          40   NaN                []
#
#                 observacao_expedicao                           ato_origem  \
# evento_expedido
# 77                                    Autos entregues em carga ao destino
# 64                                                    Documento analisado
# 35                                    Autos entregues em carga ao destino
#
#                 data_origem canais_historicos
# evento_expedido
# 77                 15/12/25
# 64                 07/10/25
# 35                 12/08/25
# 3
#   evento                                                ato  \
# 0     33  Audiência Preliminar Realizada (Telepresencial...
# 1     29  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 2     24  Intimação expedido(a) P/ Núcleo de Atuação MP ...
# 3     17  Audiência Preliminar Realizada (Telepresencial...
# 4     14  Intimação lido(a) (Para CICERO ALENCAR DA SILV...
# 5     13  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 6     11  Intimação expedido(a) Para CICERO ALENCAR DA S...
# 7      9  Intimação expedido(a) P/ Núcleo de Atuação MP ...
#
#                                      ato_normalizado data_texto    data_obj  \
# 0  audiência preliminar realizada (telepresencial...   01/04/26  2026-04-01
# 1  intimação lido(a) (para núcleo de atuação mp p...   06/03/26  2026-03-06
# 2  intimação expedido(a) p/ núcleo de atuação mp ...   02/03/26  2026-03-02
# 3  audiência preliminar realizada (telepresencial...   10/02/26  2026-02-10
# 4  intimação lido(a) (para cicero alencar da silv...   06/02/26  2026-02-06
# 5  intimação lido(a) (para núcleo de atuação mp p...   23/01/26  2026-01-23
# 6  intimação expedido(a) para cicero alencar da s...   12/01/26  2026-01-12
# 7  intimação expedido(a) p/ núcleo de atuação mp ...   12/01/26  2026-01-12
#
#   data_leitura_str data_referencia_str  \
# 0             None                None
# 1       2026-03-06            02/03/26
# 2             None                None
# 3             None                None
# 4       2026-01-21            12/01/26
# 5       2026-01-22                None
# 6             None            12/01/26
# 7             None                None
#
#                                      autor observacao  categoria  \
# 0                     DANILO RIBEIRO VIANA             audiencia
# 1  FERNANDO ROGERIO PESSOA VILA NOVA FILHO             intimacao
# 2          VITORIA YASMIN PEREIRA DE JESUS             intimacao
# 3                     DANILO RIBEIRO VIANA             audiencia
# 4                                      ECT             intimacao
# 5                              SISTEMA CNJ             intimacao
# 6          VITORIA YASMIN PEREIRA DE JESUS             intimacao
# 7          VITORIA YASMIN PEREIRA DE JESUS             intimacao
#
#   meio_comunicacao situacao_comunicacao                       destinatario
# 0             None            realizada     01/04/2026 18:22, paulo afonso
# 1             None                 lida  núcleo de atuação mp paulo afonso
# 2             None             expedida  núcleo de atuação mp paulo afonso
# 3             None            realizada     10/02/2026 14:08, paulo afonso
# 4             None                 lida            cicero alencar da silva
# 5             None                 lida  núcleo de atuação mp paulo afonso
# 6             None             expedida            cicero alencar da silva
# 7             None             expedida  núcleo de atuação mp paulo afonso
# 0    False
# 1    False
# Name: revelia, dtype: bool
# processo_0004152-17.2025.8.05.0191
#                 data_expedicao  \
# evento_expedido
# 24                    02/03/26
# 11                    12/01/26
#
#                                                       ato_expedido  \
# evento_expedido
# 24               Intimação expedido(a) P/ Núcleo de Atuação MP ...
# 11               Intimação expedido(a) Para CICERO ALENCAR DA S...
#
#                                       destinatario     meio canal  \
# evento_expedido
# 24               núcleo de atuação mp paulo afonso     None  None
# 11                         cicero alencar da silva  pessoal  None
#
#                                                           ato_lido  \
# evento_expedido
# 24               Intimação lido(a) (Para Núcleo de Atuação MP P...
# 11               Intimação lido(a) (Para CICERO ALENCAR DA SILV...
#
#                 data_leitura evento_lido prazo documentos_origem  \
# evento_expedido
# 24                2026-03-06          29   NaN                []
# 11                2026-01-21          14   NaN                []
#
#                 observacao_expedicao  \
# evento_expedido
# 24
# 11
#
#                                                    ato_origem data_origem  \
# evento_expedido
# 24               Intimação para Videoconferência à disposição    02/03/26
# 11               Intimação para Videoconferência à disposição    12/01/26
#
#                 canais_historicos
# evento_expedido
# 24
# 11                        pessoal
# 2
#   evento                                                ato  \
# 0     20  Intimação lido(a) (Para OI MOVEL S A SOCIEDADE...
# 1     19  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
# 2     17  Intimação expedido(a) (P/ Advgs. de OI MOVEL S...
# 3     16  Intimação expedido(a) (P/ Advgs. de SEVERINO A...
# 4     12    Audiência Conciliação Realizada Sem conciliação
# 5      8  Citação lido(a) P/ OI MOVEL S A SOCIEDADE EMPR...
# 6      6  Citação expedido(a) Para OI MOVEL S A SOCIEDAD...
# 7      4  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
#
#                                      ato_normalizado data_texto    data_obj  \
# 0  intimação lido(a) (para oi movel s a sociedade...   21/01/19  2019-01-21
# 1  intimação lido(a) (para severino alves de oliv...   21/01/19  2019-01-21
# 2  intimação expedido(a) (p/ advgs. de oi movel s...   17/12/18  2018-12-17
# 3  intimação expedido(a) (p/ advgs. de severino a...   17/12/18  2018-12-17
# 4    audiência conciliação realizada sem conciliação   30/11/18  2018-11-30
# 5  citação lido(a) p/ oi movel s a sociedade empr...   14/11/18  2018-11-14
# 6  citação expedido(a) para oi movel s a sociedad...   31/10/18  2018-10-31
# 7  intimação lido(a) (para severino alves de oliv...   31/10/18  2018-10-31
#
#   data_leitura_str data_referencia_str                      autor observacao  \
# 0       2019-01-21            17/12/18                SISTEMA CNJ
# 1       2019-01-21            17/12/18                SISTEMA CNJ
# 2             None                None       IVAN GUEDES DA SILVA
# 3             None                None       IVAN GUEDES DA SILVA
# 4             None                None  CATARINE SA SANTOS E LIMA
# 5       2018-11-08                None                        ECT
# 6             None                None  MARCELO PEREIRA DA SILVAA
# 7       2018-10-31            31/10/18                SISTEMA CNJ
#
#    categoria meio_comunicacao situacao_comunicacao  \
# 0  intimacao             None                 lida
# 1  intimacao             None                 lida
# 2  intimacao    domicilio_cnj             expedida
# 3  intimacao    domicilio_cnj             expedida
# 4  audiencia             None            realizada
# 5    citacao             None                 lida
# 6    citacao             None             expedida
# 7  intimacao             None                 lida
#
#                                         destinatario
# 0  oi movel s a sociedade empresaria em recuperac...
# 1                    severino alves de oliveira lima
# 2  oi movel s a sociedade empresaria em recuperac...
# 3                    severino alves de oliveira lima
# 4                                               None
# 5  oi movel s a sociedade empresaria em recuperac...
# 6  oi movel s a sociedade empresaria em recuperac...
# 7                    severino alves de oliveira lima
# 0    False
# 1    False
# Name: revelia, dtype: bool
# processo_0007018-42.2018.8.05.0191
#                 data_expedicao  \
# evento_expedido
# 17                    17/12/18
# 16                    17/12/18
#
#                                                       ato_expedido  \
# evento_expedido
# 17               Intimação expedido(a) (P/ Advgs. de OI MOVEL S...
# 16               Intimação expedido(a) (P/ Advgs. de SEVERINO A...
#
#                                                       destinatario      meio  \
# evento_expedido
# 17               oi movel s a sociedade empresaria em recuperac...  advogado
# 16                                 severino alves de oliveira lima  advogado
#
#                          canal  \
# evento_expedido
# 17               domicilio_cnj
# 16               domicilio_cnj
#
#                                                           ato_lido  \
# evento_expedido
# 17               Intimação lido(a) (Para OI MOVEL S A SOCIEDADE...
# 16               Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
#
#                 data_leitura evento_lido prazo documentos_origem  \
# evento_expedido
# 17                2019-01-21          20   NaN                []
# 16                2019-01-21          19   NaN                []
#
#                 observacao_expedicao              ato_origem data_origem  \
# evento_expedido
# 17                                    Intimação à disposição    17/12/18
# 16                                    Intimação à disposição    17/12/18
#
#                  canais_historicos
# evento_expedido
# 17               advogado, pessoal
# 16                        advogado
# 2

# %%
df_final_relacoes = pd.concat(df_relacoes_total, ignore_index=True)
display(df_final_relacoes.head())
df_final_relacoes.columns
# Out:
#   evento_expedido data_expedicao  \
# 0             229       10/03/25
# 1             230       10/03/25
# 2             228       10/03/25
# 3             209       19/12/24
# 4             186       16/08/24
#
#                                         ato_expedido  \
# 0  Intimação expedido(a) (P/ Advgs. de MCT MEU TU...
# 1  Intimação expedido(a) (P/ Advgs. de PARATI - C...
# 2  Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 3  Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
# 4  Intimação expedido(a) (P/ Advgs. de LUIS ROBSO...
#
#                                         destinatario      meio          canal  \
# 0                                       mct meu tudo  advogado  domicilio_cnj
# 1  parati - credito financiamento e investimento ...  advogado  domicilio_cnj
# 2                                luis robson pereira  advogado  domicilio_cnj
# 3                                luis robson pereira  advogado  domicilio_cnj
# 4                                luis robson pereira  advogado  domicilio_cnj
#
#                                             ato_lido data_leitura evento_lido  \
# 0  Intimação lido(a) (Para MCT MEU TUDO) em 20/03...   2025-03-20         245
# 1  Intimação lido(a) (Para PARATI - CREDITO FINAN...   2025-03-18         243
# 2  Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...   2025-03-11         237
# 3  Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...   2025-01-21         214
# 4  Intimação lido(a) (Para LUIS ROBSON PEREIRA) e...   2024-08-19         189
#
#      prazo documentos_origem observacao_expedicao  \
# 0   5 dias                []
# 1   5 dias                []
# 2   5 dias                []
# 3  15 dias                []
# 4   5 dias                []
#
#                               ato_origem data_origem  canais_historicos
# 0                    Documento analisado    10/03/25  advogado, pessoal
# 1                    Documento analisado    10/03/25  advogado, pessoal
# 2                    Documento analisado    10/03/25  advogado, pessoal
# 3                 Intimação à disposição    19/12/24  advogado, pessoal
# 4  Proferido despacho de mero expediente    16/08/24  advogado, pessoal
# Index(['evento_expedido', 'data_expedicao', 'ato_expedido', 'destinatario',
#        'meio', 'canal', 'ato_lido', 'data_leitura', 'evento_lido', 'prazo',
#        'documentos_origem', 'observacao_expedicao', 'ato_origem',
#        'data_origem', 'canais_historicos'],
#       dtype='object')

# %%
for numero, df in processos.items():
    # df.drop('ato_normalizado')
    
    display(df[df['data_leitura_str'].notnull()])
    # display(df.drop(columns=[['ato_normalizado', 'data_obj']], axis=1))
    print(
        f"Processo: {numero} | "
        f"Movimentações: {len(df)}"
    )
# Out:
#    evento                                                ato  \
# 3      62  Intimação lido(a) (Para TV VINHOS LTDA) em 11/...
# 4      61  Intimação lido(a) (Para PAYOUT PAGAMENTOS INTE...
# 10     30  Citação lido(a) P/ PAYOUT PAGAMENTOS INTELIGEN...
# 11     28  Intimação lido(a) (Para TV VINHOS LTDA) em 05/...
# 12     26      Citação lido(a) P/ TV VINHOS LTDA em 05/02/26
# 13     25  Intimação lido(a) (Para PAYOUT PAGAMENTOS INTE...
# 21      6  Intimação lido(a) (Para DANILO AUGUSTO E ARAUJ...
#
#                                       ato_normalizado data_texto    data_obj  \
# 3   intimação lido(a) (para tv vinhos ltda) em 11/...   17/05/26  2026-05-17
# 4   intimação lido(a) (para payout pagamentos inte...   09/05/26  2026-05-09
# 10  citação lido(a) p/ payout pagamentos inteligen...   16/02/26  2026-02-16
# 11  intimação lido(a) (para tv vinhos ltda) em 05/...   14/02/26  2026-02-14
# 12      citação lido(a) p/ tv vinhos ltda em 05/02/26   14/02/26  2026-02-14
# 13  intimação lido(a) (para payout pagamentos inte...   03/02/26  2026-02-03
# 21  intimação lido(a) (para danilo augusto e arauj...   15/01/26  2026-01-15
#
#    data_leitura_str data_referencia_str        autor observacao  categoria  \
# 3        2026-05-11            28/04/26          ECT             intimacao
# 4        2026-05-08            28/04/26  SISTEMA CNJ             intimacao
# 10       2026-02-04                None          ECT               citacao
# 11       2026-02-05            21/01/26          ECT             intimacao
# 12       2026-02-05                None          ECT               citacao
# 13       2026-02-02            21/01/26  SISTEMA CNJ             intimacao
# 21       2026-01-15            15/01/26  SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao  \
# 3              None                 lida
# 4              None                 lida
# 10             None                 lida
# 11             None                 lida
# 12             None                 lida
# 13             None                 lida
# 21             None                 lida
#
#                                        destinatario
# 3                                    tv vinhos ltda
# 4               payout pagamentos inteligentes ltda
# 10  payout pagamentos inteligentes ltda em 04/02/26
# 11                                   tv vinhos ltda
# 12                       tv vinhos ltda em 05/02/26
# 13              payout pagamentos inteligentes ltda
# 21                   danilo augusto e araujo franca
# Processo: processo_0000084-87.2026.8.05.0191 | Movimentações: 22
#    evento                                                ato  \
# 8     223  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 16    182  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 42     41  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 43     40  Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEI...
# 47     27  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 48     26  Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEI...
# 49     25  Intimação lido(a) (Para AMIL ASSISTENCIA MEDIC...
# 50     24  Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEI...
# 53     13  Citação lido(a) P/ Representante: AMIL ASSISTE...
# 57      6  Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEI...
#
#                                       ato_normalizado data_texto    data_obj  \
# 8   intimação lido(a) (para amil assistencia medic...   20/03/26  2026-03-20
# 16  intimação lido(a) (para amil assistencia medic...   21/10/25  2025-10-21
# 42  intimação lido(a) (para amil assistencia medic...   17/05/25  2025-05-17
# 43  intimação lido(a) (para raquel lemos de olivei...   17/05/25  2025-05-17
# 47  intimação lido(a) (para amil assistencia medic...   07/03/25  2025-03-07
# 48  intimação lido(a) (para raquel lemos de olivei...   07/03/25  2025-03-07
# 49  intimação lido(a) (para amil assistencia medic...   18/02/25  2025-02-18
# 50  intimação lido(a) (para raquel lemos de olivei...   18/02/25  2025-02-18
# 53  citação lido(a) p/ representante: amil assiste...   07/02/25  2025-02-07
# 57  intimação lido(a) (para raquel lemos de olivei...   06/02/25  2025-02-06
#
#    data_leitura_str data_referencia_str                          autor  \
# 8        2026-03-19            09/03/26                    SISTEMA CNJ
# 16       2025-10-20            10/10/25                    SISTEMA CNJ
# 42       2025-05-16            06/05/25                    SISTEMA CNJ
# 43       2025-05-16            06/05/25                    SISTEMA CNJ
# 47       2025-03-06            17/02/25                    SISTEMA CNJ
# 48       2025-03-06            17/02/25                    SISTEMA CNJ
# 49       2025-02-17            06/02/25                    SISTEMA CNJ
# 50       2025-02-17            06/02/25                    SISTEMA CNJ
# 53       2025-02-07                None  Tulio Godoy Gomes Salles Rosa
# 57       2025-02-06            06/02/25                    SISTEMA CNJ
#
#    observacao  categoria meio_comunicacao situacao_comunicacao  \
# 8              intimacao             None                 lida
# 16             intimacao             None                 lida
# 42             intimacao             None                 lida
# 43             intimacao             None                 lida
# 47             intimacao             None                 lida
# 48             intimacao             None                 lida
# 49             intimacao             None                 lida
# 50             intimacao             None                 lida
# 53               citacao             None                 lida
# 57             intimacao             None                 lida
#
#                                          destinatario
# 8           amil assistencia medica internacional s a
# 16          amil assistencia medica internacional s a
# 42          amil assistencia medica internacional s a
# 43                           raquel lemos de oliveira
# 47          amil assistencia medica internacional s a
# 48                           raquel lemos de oliveira
# 49          amil assistencia medica internacional s a
# 50                           raquel lemos de oliveira
# 53  representante: amil assistencia medica interna...
# 57                           raquel lemos de oliveira
# Processo: processo_0000443-71.2025.8.05.0191 | Movimentações: 58
#    evento                                                ato  \
# 2     118  Intimação lido(a) (Para EDILEIDE DA SILVA LIMA...
# 4     114  Intimação lido(a) (Para EDILEIDE DA SILVA LIMA...
# 6      93  Intimação lido(a) (Para EDILEIDE DA SILVA LIMA...
# 8      30  Intimação lido(a) (Para LARBELO MOVEIS) em 10/...
# 10     19  Intimação lido(a) (Para EDILEIDE DA SILVA LIMA...
# 13     11      Citação lido(a) P/ LARBELO MOVEIS em 08/03/23
# 15      5  Intimação lido(a) (Para EDILEIDE DA SILVA LIMA...
#
#                                       ato_normalizado data_texto    data_obj  \
# 2   intimação lido(a) (para edileide da silva lima...   31/10/24  2024-10-31
# 4   intimação lido(a) (para edileide da silva lima...   24/10/24  2024-10-24
# 6   intimação lido(a) (para edileide da silva lima...   11/06/24  2024-06-11
# 8   intimação lido(a) (para larbelo moveis) em 10/...   16/05/23  2023-05-16
# 10  intimação lido(a) (para edileide da silva lima...   22/03/23  2023-03-22
# 13      citação lido(a) p/ larbelo moveis em 08/03/23   15/03/23  2023-03-15
# 15  intimação lido(a) (para edileide da silva lima...   16/02/23  2023-02-16
#
#    data_leitura_str data_referencia_str                            autor  \
# 2        2024-10-31            30/10/24  LEANA BEZERRA GOMES EVANGELISTA
# 4        2024-10-24            16/10/24  LEANA BEZERRA GOMES EVANGELISTA
# 6        2024-06-11            05/06/24  LEANA BEZERRA GOMES EVANGELISTA
# 8        2023-05-10            17/04/23                              ECT
# 10       2023-03-22            22/03/23  LEANA BEZERRA GOMES EVANGELISTA
# 13       2023-03-08                None                              ECT
# 15       2023-02-16            16/02/23                      SISTEMA CNJ
#
#    observacao  categoria meio_comunicacao situacao_comunicacao  \
# 2              intimacao             None                 lida
# 4              intimacao             None                 lida
# 6              intimacao             None                 lida
# 8              intimacao             None                 lida
# 10             intimacao             None                 lida
# 13               citacao             None                 lida
# 15             intimacao             None                 lida
#
#                   destinatario
# 2       edileide da silva lima
# 4       edileide da silva lima
# 6       edileide da silva lima
# 8               larbelo moveis
# 10      edileide da silva lima
# 13  larbelo moveis em 08/03/23
# 15      edileide da silva lima
# Processo: processo_0000485-91.2023.8.05.0191 | Movimentações: 16
#   evento                                                ato  \
# 2     35  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 3     32  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 7     14  Devolução sem Leitura De Intimação expedida em...
# 8     13  Intimação lido(a) (Para Núcleo de Atuação MP P...
#
#                                      ato_normalizado data_texto    data_obj  \
# 2  intimação lido(a) (para núcleo de atuação mp p...   10/04/26  2026-04-10
# 3  intimação lido(a) (para núcleo de atuação mp p...   07/04/26  2026-04-07
# 7  devolução sem leitura de intimação expedida em...   06/03/26  2026-03-06
# 8  intimação lido(a) (para núcleo de atuação mp p...   07/03/26  2026-03-07
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
#
# 18       2022-09-12            02/09/22                      SISTEMA CNJ
# 19       2022-09-05            02/09/22  FERNANDO AUGUSTO DE FARIA CORBO
# 23       2022-09-01            31/08/22             KALYF SANTOS ALMEIDA
# 25       2022-07-18            15/07/22  FERNANDO AUGUSTO DE FARIA CORBO
# 28       2022-07-11            11/07/22             KALYF SANTOS ALMEIDA
# 30       2022-06-20            08/06/22                      SISTEMA CNJ
# 31       2022-06-10            08/06/22  FERNANDO AUGUSTO DE FARIA CORBO
# 38       2022-03-28                None                      SISTEMA CNJ
# 39       2022-03-24            17/03/22             KALYF SANTOS ALMEIDA
# 42       2022-03-15            15/03/22                      SISTEMA CNJ
#
#    observacao  categoria meio_comunicacao situacao_comunicacao  \
# 2              intimacao             None                 lida
# 3              intimacao             None                 lida
# 6              intimacao             None                 lida
# 7              intimacao             None                 lida
# 10             intimacao             None                 lida
# 12             intimacao             None                 lida
# 13             intimacao             None                 lida
# 16             intimacao             None                 lida
# 18             intimacao             None             expedida
# 19             intimacao             None             expedida
# 23             intimacao             None                 lida
# 25             intimacao             None             expedida
# 28             intimacao             None                 lida
# 30             intimacao             None                 lida
# 31             intimacao             None                 lida
# 38               citacao             None                 lida
# 39             intimacao             None                 lida
# 42             intimacao             None                 lida
#
#                                          destinatario
# 2                    maria lucia teixeira de oliveira
# 3                   banco bradesco financiamentos s a
# 6                    maria lucia teixeira de oliveira
# 7                   banco bradesco financiamentos s a
# 10                  banco bradesco financiamentos s a
# 12                   maria lucia teixeira de oliveira
# 13                  banco bradesco financiamentos s a
# 16                  banco bradesco financiamentos s a
# 18                   maria lucia teixeira de oliveira
# 19                  banco bradesco financiamentos s a
# 23                   maria lucia teixeira de oliveira
# 25                  banco bradesco financiamentos s a
# 28                   maria lucia teixeira de oliveira
# 30                   maria lucia teixeira de oliveira
# 31                  banco bradesco financiamentos s a
# 38  banco bradesco financiamentos s a em 28/03/22 ...
# 39                   maria lucia teixeira de oliveira
# 42                   maria lucia teixeira de oliveira
# Processo: processo_0000554-60.2022.8.05.0191 | Movimentações: 43
#   evento                                                ato  \
# 5      9  Citação lido(a) P/ AZUL LINHAS AEREAS BRASILEI...
# 7      5  Intimação lido(a) (Para PAULO CESAR AGUIAR NET...
#
#                                      ato_normalizado data_texto    data_obj  \
# 5  citação lido(a) p/ azul linhas aereas brasilei...   13/03/26  2026-03-13
# 7  intimação lido(a) (para paulo cesar aguiar net...   12/03/26  2026-03-12
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 5       2026-03-13                None  SISTEMA CNJ               citacao
# 7       2026-03-12            12/03/26  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao  \
# 5             None                 lida
# 7             None                 lida
#
#                                         destinatario
# 5  azul linhas aereas brasileiras s a em 13/03/26...
# 7                            paulo cesar aguiar neto
# Processo: processo_0000686-78.2026.8.05.0191 | Movimentações: 8
#    evento                                                ato  \
# 0     112  Intimação lido(a) (Para BRUNO HENRIQUE GOMES B...
# 3     103  Intimação lido(a) (Para BRUNO HENRIQUE GOMES B...
# 9      72  Intimação lido(a) (Para BRUNO HENRIQUE GOMES B...
# 14     38  Intimação lido(a) (Para BRUNO HENRIQUE GOMES B...
# 15     36  Intimação lido(a) (Para BANCO SANTANDER BRASIL...
# 19     20  Citação lido(a) P/ BANCO SANTANDER BRASIL S A ...
#
#                                       ato_normalizado data_texto    data_obj  \
# 0
# 78   intimacao             None                 lida
# 79   intimacao             None                 lida
# 84   intimacao             None                 lida
# 86   intimacao             None                 lida
# 88   intimacao             None                 lida
# 89   intimacao             None                 lida
# 92   intimacao             None                 lida
# 94   intimacao             None                 lida
# 95   intimacao             None                 lida
# 96   intimacao             None                 lida
# 97   intimacao             None                 lida
# 103  intimacao             None                 lida
# 105  intimacao             None                 lida
# 106  intimacao             None                 lida
# 107  intimacao             None                 lida
# 108  intimacao             None                 lida
# 114    citacao             None                 lida
# 115    citacao             None                 lida
# 116    citacao             None                 lida
# 120  intimacao             None                 lida
#
#                                           destinatario
# 7                                   selma pereira dias
# 17                 priorizar corretora de seguros ltda
# 18   clube de saude administradora de beneficios ltda.
# 19                                  selma pereira dias
# 20                      hapvida assistencia medica s a
# 27                 priorizar corretora de seguros ltda
# 28   clube de saude administradora de beneficios ltda.
# 29                      hapvida assistencia medica s a
# 30                                  selma pereira dias
# 31                 priorizar corretora de seguros ltda
# 32                      hapvida assistencia medica s a
# 33   clube de saude administradora de beneficios ltda.
# 41                                  selma pereira dias
# 42                 priorizar corretora de seguros ltda
# 43                      hapvida assistencia medica s a
# 44   clube de saude administradora de beneficios ltda.
# 49                                  selma pereira dias
# 50                 priorizar corretora de seguros ltda
# 51   clube de saude administradora de beneficios ltda.
# 56                      hapvida assistencia medica s a
# 57   clube de saude administradora de beneficios ltda.
# 58                                  selma pereira dias
# 59                      hapvida assistencia medica s a
# 60                 priorizar corretora de seguros ltda
# 61   clube de saude administradora de beneficios ltda.
# 68                                  selma pereira dias
# 69                      hapvida assistencia medica s a
# 70                 priorizar corretora de seguros ltda
# 71   clube de saude administradora de beneficios ltda.
# 76                                  selma pereira dias
# 77                     hapvida assistencia medica s.a.
# 78                 priorizar corretora de seguros ltda
# 79   clube de saude administradora de beneficios ltda.
# 84                                  selma pereira dias
# 86                 priorizar corretora de seguros ltda
# 88                      priorizar corretora de seguros
# 89                                  selma pereira dias
# 92                                  selma pereira dias
# 94                      priorizar corretora de seguros
# 95                     hapvida assistencia medica s.a.
# 96   clube de saude administradora de beneficios ltda.
# 97                                  selma pereira dias
# 103                                 selma pereira dias
# 105                     priorizar corretora de seguros
# 106                    hapvida assistencia medica ltda
# 107   clube de saude administradora de beneficios ltda
# 108                                 selma pereira dias
# 114         priorizar corretora de seguros em 24/05/23
# 115  hapvida assistencia medica ltda em 19/05/23 ob...
# 116  representante: clube de saude administradora d...
# 120                                 selma pereira dias
# Processo: processo_0001340-70.2023.8.05.0191 | Movimentações: 121
#   evento                                                ato  \
# 0     16  Intimação lido(a) (Para GRUPO CASAS BAHIA S A)...
# 1     12  Citação lido(a) P/ GRUPO CASAS BAHIA S A em 20...
# 4      6  Intimação lido(a) (Para ANDREA CARLA CARDOSO D...
#
#                                      ato_normalizado data_texto    data_obj  \
# 0  intimação lido(a) (para grupo casas bahia s a)...   02/06/26  2026-06-02
# 1  citação lido(a) p/ grupo casas bahia s a em 20...   20/05/26  2026-05-20
# 4  intimação lido(a) (para andrea carla cardoso d...   20/05/26  2026-05-20
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 0       2026-06-01            20/05/26  SISTEMA CNJ             intimacao
# 1       2026-05-20                None  SISTEMA CNJ               citacao
# 4       2026-05-20            20/05/26  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao  \
# 0             None                 lida
# 1             None                 lida
# 4             None                 lida
#
#                                         destinatario
# 0                              grupo casas bahia s a
# 1  grupo casas bahia s a em 20/05/26 obs: leitura...
# 4                andrea carla cardoso de brito silva
# Processo: processo_0001463-63.2026.8.05.0191 | Movimentações: 5
#   evento                                                ato  \
# 6      5  Intimação lido(a) (Para MARCELO DANIEL MELO AL...
#
#                                      ato_normalizado data_texto    data_obj  \
# 6  intimação lido(a) (para marcelo daniel melo al...   25/05/26  2026-05-25
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 6       2026-05-25            25/05/26  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao                 destinatario
# 6             None                 lida  marcelo daniel melo alencar
# Processo: processo_0001518-14.2026.8.05.0191 | Movimentações: 7
#   evento                                                ato  \
# 0      6  Intimação lido(a) (Para ROGERIO FREITAS CAVALC...
#
#                                      ato_normalizado data_texto    data_obj  \
# 0  intimação lido(a) (para rogerio freitas cavalc...   02/06/26  2026-06-02
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 0       2026-06-02            02/06/26  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao                destinatario
# 0             None                 lida  rogerio freitas cavalcanti
# Processo: processo_0001618-66.2026.8.05.0191 | Movimentações: 1
#    evento                                                ato  \
# 4      21  Citação lido(a) P/ ASSOCIACAO DE APOSENTADOS M...
# 7      12  Intimação lido(a) (Para FLORISVALDO CARVALHO L...
# 11      6  Intimação lido(a) (Para FLORISVALDO CARVALHO L...
#
#                                       ato_normalizado data_texto    data_obj  \
# 4   citação lido(a) p/ associacao de aposentados m...   14/06/25  2025-06-14
# ...
# 8              None                 lida  núcleo de atuação mp paulo afonso
# 10             None                 lida  núcleo de atuação mp paulo afonso
# 12             None                 lida  núcleo de atuação mp paulo afonso
# 14             None                 lida  núcleo de atuação mp paulo afonso
# 16             None                 lida  núcleo de atuação mp paulo afonso
# 18             None                 lida           wilson oliveira da silva
# 19             None                 lida  núcleo de atuação mp paulo afonso
# Processo: processo_0003383-77.2023.8.05.0191 | Movimentações: 22
#    evento                                                ato  \
# 10      7  Citação lido(a) P/ EDITORA E DISTRIBUIDORA EDU...
# 12      4  Intimação lido(a) (Para LUANY GABRIELY BARBOZA...
#
#                                       ato_normalizado data_texto    data_obj  \
# 10  citação lido(a) p/ editora e distribuidora edu...   24/10/25  2025-10-24
# 12  intimação lido(a) (para luany gabriely barboza...   23/10/25  2025-10-23
#
#    data_leitura_str data_referencia_str        autor observacao  categoria  \
# 10       2025-10-24                None  SISTEMA CNJ               citacao
# 12       2025-10-23            23/10/25  SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao  \
# 10             None                 lida
# 12             None                 lida
#
#                                          destinatario
# 10  editora e distribuidora educacional s a em 24/...
# 12                  luany gabriely barboza dos santos
# Processo: processo_0003484-46.2025.8.05.0191 | Movimentações: 13
#    evento                                                ato  \
# 10      5  Intimação lido(a) (Para LUIZ RICARDO DA SILVA ...
#
#                                       ato_normalizado data_texto    data_obj  \
# 10  intimação lido(a) (para luiz ricardo da silva ...   23/10/25  2025-10-23
#
#    data_leitura_str data_referencia_str        autor observacao  categoria  \
# 10       2025-10-23            23/10/25  SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao                   destinatario
# 10             None                 lida  luiz ricardo da silva santana
# Processo: processo_0003485-31.2025.8.05.0191 | Movimentações: 11
#    evento                                                ato  \
# 15     42  Citação lido(a) P/ BANCO BRADESCO FINANCIAMENT...
# 20     22  Intimação lido(a) (Para BANCO BRADESCO FINANCI...
# 26      6  Intimação lido(a) (Para MARIA JOSE BEZERRA) em...
#
#                                       ato_normalizado data_texto    data_obj  \
# 15  citação lido(a) p/ banco bradesco financiament...   05/12/25  2025-12-05
# 20  intimação lido(a) (para banco bradesco financi...   04/11/25  2025-11-04
# 26  intimação lido(a) (para maria jose bezerra) em...   24/10/25  2025-10-24
#
#    data_leitura_str data_referencia_str        autor observacao  categoria  \
# 15       2025-11-12                None          ECT               citacao
# 20       2025-11-03            24/10/25  SISTEMA CNJ             intimacao
# 26       2025-10-24            24/10/25  SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao  \
# 15             None                 lida
# 20             None                 lida
# 26             None                 lida
#
#                                      destinatario
# 15  banco bradesco financiamentos s a em 12/11/25
# 20              banco bradesco financiamentos s a
# 26                             maria jose bezerra
# Processo: processo_0003496-60.2025.8.05.0191 | Movimentações: 27
#   evento                                                ato  \
# 5     29  Intimação lido(a) (Para CAMILA FERNADES DE ARA...
#
#                                      ato_normalizado data_texto    data_obj  \
# 5  intimação lido(a) (para camila fernades de ara...   05/12/25  2025-12-05
#
#   data_leitura_str data_referencia_str autor observacao  categoria  \
# 5       2025-11-06            30/10/25   ECT             intimacao
#
#   meio_comunicacao situacao_comunicacao               destinatario
# 5             None                 lida  camila fernades de araujo
# Processo: processo_0003540-79.2025.8.05.0191 | Movimentações: 9
#    evento                                                ato  \
# 21      8  Citação lido(a) P/ Representante: EMPRESA BAIA...
# 23      4  Intimação lido(a) (Para ENIVALDA AUREA DE MATO...
#
#                                       ato_normalizado data_texto    data_obj  \
# 21  citação lido(a) p/ representante: empresa baia...   12/11/25  2025-11-12
# 23  intimação lido(a) (para enivalda aurea de mato...   11/11/25  2025-11-11
#
#    data_leitura_str data_referencia_str  \
# 21       2025-11-12                None
# 23       2025-11-11            11/11/25
#
#                                     autor observacao  categoria  \
# 21  ELISANGELA DE QUEIROZ FERNANDES BRITO               citacao
# 23                            SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao  \
# 21             None                 lida
# 23             None                 lida
#
#                                          destinatario
# 21  representante: empresa baiana de aguas e sanea...
# 23                            enivalda aurea de matos
# Processo: processo_0003704-44.2025.8.05.0191 | Movimentações: 24
#    evento                                                ato  \
# 3      34  Intimação lido(a) (Para EDMILSON LOPES CABRAL)...
# 5      30  Intimação lido(a) (Para PREVEBENE ADMINISTRADO...
# 7      22  Intimação lido(a) (Para PREVEBENE ADMINISTRADO...
# 8      21  Intimação lido(a) (Para EDMILSON LOPES CABRAL)...
# 12      8  Citação lido(a) P/ PREVEBENE ADMINISTRADORA DE...
# 14      5  Intimação lido(a) (Para EDMILSON LOPES CABRAL)...
#
#                                       ato_normalizado data_texto    data_obj  \
# 3   intimação lido(a) (para edmilson lopes cabral)...   01/04/25  2025-04-01
# 5   intimação lido(a) (para prevebene administrado...   11/03/25  2025-03-11
# 7   intimação lido(a) (para prevebene administrado...   20/12/24  2024-12-20
# 8   intimação lido(a) (para edmilson lopes cabral)...   09/12/24  2024-12-09
# 12  citação lido(a) p/ prevebene administradora de...   04/11/24  2024-11-04
# 14  intimação lido(a) (para edmilson lopes cabral)...   03/11/24  2024-11-03
#
#    data_leitura_str data_referencia_str                         autor  \
# 3        2025-04-01            01/04/25  BRUNA PEREIRA DE SOUZA SILVA
# 5        2025-03-10            26/02/25                   SISTEMA CNJ
# 7        2024-12-19            09/12/24                   SISTEMA CNJ
# 8        2024-12-09            09/12/24  BRUNA PEREIRA DE SOUZA SILVA
# 12       2024-11-04                None                   SISTEMA CNJ
# 14       2024-11-03            03/11/24                   SISTEMA CNJ
#
#    observacao  categoria meio_comunicacao situacao_comunicacao  \
# 3              intimacao             None                 lida
# 5              intimacao             None                 lida
# 7              intimacao             None                 lida
# 8              intimacao             None                 lida
# 12               citacao             None                 lida
# 14             intimacao             None                 lida
#
#                                          destinatario
# 3                               edmilson lopes cabral
# 5   prevebene administradora de beneficios e promo...
# 7   prevebene administradora de beneficios e promo...
# 8                               edmilson lopes cabral
# 12  prevebene administradora de beneficios e promo...
# 14                              edmilson lopes cabral
# Processo: processo_0003806-03.2024.8.05.0191 | Movimentações: 15
#   evento                                                ato  \
# 2     27  Intimação lido(a) (Para TRANSPORTE COLETIVO BR...
# 4     16  Intimação lido(a) (Para ADAILTON PEREIRA DA SI...
# 7      8  Citação lido(a) P/ TRANSPORTE COLETIVO BRASIL ...
# 9      5  Intimação lido(a) (Para ADAILTON PEREIRA DA SI...
#
#                                      ato_normalizado data_texto    data_obj  \
# 2  intimação lido(a) (para transporte coletivo br...   24/04/25  2025-04-24
# 4  intimação lido(a) (para adailton pereira da si...   27/01/25  2025-01-27
# 7  citação lido(a) p/ transporte coletivo brasil ...   15/11/24  2024-11-15
# 9  intimação lido(a) (para adailton pereira da si...   04/11/24  2024-11-04
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 2       2025-04-23            13/04/25  SISTEMA CNJ             intimacao
# 4       2025-01-24            14/01/25  SISTEMA CNJ             intimacao
# 7       2024-11-18                None  SISTEMA CNJ               citacao
# 9       2024-11-04            04/11/24  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao  \
# 2             None                 lida
# 4             None                 lida
# 7             None                 lida
# 9             None                 lida
#
#                                         destinatario
# 2                    transporte coletivo brasil ltda
# 4                          adailton pereira da silva
# 7  transporte coletivo brasil ltda em 18/11/24 ob...
# 9                          adailton pereira da silva
# Processo: processo_0003821-69.2024.8.05.0191 | Movimentações: 10
#    evento                                                ato  \
# 0     112  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 3      94  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 5      79  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 7      74  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 10     65  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 12     61  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 14     40  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 16     24  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 19     16  Intimação lido(a) (Para Núcleo de Atuação MP P...
#
#                                       ato_normalizado data_texto    data_obj  \
# 0   intimação lido(a) (para núcleo de atuação mp p...   31/03/26  2026-03-31
# 3   intimação lido(a) (para núcleo de atuação mp p...   07/02/26  2026-02-07
# 5   intimação lido(a) (para núcleo de atuação mp p...   20/01/26  2026-01-20
# 7   intimação lido(a) (para núcleo de atuação mp p...   04/11/25  2025-11-04
# 10  intimação lido(a) (para núcleo de atuação mp p...   09/10/25  2025-10-09
# 12  intimação lido(a) (para núcleo de atuação mp p...   03/10/25  2025-10-03
# 14  intimação lido(a) (para núcleo de atuação mp p...   14/08/25  2025-08-14
# 16  intimação lido(a) (para núcleo de atuação mp p...   23/04/25  2025-04-23
# 19  intimação lido(a) (para núcleo de atuação mp p...   29/11/24  2024-11-29
#
#    data_leitura_str data_referencia_str  \
# 0        2026-03-30                None
# 3        2026-02-06                None
# 5        2026-01-21            15/12/25
# 7        2025-11-03                None
# 10       2025-10-09            07/10/25
# 12       2025-10-02                None
# 14       2025-08-14            12/08/25
# 16       2025-04-22                None
# 19       2024-11-28                None
#
#                                       autor observacao  categoria  \
# 0                               SISTEMA CNJ             intimacao
# 3                               SISTEMA CNJ             intimacao
# 5   FERNANDO ROGERIO PESSOA VILA NOVA FILHO             intimacao
# 7                               SISTEMA CNJ             intimacao
# 10  FERNANDO ROGERIO PESSOA VILA NOVA FILHO             intimacao
# 12                              SISTEMA CNJ             intimacao
# 14  FERNANDO ROGERIO PESSOA VILA NOVA FILHO             intimacao
# 16                              SISTEMA CNJ             intimacao
# 19                              SISTEMA CNJ             intimacao
#
#    meio_comunicacao situacao_comunicacao                       destinatario
# 0              None                 lida  núcleo de atuação mp paulo afonso
# 3           mandado                 lida  núcleo de atuação mp paulo afonso
# 5              None                 lida  núcleo de atuação mp paulo afonso
# 7              None                 lida  núcleo de atuação mp paulo afonso
# 10             None                 lida  núcleo de atuação mp paulo afonso
# 12             None                 lida  núcleo de atuação mp paulo afonso
# 14             None                 lida  núcleo de atuação mp paulo afonso
# 16             None                 lida  núcleo de atuação mp paulo afonso
# 19             None                 lida  núcleo de atuação mp paulo afonso
# Processo: processo_0004024-31.2024.8.05.0191 | Movimentações: 21
#   evento                                                ato  \
# 1     29  Intimação lido(a) (Para Núcleo de Atuação MP P...
# 4     14  Intimação lido(a) (Para CICERO ALENCAR DA SILV...
# 5     13  Intimação lido(a) (Para Núcleo de Atuação MP P...
#
#                                      ato_normalizado data_texto    data_obj  \
# 1  intimação lido(a) (para núcleo de atuação mp p...   06/03/26  2026-03-06
# 4  intimação lido(a) (para cicero alencar da silv...   06/02/26  2026-02-06
# 5  intimação lido(a) (para núcleo de atuação mp p...   23/01/26  2026-01-23
#
#   data_leitura_str data_referencia_str  \
# 1       2026-03-06            02/03/26
# 4       2026-01-21            12/01/26
# 5       2026-01-22                None
#
#                                      autor observacao  categoria  \
# 1  FERNANDO ROGERIO PESSOA VILA NOVA FILHO             intimacao
# 4                                      ECT             intimacao
# 5                              SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao                       destinatario
# 1             None                 lida  núcleo de atuação mp paulo afonso
# 4             None                 lida            cicero alencar da silva
# 5             None                 lida  núcleo de atuação mp paulo afonso
# Processo: processo_0004152-17.2025.8.05.0191 | Movimentações: 8
#   evento                                                ato  \
# 0     20  Intimação lido(a) (Para OI MOVEL S A SOCIEDADE...
# 1     19  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
# 5      8  Citação lido(a) P/ OI MOVEL S A SOCIEDADE EMPR...
# 7      4  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
#
#                                      ato_normalizado data_texto    data_obj  \
# 0  intimação lido(a) (para oi movel s a sociedade...   21/01/19  2019-01-21
# 1  intimação lido(a) (para severino alves de oliv...   21/01/19  2019-01-21
# 5  citação lido(a) p/ oi movel s a sociedade empr...   14/11/18  2018-11-14
# 7  intimação lido(a) (para severino alves de oliv...   31/10/18  2018-10-31
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 0       2019-01-21            17/12/18  SISTEMA CNJ             intimacao
# 1       2019-01-21            17/12/18  SISTEMA CNJ             intimacao
# 5       2018-11-08                None          ECT               citacao
# 7       2018-10-31            31/10/18  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao  \
# 0             None                 lida
# 1             None                 lida
# 5             None                 lida
# 7             None                 lida
#
#                                         destinatario
# 0  oi movel s a sociedade empresaria em recuperac...
# 1                    severino alves de oliveira lima
# 5  oi movel s a sociedade empresaria em recuperac...
# 7                    severino alves de oliveira lima
# Processo: processo_0007018-42.2018.8.05.0191 | Movimentações: 8

# %%
display(atos_relacionados[p])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 display(atos_relacionados[p])
#
# NameError: name 'atos_relacionados' is not defined

# %%
for i, j in atos_relacionados.items():
    display(i, j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 for i, j in atos_relacionados.items():
#       2     display(i, j)
#
# NameError: name 'atos_relacionados' is not defined

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 abc
#
# NameError: name 'abc' is not defined

# %%
df_relacoes = pd.DataFrame({

    'ato_origem':
        relacoes['ato_origem'],

    'data_origem':
        relacoes['data_origem'],

    'destinatario':
        relacoes['destinatario_lido'],

    'meio':
        relacoes['meio_real'],

    'canal':
        relacoes['meio_comunicacao_expedido'],

    'evento_lido':
        relacoes['evento_lido'],
        'data_leitura':
        relacoes['data_leitura_str_lido'],
     'prazo':
        relacoes['ato_expedido'].str.extract(
            r'(\d+\s*dias?)',
            expand=False
        ),

    'evento_expedido':
        relacoes['evento_expedido'],

    'data_expedicao':
        relacoes['data_texto_expedido'],

   

    'ato_expedido':
        relacoes['ato_expedido'],

    'ato_lido':
        relacoes['ato_lido']
})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 4
#       1 df_relacoes = pd.DataFrame({
#       2
#       3     'ato_origem':
# ----> 4         relacoes['ato_origem'],
#       5
#       6     'data_origem':
#       7         relacoes['data_origem'],
#       8
#       9     'destinatario':
#      10         relacoes['destinatario_lido'],
#      11
#      12     'meio':
#      13         relacoes['meio_real'],
#      14
#      15     'canal':
#      16         relacoes['meio_comunicacao_expedido'],
#      17
#      18     'evento_lido':
#      19         relacoes['evento_lido'],
#      20         'data_leitura':
#      21         relacoes['data_leitura_str_lido'],
#      22      'prazo':
#      23         relacoes['ato_expedido'].str.extract(
#      24             r'(\d+\s*dias?)',
#      25             expand=False
#      26         ),
#      27
#      28     'evento_expedido':
#      29         relacoes['evento_expedido'],
#      30
#      31     'data_expedicao':
#      32         relacoes['data_texto_expedido'],
#      33
#      34
#      35
#      36     'ato_expedido':
#      37         relacoes['ato_expedido'],
#      38
#      39     'ato_lido':
#      40         relacoes['ato_lido']
#      41 })
#
# TypeError: 'function' object is not subscriptable

# %%
display(df_relacoes)
# Out:
#   evento_expedido data_expedicao  \
# 0              17       17/12/18
# 1              16       17/12/18
#
#                                         ato_expedido  \
# 0  Intimação expedido(a) (P/ Advgs. de OI MOVEL S...
# 1  Intimação expedido(a) (P/ Advgs. de SEVERINO A...
#
#                                         destinatario      meio          canal  \
# 0  oi movel s a sociedade empresaria em recuperac...  advogado  domicilio_cnj
# 1                    severino alves de oliveira lima  advogado  domicilio_cnj
#
#                                             ato_lido data_leitura evento_lido  \
# 0  Intimação lido(a) (Para OI MOVEL S A SOCIEDADE...   2019-01-21          20
# 1  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...   2019-01-21          19
#
#   prazo              ato_origem data_origem  \
# 0   NaN  Intimação à disposição    17/12/18
# 1   NaN  Intimação à disposição    17/12/18
#
#                                                  key   automatiza  \
# 0  oi movel s a sociedade empresaria em recuperac...  automatizar
# 1                    severino alves de oliveira lima  automatizar
#
#    canais_historicos
# 0  advogado, pessoal
# 1           advogado

# %%
for destinatario, grupo in df.groupby('destinatario'):

    grupo = grupo.sort_values('data_obj')
    display(grupo)
# Out:
#   evento                                                ato  \
# 6      6  Citação expedido(a) Para OI MOVEL S A SOCIEDAD...
# 2     17  Intimação expedido(a) (P/ Advgs. de OI MOVEL S...
# 0     20  Intimação lido(a) (Para OI MOVEL S A SOCIEDADE...
#
#                                      ato_normalizado data_texto    data_obj  \
# 6  citação expedido(a) para oi movel s a sociedad...   31/10/18  2018-10-31
# 2  intimação expedido(a) (p/ advgs. de oi movel s...   17/12/18  2018-12-17
# 0  intimação lido(a) (para oi movel s a sociedade...   21/01/19  2019-01-21
#
#   data_leitura_str data_referencia_str                      autor observacao  \
# 6             None                None  MARCELO PEREIRA DA SILVAA
# 2             None                None       IVAN GUEDES DA SILVA
# 0       2019-01-21            17/12/18                SISTEMA CNJ
#
#    categoria meio_comunicacao situacao_comunicacao  \
# 6    citacao             None             expedida
# 2  intimacao    domicilio_cnj             expedida
# 0  intimacao             None                 lida
#
#                                         destinatario
# 6  oi movel s a sociedade empresaria em recuperac...
# 2  oi movel s a sociedade empresaria em recuperac...
# 0  oi movel s a sociedade empresaria em recuperac...
#   evento                                                ato  \
# 5      8  Citação lido(a) P/ OI MOVEL S A SOCIEDADE EMPR...
#
#                                      ato_normalizado data_texto    data_obj  \
# 5  citação lido(a) p/ oi movel s a sociedade empr...   14/11/18  2018-11-14
#
#   data_leitura_str data_referencia_str autor observacao categoria  \
# 5       2018-11-08                None   ECT              citacao
#
#   meio_comunicacao situacao_comunicacao  \
# 5             None                 lida
#
#                                         destinatario
# 5  oi movel s a sociedade empresaria em recuperac...
#   evento                                                ato  \
# 7      4  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
# 3     16  Intimação expedido(a) (P/ Advgs. de SEVERINO A...
# 1     19  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
#
#                                      ato_normalizado data_texto    data_obj  \
# 7  intimação lido(a) (para severino alves de oliv...   31/10/18  2018-10-31
# 3  intimação expedido(a) (p/ advgs. de severino a...   17/12/18  2018-12-17
# 1  intimação lido(a) (para severino alves de oliv...   21/01/19  2019-01-21
#
#   data_leitura_str data_referencia_str                 autor observacao  \
# 7       2018-10-31            31/10/18           SISTEMA CNJ
# 3             None                None  IVAN GUEDES DA SILVA
# 1       2019-01-21            17/12/18           SISTEMA CNJ
#
#    categoria meio_comunicacao situacao_comunicacao  \
# 7  intimacao             None                 lida
# 3  intimacao    domicilio_cnj             expedida
# 1  intimacao             None                 lida
#
#                       destinatario
# 7  severino alves de oliveira lima
# 3  severino alves de oliveira lima
# 1  severino alves de oliveira lima

# %%
lidas = grupo[
    grupo['situacao_comunicacao'] == 'lida'
]
expedidas = grupo[
    grupo['situacao_comunicacao'] == 'expedida'
]

# %%
display(lidas)
# Out:
#   evento                                                ato  \
# 7      4  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
# 1     19  Intimação lido(a) (Para SEVERINO ALVES DE OLIV...
#
#                                      ato_normalizado data_texto    data_obj  \
# 7  intimação lido(a) (para severino alves de oliv...   31/10/18  2018-10-31
# 1  intimação lido(a) (para severino alves de oliv...   21/01/19  2019-01-21
#
#   data_leitura_str data_referencia_str        autor observacao  categoria  \
# 7       2018-10-31            31/10/18  SISTEMA CNJ             intimacao
# 1       2019-01-21            17/12/18  SISTEMA CNJ             intimacao
#
#   meio_comunicacao situacao_comunicacao                     destinatario
# 7             None                 lida  severino alves de oliveira lima
# 1             None                 lida  severino alves de oliveira lima

# %%
resultado = []

for _, lido in lidas.iterrows():

    expedido = expedidas[
        (
            expedidas['destinatario']
            == lido['destinatario']
        )
        &
        (
            expedidas['data_obj']
            ==
            pd.to_datetime(
                lido['data_referencia_str'],
                dayfirst=True
            )
        )
    ]

    if len(expedido):

        expedido = expedido.iloc[0]

        resultado.append({

            'destinatario':
                lido['destinatario'],

            'evento_expedido':
                expedido['evento'],

            'evento_lido':
                lido['evento'],

            'data_expedicao':
                expedido['data_obj'],

            'data_leitura':
                lido['data_obj'],

            'meio':
                expedido['meio_comunicacao']
        })

# %%
print(resultado)
# Out:
# []

# %%
def buscar_relacao_evento(ato):
    
    padrao = re.search(
        # r'Intimação\s+(lido\(a\)|expedido\(a\))'
        # r'\s+(lido\(a\)|expedido\(a\))'
        r'(.+?)\s+(lido\(a\)|expedido\(a\))' #qualquer documento lido ou expedido
        r'.*?\(Para\s+(.*?)\)'
        r'.*?em\s+(\d{2}/\d{2}/\d{2})',
        # r'\(P/\s+Advgs?\.\s+de\s+(.*?)\)',
        # r'.*?\*Referente ao evento\s+(.*?)\((\d{2}/\d{2}/\d{2})\)',
        ato,
        re.I | re.S
    )
    return padrao

# %%
processos = []
for process_json in pasta.glob('*.json'):
    with open(process_json, 'r', encoding='utf-8') as f:
        processo = json.load(f)
        processos.append(processo)
# print(len(processos))
        df = pd.DataFrame(processos['movimentacoes'])
    display(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[278], line 7
#       5         processos.append(processo)
#       6 # print(len(processos))
# ----> 7         df = pd.DataFrame(processos['movimentacoes'])
#       8     display(df)
#
# TypeError: list indices must be integers or slices, not str

# %%
def referencia(ato):
    m_referente = re.search(r'\*Referente ao evento\s+(.*?)\((\d{2}/\d{2}/\d{2})\)', ato,re.I)

    if m_referente:
        evento = m_referente.group(1).strip()
        data_referencia = m_referente.group(2)

        print(f'''ref: {evento}
data referência {data_referencia}''')
        print('')
    return m_referente
        # print(data_referencia)
        
def destinatario(ato):

    #advogado
    m_adv = re.search(r'\(P/\s+Advgs?\.\s+de\s+(.*?)\)', ato, re.I)
    if m_adv:
        return {'tipo': 'advogado', 'nome': m_adv.group(1).strip()}
    # Advogado

    # DJEN
    m_djen = re.search(r'\bDJEN\b',ato,re.I)
    if m_djen:
        return {'tipo': 'djen', 'nome': m_djen.group(0).strip()}

    # AR
    m_ar = re.search(r'Juntada\s+de\s+AR',ato,re.I)
    if m_ar:
        return {'tipo': 'ar', 'nome': m_ar.group(0).strip()}
   

    # parte
    m = re.search(r'\(Para\s+(.*?)\)',ato,re.I)

    if m: 
        return {'tipo': 'parte','nome': m.group(1).strip()}

    return None

# %%
eventos_encadeados = []

for processo in processos:

    for mov in processo['movimentacoes']:

        # 1. Precisa ser um evento lido
        rel_lido = buscar_relacao_evento(mov['ato'])

        if not rel_lido:
            continue

        if rel_lido.group(2) != 'lido(a)':
            continue

        destinatario_lido = rel_lido.group(3)

        # 2. Precisa ter referência ao ato origem
        ref = referencia(mov['ato'])

        if not ref:
            continue

        nome_origem = ref.group(1).strip()
        data_origem = ref.group(2)

        # 3. Encontrar o ato origem
        ato_origem = None

        for mov_ref in processo['movimentacoes']:

            if mov_ref['data_texto'] != data_origem:
                continue

            if nome_origem.lower() in mov_ref['ato'].lower():
                ato_origem = mov_ref
                break

        if not ato_origem:
            continue
# Out:
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 15/01/26
#
# ref: Concedida a Medida Liminar
# data referência 09/03/26
#
# ref: Extinta a execução ou o cumprimento da sentença
# data referência 10/10/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/02/25
#
# ref: Intimação à disposição
# data referência 30/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 16/10/24
#
# ref: Intimação à disposição
# data referência 05/06/24
#
# ref: Intimação à disposição
# data referência 17/04/23
#
# ref: Julgada procedente em parte a ação
# data referência 22/03/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 16/02/23
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 12/03/26
#
# ref: Intimação à disposição
# data referência 27/04/26
#
# ref: Intimação expedido(a)
# data referência 09/03/26
#
# ref: Documento analisado
# data referência 07/11/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 07/04/26
#
# ref: Julgada procedente a ação
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 02/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 24/04/26
#
# ref: Proferido despacho de mero expediente
# data referência 01/04/26
#
# ref: Intimação à disposição
# data referência 28/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 12/04/25
#
# ref: Ato ordinatório praticado
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 25/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 02/06/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 03/06/26
#
# ref: Intimação expedido(a)
# data referência 15/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Intimação para Videoconferência à disposição
# data referência 07/07/25
#
# ref: Intimação à disposição
# data referência 07/07/25
#
# ref: Extinto o processo por Perempção, litispendência ou coisa julgada
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Proferido despacho de mero expediente
# data referência 04/09/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/06/25
#
# ref: Intimação à disposição
# data referência 12/05/25
#
# ref: Documento analisado
# data referência 03/12/24
#
# ref: Intimação à disposição
# data referência 25/11/24
#
# ref: Intimação à disposição
# data referência 01/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 10/07/24
#
# ref: Documento analisado
# data referência 24/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/06/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 14/07/25
#
# ref: Intimação à disposição
# data referência 12/09/25
#
# ref: Intimação à disposição
# data referência 01/09/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 28/08/24
#
# ref: Intimação à disposição
# data referência 10/06/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 01/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 06/02/26
#
# ref: Intimação à disposição
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 23/10/25
#
# ref: Intimação à disposição
# data referência 24/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 24/10/25
#
# ref: Intimação à disposição
# data referência 01/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 26/02/25
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 03/11/24
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Audiência  de Conciliação Designada
# data referência 31/10/18

# %%
eventos_encadeados = []

for processo in processos:

    for mov_lido in processo['movimentacoes']:

        # 1 - localizar leitura
        rel_lido = buscar_relacao_evento(mov_lido['ato'])

        if not rel_lido:
            continue

        if rel_lido.group(2) != 'lido(a)':
            continue

        destinatario_lido = rel_lido.group(3)

        # 2 - localizar referência
        ref = referencia(mov_lido['ato'])

        if not ref:
            continue

        nome_origem = ref.group(1).strip()
        data_origem = ref.group(2)

        # 3 - localizar ato origem
        ato_origem = next(
            (
                m for m in processo['movimentacoes']
                if m['data_texto'] == data_origem
                and nome_origem.lower() in m['ato'].lower()
            ),
            None
        )

        if not ato_origem:
            continue

        # 4 - localizar expedição correspondente
        evento_expedido = None
        meio_expedido = None

        for mov_exp in processo['movimentacoes']:

            rel_exp = buscar_relacao_evento(mov_exp['ato'])

            if not rel_exp:
                continue

            if rel_exp.group(2) != 'expedido(a)':
                continue

            info_exp = destinatario(mov_exp['ato'])

            if not info_exp:
                continue

            # mesmo destinatário
            if info_exp['nome'] != destinatario_lido:
                continue

            evento_expedido = mov_exp
            meio_expedido = info_exp['tipo']
            break

        # 5 - montar cadeia
        eventos_encadeados.append({
            'ato_origem': ato_origem,
            'evento_expedido': evento_expedido,
            'evento_lido': mov_lido,

            'destinatario': destinatario_lido,

            'meio_expedido': meio_expedido,
            'meio_lido': 'parte',

            'evento_referenciado': nome_origem,
            'data_referencia': data_origem,
        })
# Out:
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 15/01/26
#
# ref: Concedida a Medida Liminar
# data referência 09/03/26
#
# ref: Extinta a execução ou o cumprimento da sentença
# data referência 10/10/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/02/25
#
# ref: Intimação à disposição
# data referência 30/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 16/10/24
#
# ref: Intimação à disposição
# data referência 05/06/24
#
# ref: Intimação à disposição
# data referência 17/04/23
#
# ref: Julgada procedente em parte a ação
# data referência 22/03/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 16/02/23
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 12/03/26
#
# ref: Intimação à disposição
# data referência 27/04/26
#
# ref: Intimação expedido(a)
# data referência 09/03/26
#
# ref: Documento analisado
# data referência 07/11/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 07/04/26
#
# ref: Julgada procedente a ação
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 02/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 24/04/26
#
# ref: Proferido despacho de mero expediente
# data referência 01/04/26
#
# ref: Intimação à disposição
# data referência 28/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 12/04/25
#
# ref: Ato ordinatório praticado
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 25/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 02/06/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 03/06/26
#
# ref: Intimação expedido(a)
# data referência 15/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Intimação para Videoconferência à disposição
# data referência 07/07/25
#
# ref: Intimação à disposição
# data referência 07/07/25
#
# ref: Extinto o processo por Perempção, litispendência ou coisa julgada
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Proferido despacho de mero expediente
# data referência 04/09/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/06/25
#
# ref: Intimação à disposição
# data referência 12/05/25
#
# ref: Documento analisado
# data referência 03/12/24
#
# ref: Intimação à disposição
# data referência 25/11/24
#
# ref: Intimação à disposição
# data referência 01/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 10/07/24
#
# ref: Documento analisado
# data referência 24/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/06/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 14/07/25
#
# ref: Intimação à disposição
# data referência 12/09/25
#
# ref: Intimação à disposição
# data referência 01/09/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 28/08/24
#
# ref: Intimação à disposição
# data referência 10/06/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 01/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 06/02/26
#
# ref: Intimação à disposição
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 23/10/25
#
# ref: Intimação à disposição
# data referência 24/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 24/10/25
#
# ref: Intimação à disposição
# data referência 01/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 26/02/25
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 03/11/24
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Audiência  de Conciliação Designada
# data referência 31/10/18

# %%
eventos_encadeados = []

for processo in processos:
    for mov in processo['movimentacoes']:
        if 'lido(a)' in mov['ato']:
            print(f"Ev FILHO :{mov['evento']} - {mov['ato']}")
            evento_relacionado_filho = buscar_relacao_evento(mov['ato'])

            if evento_relacionado_filho:
                data_referencia = referencia(mov['ato']).group(2)
                destinatario_filho = buscar_relacao_evento(mov['ato']).group(3)
                # if not destinatario_filho:
                #     continue
            if data_referencia:
                for mov_ref in processo['movimentacoes']:
                    if mov_ref['data_texto'] == data_referencia:
                        evento_relacionado_pai = buscar_relacao_evento(mov_ref['ato'])
                        mov_pai = mov_ref
                        # dados_evento_pai = buscar_relacao_evento(mov_pai)
                        # if dados_evento_pai:
                        #     print(dados_evento_pai.group(2))
                if mov_pai:
                    evento_relacionado_pai = buscar_relacao_evento(mov_pai['ato'])
                    if evento_relacionado_pai:
                        documento = evento_relacionado_pai.group(1)
                        situacao = evento_relacionado_pai.group(2)
                        destinatario_pai = evento_relacionado_pai.group(3)
                        if not destinatario_pai and destinatario_filho:
                            continue
                        # if documento:# == evento_relacionado_filho.group(1):
                        if destinatario_pai == destinatario_filho:

                            print(f"Ev PAI: Ev:{mov_pai['evento']} - {mov_pai['data_texto']} - {mov_pai['ato']}") 
                            print(f"documento: {documento}")
                            print(f"situacão: {situacao}")
                            print(f"destinatário: {destinatario_pai}")
                            print('')

            if evento_relacionado_filho:
                if evento_relacionado_filho.group(3):
                    print("destinatário:", evento_relacionado_filho.group(3))
                if evento_relacionado_filho.group(1):
                    print("documento:", evento_relacionado_filho.group(1))
                if evento_relacionado_filho.group(2):
                    print("situação:", evento_relacionado_filho.group(2))
                if evento_relacionado_filho.group(4):
                    print("data leitura:", evento_relacionado_filho.group(4))


                else:
                    continue
                
            print('---------------------------------')
            print('')
            # if referencias:
            #     referencia = referencias.group(1)
            #     data_referencia = referencia.group(2)
                
                
                # print(referencia)
                # print(data_referencia)
                # print('---------------------------------')
                # print('')
        #     evento_relacionado = buscar_relacao_evento(mov['ato'])
        #     if not evento_relacionado:
        #         continue
        #     if evento_relacionado.group(4):
        #         data_ato_ref = evento_relacionado.group(4)
        #         for mov_ref in processo["movimentacoes"]:
        #             if mov_ref["data_texto"] == data_ato_ref:
        #                 eventos_pai = mov_ref
        #                 eventos_encadeados.append(eventos_pai)
        #                 eventos_encadeados.append(mov['ato'])
        #                 print(eventos_encadeados)
        #                 print('---------------------------------------------------')
        #                 break
        #     # else: 
        #     #     continue
                
        #     # if evento_relacionado:
        #     #     print("situação:", evento_relacionado.group(1))
        #     #     print("destinatário:", evento_relacionado.group(2))
        #     #     print("data leitura:", evento_relacionado.group(3))
        #     #     print("ato referência:", evento_relacionado.group(4))
        #     #     print("data ato:", evento_relacionado.group(5))
        #     #     print('---------------------------------------------------')

        # #     destinatario_por_adv = re.search(r'P\/\s+Advgs?\.', mov['ato'])
        # #     destinatario_pessoalmente = re.search(r'([A-Z])', mov['ato'])
        # # if destinatario_por_adv:
        # #     print(destinatario_por_adv.group())

        # # if destinatario_pessoalmente:
        # #     print(destinatario_pessoalmente.group())

        # print(mov['evento'])
        # print(mov['ato'])

    # if 'lido' in mov['ato']:
        # destinatario = 
        
        # print(f'DATA:{mov["data_texto"]}')
        # print(f'CAT:{mov["categoria"]}')
    # print(f'SIT:{mov["situacao_comunicacao"]})
    
    # print(f'REF:{mov["data_referencia_str"]})
# Out:
# Ev FILHO :62 - Intimação lido(a) (Para TV VINHOS LTDA) em 11/05/26 *Referente ao evento  Ato ordinatório praticado(28/04/26)
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# destinatário: TV VINHOS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 11/05/26
# ---------------------------------
#
# Ev FILHO :61 - Intimação lido(a) (Para PAYOUT PAGAMENTOS INTELIGENTES LTDA) em 08/05/26 *Referente ao evento  Ato ordinatório praticado(28/04/26)
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# destinatário: PAYOUT PAGAMENTOS INTELIGENTES LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 08/05/26
# ---------------------------------
#
# Ev FILHO :30 - Citação lido(a) P/ PAYOUT PAGAMENTOS INTELIGENTES LTDA em 04/02/26
# ---------------------------------
#
# Ev FILHO :28 - Intimação lido(a) (Para TV VINHOS LTDA) em 05/02/26 *Referente ao evento Intimação à disposição(21/01/26)
# ref: Intimação à disposição
# data referência 21/01/26
#
# destinatário: TV VINHOS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 05/02/26
# ---------------------------------
#
# Ev FILHO :26 - Citação lido(a) P/ TV VINHOS LTDA em 05/02/26
# ---------------------------------
#
# Ev FILHO :25 - Intimação lido(a) (Para PAYOUT PAGAMENTOS INTELIGENTES LTDA) em 02/02/26 *Referente ao evento Intimação à disposição(21/01/26)
# ref: Intimação à disposição
# data referência 21/01/26
#
# destinatário: PAYOUT PAGAMENTOS INTELIGENTES LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 02/02/26
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para DANILO AUGUSTO E ARAUJO FRANCA) em 15/01/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(15/01/26)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 15/01/26
#
# Ev PAI: Ev:6 - 15/01/26 - Intimação lido(a) (Para DANILO AUGUSTO E ARAUJO FRANCA) em 15/01/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(15/01/26)
# documento: Intimação
# situacão: lido(a)
# destinatário: DANILO AUGUSTO E ARAUJO FRANCA
#
# destinatário: DANILO AUGUSTO E ARAUJO FRANCA
# documento: Intimação
# situação: lido(a)
# data leitura: 15/01/26
# ---------------------------------
#
# Ev FILHO :223 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 19/03/26 *Referente ao evento Concedida a Medida Liminar(09/03/26)
# ref: Concedida a Medida Liminar
# data referência 09/03/26
#
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 19/03/26
# ---------------------------------
#
# Ev FILHO :182 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 20/10/25 *Referente ao evento Extinta a execução ou o cumprimento da sentença(10/10/25)
# ref: Extinta a execução ou o cumprimento da sentença
# data referência 10/10/25
#
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 20/10/25
# ---------------------------------
#
# Ev FILHO :41 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 16/05/25 *Referente ao evento Julgada procedente a ação(06/05/25)
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 16/05/25
# ---------------------------------
#
# Ev FILHO :40 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 16/05/25 *Referente ao evento Julgada procedente a ação(06/05/25)
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/05/25
# ---------------------------------
#
# Ev FILHO :27 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 06/03/25 *Referente ao evento Intimação à disposição(17/02/25)
# ref: Intimação à disposição
# data referência 17/02/25
#
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/25
# ---------------------------------
#
# Ev FILHO :26 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/03/25 *Referente ao evento Intimação à disposição(17/02/25)
# ref: Intimação à disposição
# data referência 17/02/25
#
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/25
# ---------------------------------
#
# Ev FILHO :25 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 17/02/25 *Referente ao evento Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA(06/02/25)
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 17/02/25
# ---------------------------------
#
# Ev FILHO :24 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 17/02/25 *Referente ao evento Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA(06/02/25)
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
#
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 17/02/25
# ---------------------------------
#
# Ev FILHO :13 - Citação lido(a) P/ Representante: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A em 07/02/25
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
#
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/02/25
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
#
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/02/25
# ---------------------------------
#
# Ev FILHO :118 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 31/10/24 *Referente ao evento Intimação à disposição(30/10/24)
# ref: Intimação à disposição
# data referência 30/10/24
#
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 31/10/24
# ---------------------------------
#
# Ev FILHO :114 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 24/10/24 *Referente ao evento  Proferido despacho de mero expediente(16/10/24)
# ref: Proferido despacho de mero expediente
# data referência 16/10/24
#
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 24/10/24
# ---------------------------------
#
# Ev FILHO :93 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 11/06/24 *Referente ao evento Intimação à disposição(05/06/24)
# ref: Intimação à disposição
# data referência 05/06/24
#
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 11/06/24
# ---------------------------------
#
# Ev FILHO :30 - Intimação lido(a) (Para LARBELO MOVEIS) em 10/05/23 *Referente ao evento Intimação à disposição(17/04/23)
# ref: Intimação à disposição
# data referência 17/04/23
#
# destinatário: LARBELO MOVEIS
# documento: Intimação
# situação: lido(a)
# data leitura: 10/05/23
# ---------------------------------
#
# Ev FILHO :19 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 22/03/23 *Referente ao evento Julgada procedente em parte a ação(22/03/23)
# ref: Julgada procedente em parte a ação
# data referência 22/03/23
#
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 22/03/23
# ---------------------------------
#
# Ev FILHO :11 - Citação lido(a) P/ LARBELO MOVEIS em 08/03/23
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 16/02/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (16/02/23)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 16/02/23
#
# Ev PAI: Ev:5 - 16/02/23 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 16/02/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (16/02/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
#
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/02/23
# ---------------------------------
#
# Ev FILHO :9 - Citação lido(a) P/ AZUL LINHAS AEREAS BRASILEIRAS S A em 13/03/26 OBS: Leitura realizada via Domicílio Eletrônico
# Ev PAI: Ev:5 - 16/02/23 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 16/02/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (16/02/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
#
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para PAULO CESAR AGUIAR NETO) em 12/03/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(12/03/26)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 12/03/26
#
# Ev PAI: Ev:5 - 12/03/26 - Intimação lido(a) (Para PAULO CESAR AGUIAR NETO) em 12/03/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(12/03/26)
# documento: Intimação
# situacão: lido(a)
# destinatário: PAULO CESAR AGUIAR NETO
#
# destinatário: PAULO CESAR AGUIAR NETO
# documento: Intimação
# situação: lido(a)
# data leitura: 12/03/26
# ---------------------------------
#
# Ev FILHO :112 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 07/05/26 *Referente ao evento Intimação à disposição(27/04/26)
# ref: Intimação à disposição
# data referência 27/04/26
#
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 07/05/26
# ---------------------------------
#
# Ev FILHO :103 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 19/03/26 *Referente ao evento Intimação expedido(a)(09/03/26)
# ref: Intimação expedido(a)
# data referência 09/03/26
#
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 19/03/26
# ---------------------------------
#
# Ev FILHO :72 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 17/11/25 *Referente ao evento Documento analisado(07/11/25)
# ref: Documento analisado
# data referência 07/11/25
#
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 17/11/25
# ---------------------------------
#
# Ev FILHO :38 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 09/05/25 *Referente ao evento Informações prestadas pela autoridade coatora expedido(a)(05/05/25)
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 09/05/25
# ---------------------------------
#
# Ev FILHO :36 - Intimação lido(a) (Para BANCO SANTANDER BRASIL S A) em 06/05/25 *Referente ao evento Informações prestadas pela autoridade coatora expedido(a)(05/05/25)
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# destinatário: BANCO SANTANDER BRASIL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 06/05/25
# ---------------------------------
#
# Ev FILHO :20 - Citação lido(a) P/ BANCO SANTANDER BRASIL S A em 01/04/25
# ---------------------------------
#
# Ev FILHO :22 - Citação lido(a) P/ BANCO MASTER S A em 29/04/26
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para JOSE HILTON MATOS DOS SANTOS) em 07/04/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(07/04/26)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 07/04/26
#
# Ev PAI: Ev:6 - 07/04/26 - Intimação lido(a) (Para JOSE HILTON MATOS DOS SANTOS) em 07/04/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(07/04/26)
# documento: Intimação
# situacão: lido(a)
# destinatário: JOSE HILTON MATOS DOS SANTOS
#
# destinatário: JOSE HILTON MATOS DOS SANTOS
# documento: Intimação
# situação: lido(a)
# data leitura: 07/04/26
# ---------------------------------
#
# Ev FILHO :18 - Intimação lido(a) (Para LUIZ ANTONIO DE ANDRADE) em 14/05/25 *Referente ao evento Julgada procedente a ação(13/05/25)
# ref: Julgada procedente a ação
# data referência 13/05/25
#
# destinatário: LUIZ ANTONIO DE ANDRADE
# documento: Intimação
# situação: lido(a)
# data leitura: 14/05/25
# ---------------------------------
#
# Ev FILHO :9 - Citação lido(a) P/ ASSOCIACAO DOS APOSENTADOS E PENSIONISTAS NACIONAL em 08/04/25
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para LUIZ ANTONIO DE ANDRADE) em 02/04/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (02/04/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 02/04/25
#
# Ev PAI: Ev:5 - 02/04/25 - Intimação lido(a) (Para LUIZ ANTONIO DE ANDRADE) em 02/04/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (02/04/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: LUIZ ANTONIO DE ANDRADE
#
# destinatário: LUIZ ANTONIO DE ANDRADE
# documento: Intimação
# situação: lido(a)
# data leitura: 02/04/25
# ---------------------------------
#
# Ev FILHO :246 - Intimação lido(a) (Para NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO) em 04/05/26 *Referente ao evento  Proferido despacho de mero expediente(24/04/26)
# ref: Proferido despacho de mero expediente
# data referência 24/04/26
#
# destinatário: NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO
# documento: Intimação
# situação: lido(a)
# data leitura: 04/05/26
# ---------------------------------
#
# Ev FILHO :228 - Intimação lido(a) (Para NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO) em 13/04/26 *Referente ao evento  Proferido despacho de mero expediente(01/04/26)
# ref: Proferido despacho de mero expediente
# data referência 01/04/26
#
# destinatário: NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO
# documento: Intimação
# situação: lido(a)
# data leitura: 13/04/26
# ---------------------------------
#
# Ev FILHO :27 - Intimação lido(a) (Para ERICK ERNANDES SANDES) em 08/05/25 *Referente ao evento Intimação à disposição(28/04/25)
# ref: Intimação à disposição
# data referência 28/04/25
#
# destinatário: ERICK ERNANDES SANDES
# documento: Intimação
# situação: lido(a)
# data leitura: 08/05/25
# ---------------------------------
#
# Ev FILHO :17 - Intimação lido(a) (Para NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO) em 25/04/25 *Referente ao evento  Ato ordinatório praticado(15/04/25)
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# destinatário: NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO
# documento: Intimação
# situação: lido(a)
# data leitura: 25/04/25
# ---------------------------------
#
# Ev FILHO :16 - Intimação lido(a) (Para ERICK ERNANDES SANDES) em 25/04/25 *Referente ao evento  Ato ordinatório praticado(15/04/25)
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# destinatário: ERICK ERNANDES SANDES
# documento: Intimação
# situação: lido(a)
# data leitura: 25/04/25
# ---------------------------------
#
# Ev FILHO :8 - Citação lido(a) P/ NU PAGAMENTOS S A INSTITUICAO DE PAGAMENTO em 14/04/25 OBS: Leitura realizada via Domicílio Eletrônico
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para ERICK ERNANDES SANDES) em 12/04/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (12/04/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 12/04/25
#
# Ev PAI: Ev:6 - 12/04/25 - Intimação lido(a) (Para ERICK ERNANDES SANDES) em 12/04/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (12/04/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: ERICK ERNANDES SANDES
#
# destinatário: ERICK ERNANDES SANDES
# documento: Intimação
# situação: lido(a)
# data leitura: 12/04/25
# ---------------------------------
#
# Ev FILHO :16 - Intimação lido(a) (Para GRUPO CASAS BAHIA S A) em 01/06/26 *Referente ao evento  Ato ordinatório praticado(20/05/26)
# ref: Ato ordinatório praticado
# data referência 20/05/26
#
# destinatário: GRUPO CASAS BAHIA S A
# documento: Intimação
# situação: lido(a)
# data leitura: 01/06/26
# ---------------------------------
#
# Ev FILHO :12 - Citação lido(a) P/ GRUPO CASAS BAHIA S A em 20/05/26 OBS: Leitura realizada via Domicílio Eletrônico
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (
- Intimação lido(a) (Para COMPANHIA DE SEGUROS PREVIDENCIA DO SUL) em 07/07/25 *Referente ao evento Extinto o processo por Perempção, litispendência ou coisa julgada(13/05/25)
# ref: Extinto o processo por Perempção, litispendência ou coisa julgada
# data referência 13/05/25
#
# destinatário: COMPANHIA DE SEGUROS PREVIDENCIA DO SUL
# documento: Intimação
# situação: lido(a)
# data leitura: 07/07/25
# ---------------------------------
#
# Ev FILHO :17 - Citação lido(a) P/ MONGERAL AEGON SEGUROS E PREVIDENCIA S/A em 16/05/25 OBS: Leitura realizada via Domicílio Eletrônico
# ---------------------------------
#
# Ev FILHO :16 - Citação lido(a) P/ Representante: COMPANHIA DE SEGUROS PREVIDENCIA DO SUL em 15/05/25
# ---------------------------------
#
# Ev FILHO :15 - Citação lido(a) P/ ASPECIR UNIAO SEGURADORA em 15/05/25 OBS: Leitura realizada via Domicílio Eletrônico
# ---------------------------------
#
# Ev FILHO :12 - Citação lido(a) P/ UNIMED SEGURADORA S/A em 13/05/25 OBS: Leitura realizada via Domicílio Eletrônico
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para JOSE CARLOS DO NASCIMENTO) em 13/05/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/05/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# Ev PAI: Ev:6 - 13/05/25 - Intimação lido(a) (Para JOSE CARLOS DO NASCIMENTO) em 13/05/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/05/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: JOSE CARLOS DO NASCIMENTO
#
# destinatário: JOSE CARLOS DO NASCIMENTO
# documento: Intimação
# situação: lido(a)
# data leitura: 13/05/25
# ---------------------------------
#
# Ev FILHO :52 - Intimação lido(a) (Para JOSE ALDSON FRANCA MINA) em 12/09/25 *Referente ao evento  Proferido despacho de mero expediente(04/09/25)
# ref: Proferido despacho de mero expediente
# data referência 04/09/25
#
# destinatário: JOSE ALDSON FRANCA MINA
# documento: Intimação
# situação: lido(a)
# data leitura: 12/09/25
# ---------------------------------
#
# Ev FILHO :26 - Intimação lido(a) (Para JOSE ALDSON FRANCA MINA) em 17/07/25 *Referente ao evento Julgada procedente em parte a ação(11/07/25)
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# destinatário: JOSE ALDSON FRANCA MINA
# documento: Intimação
# situação: lido(a)
# data leitura: 17/07/25
# ---------------------------------
#
# Ev FILHO :25 - Intimação lido(a) (Para GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA) em 21/07/25 *Referente ao evento Julgada procedente em parte a ação(11/07/25)
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# destinatário: GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 21/07/25
# ---------------------------------
#
# Ev FILHO :10 - Citação lido(a) P/ JOSE ALDSON FRANCA MINA em 12/06/25
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA) em 06/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/06/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/06/25
#
# Ev PAI: Ev:5 - 06/06/25 - Intimação lido(a) (Para GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA) em 06/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/06/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA
#
# destinatário: GJT PAULO AFONSO ALUGUEL DE EQUIPAMENTOS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/06/25
# ---------------------------------
#
# Ev FILHO :158 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 12/05/25 *Referente ao evento Intimação à disposição(12/05/25)
# ref: Intimação à disposição
# data referência 12/05/25
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 12/05/25
# ---------------------------------
#
# Ev FILHO :143 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 13/12/24 *Referente ao evento Documento analisado(03/12/24)
# ref: Documento analisado
# data referência 03/12/24
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 13/12/24
# ---------------------------------
#
# Ev FILHO :139 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 02/12/24 *Referente ao evento Intimação à disposição(25/11/24)
# ref: Intimação à disposição
# data referência 25/11/24
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 02/12/24
# ---------------------------------
#
# Ev FILHO :128 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 01/10/24 *Referente ao evento Intimação à disposição(01/10/24)
# ref: Intimação à disposição
# data referência 01/10/24
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 01/10/24
# ---------------------------------
#
# Ev FILHO :104 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 11/07/24 *Referente ao evento  Proferido despacho de mero expediente(10/07/24)
# ref: Proferido despacho de mero expediente
# data referência 10/07/24
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 11/07/24
# ---------------------------------
#
# Ev FILHO :96 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 06/05/24 *Referente ao evento Documento analisado(24/04/24)
# ref: Documento analisado
# data referência 24/04/24
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/05/24
# ---------------------------------
#
# Ev FILHO :86 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 05/04/24 *Referente ao evento Julgada procedente em parte a ação(26/03/24)
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 05/04/24
# ---------------------------------
#
# Ev FILHO :85 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 27/03/24 *Referente ao evento Julgada procedente em parte a ação(26/03/24)
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 27/03/24
# ---------------------------------
#
# Ev FILHO :75 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 01/12/23 *Referente ao evento Intimação para Videoconferência à disposição(21/11/23)
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 01/12/23
# ---------------------------------
#
# Ev FILHO :74 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 01/12/23 *Referente ao evento  Proferido despacho de mero expediente(21/11/23)
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 01/12/23
# ---------------------------------
#
# Ev FILHO :73 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 23/11/23 *Referente ao evento Intimação para Videoconferência à disposição(21/11/23)
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 23/11/23
# ---------------------------------
#
# Ev FILHO :67 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 21/11/23 *Referente ao evento  Proferido despacho de mero expediente(21/11/23)
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 21/11/23
# ---------------------------------
#
# Ev FILHO :59 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 16/11/23 *Referente ao evento Intimação para Videoconferência à disposição(06/11/23)
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/11/23
# ---------------------------------
#
# Ev FILHO :58 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 06/11/23 *Referente ao evento Intimação para Videoconferência à disposição(06/11/23)
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 06/11/23
# ---------------------------------
#
# Ev FILHO :51 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 16/10/23 *Referente ao evento Intimação para Videoconferência à disposição(03/10/23)
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/10/23
# ---------------------------------
#
# Ev FILHO :50 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 16/10/23 *Referente ao evento Intimação para Videoconferência à disposição(03/10/23)
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/10/23
# ---------------------------------
#
# Ev FILHO :49 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 05/10/23 *Referente ao evento Intimação para Videoconferência à disposição(03/10/23)
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 05/10/23
# ---------------------------------
#
# Ev FILHO :48 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 05/10/23 *Referente ao evento Intimação para Videoconferência à disposição(03/10/23)
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 05/10/23
# ---------------------------------
#
# Ev FILHO :27 - Intimação lido(a) (Para INSTITUTO EM BELLEZA ARACAJU LTDA) em 25/08/23 *Referente ao evento Intimação para Videoconferência à disposição(24/08/23)
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# destinatário: INSTITUTO EM BELLEZA ARACAJU LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 25/08/23
# ---------------------------------
#
# Ev FILHO :26 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 24/08/23 *Referente ao evento Intimação para Videoconferência à disposição(24/08/23)
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 24/08/23
# ---------------------------------
#
# Ev FILHO :9 - Citação lido(a) P/ INSTITUTO EM BELLEZA ARACAJU LTDA em 31/07/23
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 18/07/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (18/07/23)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/23
#
# Ev PAI: Ev:5 - 18/07/23 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 18/07/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (18/07/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: SANDRA PATRICIA RESTREPO PONTES
#
# destinatário: SANDRA PATRICIA RESTREPO PONTES
# documento: Intimação
# situação: lido(a)
# data leitura: 18/07/23
# ---------------------------------
#
# Ev FILHO :60 - Citação lido(a) P/ PAULO AFONSO CURSOS TECNICOS LTDA em 18/07/25
# Ev PAI: Ev:5 - 18/07/23 - Intimação lido(a) (Para SANDRA PATRICIA RESTREPO PONTES) em 18/07/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (18/07/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: SANDRA PATRICIA RESTREPO PONTES
#
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para KAMILLA SOUZA GOMES DA COSTA) em 13/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/06/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/06/25
#
# Ev PAI: Ev:6 - 13/06/25 - Intimação lido(a) (Para KAMILLA SOUZA GOMES DA COSTA) em 13/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/06/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: KAMILLA SOUZA GOMES DA COSTA
#
# destinatário: KAMILLA SOUZA GOMES DA COSTA
# documento: Intimação
# situação: lido(a)
# data leitura: 13/06/25
# ---------------------------------
#
# Ev FILHO :11 - Citação lido(a) P/ PKL ONE PARTICIPACOES S.A. em 14/07/25 OBS: Leitura realizada via Domicílio Eletrônico
# Ev PAI: Ev:6 - 13/06/25 - Intimação lido(a) (Para KAMILLA SOUZA GOMES DA COSTA) em 13/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/06/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: KAMILLA SOUZA GOMES DA COSTA
#
# ---------------------------------
#
# Ev FILHO :10 - Citação lido(a) P/ BANCO MASTER S A em 14/07/25 OBS: Leitura realizada via Domicílio Eletrônico
# Ev PAI: Ev:6 - 13/06/25 - Intimação lido(a) (Para KAMILLA SOUZA GOMES DA COSTA) em 13/06/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (13/06/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: KAMILLA SOUZA GOMES DA COSTA
#
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para ALESSANDRO DA SILVA FEITOSA) em 14/07/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (14/07/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 14/07/25
#
# Ev PAI: Ev:6 - 14/07/25 - Intimação lido(a) (Para ALESSANDRO DA SILVA FEITOSA) em 14/07/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (14/07/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: ALESSANDRO DA SILVA FEITOSA
#
# destinatário: ALESSANDRO DA SILVA FEITOSA
# documento: Intimação
# situação: lido(a)
# data leitura: 14/07/25
# ---------------------------------
#
# Ev FILHO :60 - Intimação lido(a) (Para JERSON UBIRATAN DA SILVA BARROS) em 19/09/25 *Referente ao evento Intimação à disposição(12/09/25)
# ref: Intimação à disposição
# data referência 12/09/25
#
# destinatário: JERSON UBIRATAN DA SILVA BARROS
# documento: Intimação
# situação: lido(a)
# data leitura: 19/09/25
# ---------------------------------
#
# Ev FILHO :57 - Intimação lido(a) (Para JERSON UBIRATAN DA SILVA BARROS) em 05/09/25 *Referente ao evento Intimação à disposição(01/09/25)
# ref: Intimação à disposição
# data referência 01/09/25
#
# destinatário: JERSON UBIRATAN DA SILVA BARROS
# documento: Intimação
# situação: lido(a)
# data leitura: 05/09/25
# ---------------------------------
#
# Ev FILHO :9 - Citação lido(a) P/ JERSON UBIRATAN DA SILVA BARROS em 24/07/25
# ---------------------------------
#
# Ev FILHO :4 - Intimação lido(a) (Para CONDOMINIO RESIDENCIAL BRISAS DO LAGO) em 18/07/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (18/07/25)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/25
#
# Ev PAI: Ev:4 - 18/07/25 - Intimação lido(a) (Para CONDOMINIO RESIDENCIAL BRISAS DO LAGO) em 18/07/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (18/07/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: CONDOMINIO RESIDENCIAL BRISAS DO LAGO
#
# destinatário: CONDOMINIO RESIDENCIAL BRISAS DO LAGO
# documento: Intimação
# situação: lido(a)
# data leitura: 18/07/25
# ---------------------------------
#
# Ev FILHO :30 - Intimação lido(a) (Para VOLTZ MOTORS DO BRASIL COMERCIO DE MOTOCICLETAS LTDA - EM RECUPERACAO JUDICIAL) em 24/01/25 *Referente ao evento Intimação à disposição(14/01/25)
# ref: Intimação à disposição
# data referência 14/01/25
#
# destinatário: VOLTZ MOTORS DO BRASIL COMERCIO DE MOTOCICLETAS LTDA - EM RECUPERACAO JUDICIAL
# documento: Intimação
# situação: lido(a)
# data leitura: 24/01/25
# ---------------------------------
#
# Ev FILHO :29 - Intimação lido(a) (Para HEVITON OLIVEIRA RODRIGUES) em 24/01/25 *Referente ao evento Intimação à disposição(14/01/25)
# ref: Intimação à disposição
# data referência 14/01/25
#
# destinatário: HEVITON OLIVEIRA RODRIGUES
# documento: Intimação
# situação: lido(a)
# data leitura: 24/01/25
# ---------------------------------
#
# Ev FILHO :8 - Citação lido(a) P/ VOLTZ MOTORS DO BRASIL COMERCIO DE MOTOCICLETAS LTDA - EM RECUPERACAO JUDICIAL em 10/09/24 OBS: Leitura Automática Pelo ProJudi ou on-line pela parte
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para HEVITON OLIVEIRA RODRIGUES) em 28/08/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (28/08/24)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 28/08/24
#
# Ev PAI: Ev:5 - 28/08/24 - Intimação lido(a) (Para HEVITON OLIVEIRA RODRIGUES) em 28/08/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (28/08/24)
# documento: Intimação
# situacão: lido(a)
# destinatário: HEVITON OLIVEIRA RODRIGUES
#
# destinatário: HEVITON OLIVEIRA RODRIGUES
# documento: Intimação
# situação: lido(a)
# data leitura: 28/08/24
# ---------------------------------
#
# Ev FILHO :61 - Intimação lido(a) (Para ROBSON DE OLIVEIRA SILVA) em 20/06/24 *Referente ao evento Intimação à disposição(10/06/24)
# ref: Intimação à disposição
# data referência 10/06/24
#
# destinatário: ROBSON DE OLIVEIRA SILVA
# documento: Intimação
# situação: lido(a)
# data leitura: 20/06/24
# ---------------------------------
#
# Ev FILHO :51 - Intimação lido(a) (Para ROBSON DE OLIVEIRA SILVA) em 06/05/24 *Referente ao evento Julgada procedente em parte a ação(25/04/24)
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# destinatário: ROBSON DE OLIVEIRA SILVA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/05/24
# ---------------------------------
#
# Ev FILHO :50 - Intimação lido(a) (Para FABIANA DOS SANTOS SILVA GOMES MARMORARIA) em 25/04/24 *Referente ao evento Julgada procedente em parte a ação(25/04/24)
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# destinatário: FABIANA DOS SANTOS SILVA GOMES MARMORARIA
# documento: Intimação
# situação: lido(a)
# data leitura: 25/04/24
# ---------------------------------
#
# Ev FILHO :44 - Intimação lido(a) (Para ROBSON DE OLIVEIRA SILVA) em 18/03/24 *Referente ao evento Intimação para Videoconferência à disposição(06/03/24)
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# destinatário: ROBSON DE OLIVEIRA SILVA
# documento: Intimação
# situação: lido(a)
# data leitura: 18/03/24
# ---------------------------------
#
# Ev FILHO :42 - Intimação lido(a) (Para ROBSON DE OLIVEIRA SILVA) em 18/03/24 *Referente ao evento Intimação para Videoconferência à disposição(06/03/24)
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# destinatário: ROBSON DE OLIVEIRA SILVA
# documento: Intimação
# situação: lido(a)
# data leitura: 18/03/24
# ---------------------------------
#
# Ev FILHO :40 - Intimação lido(a) (Para ROBSON DE OLIVEIRA SILVA) em 18/03/24 *Referente ao evento  Proferido despacho de mero expediente(06/03/24)
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# destinatário: ROBSON DE OLIVEIRA SILVA
# documento: Intimação
# situação: lido(a)
# data leitura: 18/03/24
# ---------------------------------
#
# Ev FILHO :35 - Intimação lido(a) (Para FABIANA DOS SANTOS SILVA GOMES MARMORARIA) em 06/03/24 *Referente ao evento Intimação para Videoconferência à disposição(06/03/24)
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# destinatário: FABIANA DOS SANTOS SILVA GOMES MARMORARIA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/24
# ---------------------------------
#
# Ev FILHO :34 - Intimação lido(a) (Para FABIANA DOS SANTOS SILVA GOMES MARMORARIA) em 06/03/24 *Referente ao evento  Proferido despacho de mero expediente(06/03/24)
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# destinatário: FABIANA DOS SANTOS SILVA GOMES MARMORARIA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/24
# ---------------------------------
#
# Ev FILHO :8 - Citação lido(a) P/ ROBSON DE OLIVEIRA SILVA em 17/11/23
# ---------------------------------
#
# Ev FILHO :4 - Intimação lido(a) (Para FABIANA DOS SANTOS SILVA GOMES MARMORARIA) em 01/11/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (01/11/23)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 01/11/23
#
# Ev PAI: Ev:4 - 01/11/23 - Intimação lido(a) (Para FABIANA DOS SANTOS SILVA GOMES MARMORARIA) em 01/11/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (01/11/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: FABIANA DOS SANTOS SILVA GOMES MARMORARIA
#
# destinatário: FABIANA DOS SANTOS SILVA GOMES MARMORARIA
# documento: Intimação
# situação: lido(a)
# data leitura: 01/11/23
# ---------------------------------
#
# Ev FILHO :81 - Intimação lido(a) (Para BANCO BRADESCO S A) em 19/02/26 *Referente ao evento  Proferido despacho de mero expediente(06/02/26)
# ref: Proferido despacho de mero expediente
# data referência 06/02/26
#
# destinatário: BANCO BRADESCO S A
# documento: Intimação
# situação: lido(a)
# data leitura: 19/02/26
# ---------------------------------
#
# Ev FILHO :36 - Citação lido(a) P/ BANCO BRADESCO S A em 30/10/25
# ---------------------------------
#
# Ev FILHO :20 - Intimação lido(a) (Para BANCO BRADESCO S A) em 24/10/25 *Referente ao evento Intimação à disposição(14/10/25)
# ref: Intimação à disposição
# data referência 14/10/25
#
# destinatário: BANCO BRADESCO S A
# documento: Intimação
# situação: lido(a)
# data leitura: 24/10/25
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para WENDEL CORDEIRO MARQUES) em 14/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(14/10/25)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 14/10/25
#
# Ev PAI: Ev:6 - 14/10/25 - Intimação lido(a) (Para WENDEL CORDEIRO MARQUES) em 14/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(14/10/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: WENDEL CORDEIRO MARQUES
#
# destinatário: WENDEL CORDEIRO MARQUES
# documento: Intimação
# situação: lido(a)
# data leitura: 14/10/25
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para LUIZ RICARDO DA SILVA SANTANA) em 23/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(23/10/25)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 23/10/25
#
# Ev PAI: Ev:5 - 23/10/25 - Intimação lido(a) (Para LUIZ RICARDO DA SILVA SANTANA) em 23/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(23/10/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: LUIZ RICARDO DA SILVA SANTANA
#
# destinatário: LUIZ RICARDO DA SILVA SANTANA
# documento: Intimação
# situação: lido(a)
# data leitura: 23/10/25
# ---------------------------------
#
# Ev FILHO :42 - Citação lido(a) P/ BANCO BRADESCO FINANCIAMENTOS S A em 12/11/25
# Ev PAI: Ev:5 - 23/10/25 - Intimação lido(a) (Para LUIZ RICARDO DA SILVA SANTANA) em 23/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(23/10/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: LUIZ RICARDO DA SILVA SANTANA
#
# ---------------------------------
#
# Ev FILHO :22 - Intimação lido(a) (Para BANCO BRADESCO FINANCIAMENTOS S A) em 03/11/25 *Referente ao evento Intimação à disposição(24/10/25)
# ref: Intimação à disposição
# data referência 24/10/25
#
# destinatário: BANCO BRADESCO FINANCIAMENTOS S A
# documento: Intimação
# situação: lido(a)
# data leitura: 03/11/25
# ---------------------------------
#
# Ev FILHO :6 - Intimação lido(a) (Para MARIA JOSE BEZERRA) em 24/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(24/10/25)
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 24/10/25
#
# Ev PAI: Ev:6 - 24/10/25 - Intimação lido(a) (Para MARIA JOSE BEZERRA) em 24/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(24/10/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: MARIA JOSE BEZERRA
#
# destinatário: MARIA JOSE BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 24/10/25
# ---------------------------------
#
# Ev FILHO :34 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 01/04/25 *Referente ao evento Intimação à disposição(01/04/25)
# ref: Intimação à disposição
# data referência 01/04/25
#
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 01/04/25
# ---------------------------------
#
# Ev FILHO :30 - Intimação lido(a) (Para PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA) em 10/03/25 *Referente ao evento  Proferido despacho de mero expediente(26/02/25)
# ref: Proferido despacho de mero expediente
# data referência 26/02/25
#
# destinatário: PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 10/03/25
# ---------------------------------
#
# Ev FILHO :22 - Intimação lido(a) (Para PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA) em 19/12/24 *Referente ao evento Intimação à disposição(09/12/24)
# ref: Intimação à disposição
# data referência 09/12/24
#
# destinatário: PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 19/12/24
# ---------------------------------
#
# Ev FILHO :21 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 09/12/24 *Referente ao evento Intimação à disposição(09/12/24)
# ref: Intimação à disposição
# data referência 09/12/24
#
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 09/12/24
# ---------------------------------
#
# Ev FILHO :8 - Citação lido(a) P/ PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA em 04/11/24 OBS: Leitura Automática Pelo ProJudi ou on-line pela parte
# ---------------------------------
#
# Ev FILHO :5 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 03/11/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (03/11/24)
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 03/11/24
#
# Ev PAI: Ev:5 - 03/11/24 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 03/11/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (03/11/24)
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
#
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 03/11/24
# ---------------------------------
#
# Ev FILHO :20 - Intimação lido(a) (Para OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)
# ref: Intimação à disposição
# data referência 17/12/18
#
# destinatário: OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL
# documento: Intimação
# situação: lido(a)
# data leitura: 21/01/19
# ---------------------------------
#
# Ev FILHO :19 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)
# ref: Intimação à disposição
# data referência 17/12/18
#
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 21/01/19
# ---------------------------------
#
# Ev FILHO :8 - Citação lido(a) P/ OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL em 08/11/18
# ---------------------------------
#
# Ev FILHO :4 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 31/10/18 *Referente ao evento Audiência  de Conciliação Designada(31/10/18)
# ref: Audiência  de Conciliação Designada
# data referência 31/10/18
#
# Ev PAI: Ev:4 - 31/10/18 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 31/10/18 *Referente ao evento Audiência  de Conciliação Designada(31/10/18)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
#
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 31/10/18
# ---------------------------------

# %%
eventos_encadeados = []

for processo in processos:
    print( 'Processo: ', processo)
    for mov in processo['movimentacoes']:
        # if 'lido(a)' in mov['ato']:
        #     print(f"Ev FILHO :{mov['evento']} - {mov['ato']}")
        evento_relacionado_filho = buscar_relacao_evento(mov['ato'])

        if evento_relacionado_filho:
            data_referencia = referencia(mov['ato']).group(2)
            destinatario_filho = buscar_relacao_evento(mov['ato']).group(3)
            # meio_filho = destinatario(mov['ato'])
            
            # if meio_filho:
            #     print(meio_filho['tipo'])

            if not destinatario_filho:
                continue
        if data_referencia:
            for mov_ref in processo['movimentacoes']:
                if mov_ref['data_texto'] == data_referencia:
                    evento_relacionado_pai = buscar_relacao_evento(mov_ref['ato'])
                    meio_pai = destinatario(mov_ref['ato'])
                    mov_pai = mov_ref
                        # dados_evento_pai = buscar_relacao_evento(mov_pai)
                        # if dados_evento_pai:
                        #     print(dados_evento_pai.group(2))
            if mov_pai:
                evento_relacionado_pai = buscar_relacao_evento(mov_ref['ato'])
                if evento_relacionado_pai:
                    documento = evento_relacionado_pai.group(1)
                    situacao = evento_relacionado_pai.group(2)
                    destinatario_pai = evento_relacionado_pai.group(3)
                    
                    if not destinatario_pai and destinatario_filho:
                        continue
                        # if documento:# == evento_relacionado_filho.group(1):
                    if destinatario_pai == destinatario_filho:

                        print(f"Ev PAI: Ev:{mov_pai['evento']} - {mov_pai['data_texto']} - {mov_pai['ato']}") 
                        print(f"documento: {documento}")
                        print(f"situacão: {situacao}")
                        print(f"destinatário: {destinatario_pai}")
                        if meio_pai:
                            print(f"meio: {meio_pai['tipo']}")
                        print('')

        if evento_relacionado_filho:
            print(f"Ev FILHO: Ev:{mov['evento']} - {mov['data_texto']} - {mov['ato']}") 
            if evento_relacionado_filho.group(3):
                print("destinatário:", evento_relacionado_filho.group(3))
            if evento_relacionado_filho.group(1):
                print("documento:", evento_relacionado_filho.group(1))
            if evento_relacionado_filho.group(2):
                print("situação:", evento_relacionado_filho.group(2))
            if evento_relacionado_filho.group(4):
                print("data leitura:", evento_relacionado_filho.group(4))


            else:
                continue
                
        print('---------------------------------')
        print('')
# Out:
# Processo:  {'partes': [{'nome': 'DANILO AUGUSTO E ARAUJO FRANCA', 'nome_normalizado': 'danilo augusto e araujo franca', 'cpf/cnpj': '891.424.205-63', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'FRANCA_DANILO@HOTMAIL.COM', 'tel': '71996123344', 'logradouro': 'ENDEREÇO RUA NELSON RODRIGUES DO NASCIMENTO', 'numero': '45', 'complemento': 'PANORAMA', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48605041'}, {'nome': 'PAYOUT PAGAMENTOS INTELIGENTES LTDA(Rev. Arg)', 'nome_normalizado': 'payout pagamentos inteligentes ltda(rev. arg)', 'cpf/cnpj': '57.225.538/0001-11', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': False, 'domicilio_cnj': True, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO ALAMEDA RIO NEGRO', 'numero': '503', 'complemento': 'ALPHAVILLE CENTRO INDUSTRIAL E EMPRESARIAL ALPHAVILLE', 'bairro': None, 'cidade': 'BARUERI', 'uf': 'SP', 'cep': '06454000'}, {'nome': 'TV VINHOS LTDA(Rev. Arg)', 'nome_normalizado': 'tv vinhos ltda(rev. arg)', 'cpf/cnpj': '63.965.406/0001-29', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO AVENID
 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48603420'}, {'nome': 'AMIL ASSISTENCIA MEDICA INTERNACIONAL S A', 'nome_normalizado': 'amil assistencia medica internacional s a', 'cpf/cnpj': '29.309.127/0001-79', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': True, 'domicilio_cnj': True, 'tem_advogado': True, 'email': 'LEGALIZACAOBR@UHGBRASIL.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO RUA ARQUITETO OLAVO REDIG DE CAMPOS 105', 'numero': '105', 'complemento': '06 AO 21 ANDAR TORRE B EMPREEND EZ TOWERS', 'bairro': 'VILA SAO FRANCISCO ZONA SUL', 'cidade': 'SAO PAULO', 'uf': 'SP', 'cep': '04711904'}], 'movimentacoes': [{'evento': '258', 'ato': 'Disponibilização no Diário da Justiça Eletrônico - DJEN Disponibilização no Diário da Justiça Eletrônico em (14/05/26) para RAQUEL LEMOS DE OLIVEIRA *Referente ao evento Intimação expedido(a)', 'ato_normalizado': 'disponibilização no diário da justiça eletrônico - djen disponibilização no diário da justiça eletrônico em (14/05/26) para raquel lemos de oliveira *referente ao evento intimação expedido(a)', 'data_texto': '12/05/26', 'data_obj': '2026-05-12', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'DJEN CNJ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'raquel lemos de oliveira'}, {'evento': '257', 'ato': 'Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Prazo: 5 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de raquel lemos de oliveira) prazo: 5 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '11/05/26', 'data_obj': '2026-05-11', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MAURO EMILIO VIANA DA SILVA MOREIRA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'raquel lemos de oliveira'}, {'evento': '256', 'ato': 'Intimação expedido(a)', 'ato_normalizado': 'intimação expedido(a)', 'data_texto': '11/05/26', 'data_obj': '2026-05-11', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MAURO EMILIO VIANA DA SILVA MOREIRA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'expedida', 'destinatario': None}, {'evento': '247', 'ato': 'Intimação expedido(a) (P/ Advgs. de AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) Prazo: 5 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de amil assistencia medica internacional s a) prazo: 5 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '24/04/26', 'data_obj': '2026-04-24', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'amil assistencia medica internacional s a'}, {'evento': '246', 'ato': 'Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Prazo: 5 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de raquel lemos de oliveira) prazo: 5 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '24/04/26 ...
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Concedida a Medida Liminar
# data referência 09/03/26
#
# Ev FILHO: Ev:223 - 20/03/26 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 19/03/26 *Referente ao evento Concedida a Medida Liminar(09/03/26)
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 19/03/26
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Extinta a execução ou o cumprimento da sentença
# data referência 10/10/25
#
# Ev FILHO: Ev:182 - 21/10/25 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 20/10/25 *Referente ao evento Extinta a execução ou o cumprimento da sentença(10/10/25)
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 20/10/25
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# Ev FILHO: Ev:41 - 17/05/25 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 16/05/25 *Referente ao evento Julgada procedente a ação(06/05/25)
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 16/05/25
# ---------------------------------
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# Ev PAI: Ev:37 - 06/05/25 - Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: advogado
#
# Ev FILHO: Ev:40 - 17/05/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 16/05/25 *Referente ao evento Julgada procedente a ação(06/05/25)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/05/25
# ---------------------------------
#
# Ev PAI: Ev:37 - 06/05/25 - Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:37 - 06/05/25 - Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:37 - 06/05/25 - Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: advogado
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# Ev FILHO: Ev:27 - 07/03/25 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 06/03/25 *Referente ao evento Intimação à disposição(17/02/25)
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/25
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# Ev PAI: Ev:22 - 17/02/25 - Intimação expedido(a) (P/ Advgs. de RAQUEL LEMOS DE OLIVEIRA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: advogado
#
# Ev FILHO: Ev:26 - 07/03/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/03/25 *Referente ao evento Intimação à disposição(17/02/25)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/03/25
# ---------------------------------
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# Ev FILHO: Ev:25 - 18/02/25 - Intimação lido(a) (Para AMIL ASSISTENCIA MEDICA INTERNACIONAL S A) em 17/02/25 *Referente ao evento Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA(06/02/25)
# destinatário: AMIL ASSISTENCIA MEDICA INTERNACIONAL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 17/02/25
# ---------------------------------
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# Ev FILHO: Ev:24 - 18/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 17/02/25 *Referente ao evento Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA(06/02/25)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 17/02/25
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# ---------------------------------
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/02/25
#
# Ev PAI: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# meio: parte
#
# Ev FILHO: Ev:6 - 06/02/25 - Intimação lido(a) (Para RAQUEL LEMOS DE OLIVEIRA) em 06/02/25 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (06/02/25)
# destinatário: RAQUEL LEMOS DE OLIVEIRA
# documento: Intimação
# situação: lido(a)
# data leitura: 06/02/25
# ---------------------------------
#
# Processo:  {'partes': [{'nome': 'EDILEIDE DA SILVA LIMA', 'nome_normalizado': 'edileide da silva lima', 'cpf/cnpj': '109.759.105-07', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'LEANAEVANGELISTA.ADV@GMAIL.COM', 'tel': '75988070152', 'logradouro': 'ENDEREÇO AREA RURAL', 'numero': 'SN', 'complemento': 'POVOADO SAO JOSE', 'bairro': 'AREA RURAL DE PAULO AFONSO', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48619899'}, {'nome': 'JOSE GENILSON PIONORIO PAIVA(Revel)', 'nome_normalizado': 'jose genilson pionorio paiva(revel)', 'cpf/cnpj': '07.643.429/0002-27', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': False, 'domicilio_cnj': True, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO PRAÇA DA MATRIZ', 'numero': '84', 'complemento': '(75 99274-5540 75-992167383', 'bairro': 'CENTRO', 'cidade': 'JEREMOABO', 'uf': 'BA', 'cep': '48540000'}], 'movimentacoes': [{'evento': '166', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Sem prazo Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edileide da silva lima) sem prazo aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '19/09/25', 'data_obj': '2025-09-19', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'ANTONIO JUVENCIO DA SILVA NETO', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'edileide da silva lima'}, {'evento': '146', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 5 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edileide da silva lima) prazo: 5 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '25/07/25', 'data_obj': '2025-07-25', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'edileide da silva lima'}, {'evento': '118', 'ato': 'Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 31/10/24 *Referente ao evento Intimação à disposição(30/10/24)', 'ato_normalizado': 'intimação lido(a) (para edileide da silva lima) em 31/10/24 *referente ao evento intimação à disposição(30/10/24)', 'data_texto': '31/10/24', 'data_obj': '2024-10-31', 'data_leitura_str': '2024-10-31', 'data_referencia_str': '30/10/24', 'autor': 'LEANA BEZERRA GOMES EVANGELISTA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinatario': 'edileide da silva lima'}, {'evento': '117', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edileide da silva lima) prazo: 10 dias;', 'data_texto': '30/10/24', 'data_obj': '2024-10-30', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'edileide da silva lima'}, {'evento': '114', 'ato': 'Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 24/10/24 *Referente ao evento  Proferido despacho de mero expediente(16/10/24)', 'ato_normalizado': 'intimação lido(a) (para edileide da silva lima) em 24/10/24 *referente ao evento  proferido despacho de mero expediente(16/10/24)', 'data_texto': '24/10/24', 'data_obj': '2024-10-24', 'data_leitura_str': '2024-10-24', 'data_referencia_str': '16/10/24', 'autor': 'LEANA BEZERRA GOMES EVANGELISTA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinat ...
# ---------------------------------
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 30/10/24
#
# Ev PAI: Ev:117 - 30/10/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# Ev FILHO: Ev:118 - 31/10/24 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 31/10/24 *Referente ao evento Intimação à disposição(30/10/24)
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 31/10/24
# ---------------------------------
#
# Ev PAI: Ev:117 - 30/10/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# ref: Proferido despacho de mero expediente
# data referência 16/10/24
#
# Ev PAI: Ev:113 - 16/10/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# Ev FILHO: Ev:114 - 24/10/24 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 24/10/24 *Referente ao evento  Proferido despacho de mero expediente(16/10/24)
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 24/10/24
# ---------------------------------
#
# Ev PAI: Ev:113 - 16/10/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 05/06/24
#
# Ev PAI: Ev:87 - 05/06/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# Ev FILHO: Ev:93 - 11/06/24 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 11/06/24 *Referente ao evento Intimação à disposição(05/06/24)
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 11/06/24
# ---------------------------------
#
# Ev PAI: Ev:87 - 05/06/24 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 17/04/23
#
# Ev FILHO: Ev:30 - 16/05/23 - Intimação lido(a) (Para LARBELO MOVEIS) em 10/05/23 *Referente ao evento Intimação à disposição(17/04/23)
# destinatário: LARBELO MOVEIS
# documento: Intimação
# situação: lido(a)
# data leitura: 10/05/23
# ---------------------------------
#
# ---------------------------------
#
# ref: Julgada procedente em parte a ação
# data referência 22/03/23
#
# Ev PAI: Ev:17 - 22/03/23 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# Ev FILHO: Ev:19 - 22/03/23 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 22/03/23 *Referente ao evento Julgada procedente em parte a ação(22/03/23)
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 22/03/23
# ---------------------------------
#
# Ev PAI: Ev:17 - 22/03/23 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:17 - 22/03/23 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:17 - 22/03/23 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:17 - 22/03/23 - Intimação expedido(a) (P/ Advgs. de EDILEIDE DA SILVA LIMA) Prazo: 10 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: advogado
#
# ---------------------------------
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 16/02/23
#
# Ev PAI: Ev:5 - 16/02/23 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 16/02/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (16/02/23)
# documento: Intimação
# situacão: lido(a)
# destinatário: EDILEIDE DA SILVA LIMA
# meio: parte
#
# Ev FILHO: Ev:5 - 16/02/23 - Intimação lido(a) (Para EDILEIDE DA SILVA LIMA) em 16/02/23 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (16/02/23)
# destinatário: EDILEIDE DA SILVA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 16/02/23
# ---------------------------------
#
# Processo:  {'partes': [{'nome': 'PAULO CESAR AGUIAR NETO', 'nome_normalizado': 'paulo cesar aguiar neto', 'cpf/cnpj': '048.697.945-86', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'CONTATO@CHIOZZO.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO RUA SAO MIGUEL', 'numero': '95', 'complemento': 'JARDIM BAHIA', 'bairro': '(CONTATO: 55 21 99591 65', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48604120'}, {'nome': 'AZUL LINHAS AEREAS BRASILEIRAS S A', 'nome_normalizado': 'azul linhas aereas brasileiras s a', 'cpf/cnpj': '09.296.295/0001-60', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': True, 'domicilio_cnj': True, 'tem_advogado': True, 'email': 'TRIBUTARIO@VOEAZUL.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA MARCOS PENTEADO DE ULHOA RODRIGUES', 'numero': '939', 'complemento': 'ANDAR 9 EDIF JATOBA COND CASTELO BRANCO', 'bairro': 'TAMBORE', 'cidade': 'BARUERI', 'uf': 'SP', 'cep': '06460040'}], 'movimentacoes': [{'evento': '40', 'ato': 'Intimação expedido(a) (P/ Advgs. de PAULO CESAR AGUIAR NETO) Prazo: 10 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de paulo cesar aguiar neto) prazo: 10 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '14/05/26', 'data_obj': '2026-05-14', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MAURO EMILIO VIANA DA SILVA MOREIRA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'paulo cesar aguiar neto'}, {'evento': '32', 'ato': 'Intimação expedido(a) (P/ Advgs. de AZUL LINHAS AEREAS BRASILEIRAS S A) Prazo: 10 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de azul linhas aereas brasileiras s a) prazo: 10 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '24/04/26', 'data_obj': '2026-04-24', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'azul linhas aereas brasileiras s a'}, {'evento': '31', 'ato': 'Intimação expedido(a) (P/ Advgs. de PAULO CESAR AGUIAR NETO) Prazo: 10 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de paulo cesar aguiar neto) prazo: 10 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '24/04/26', 'data_obj': '2026-04-24', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'paulo cesar aguiar neto'}, {'evento': '21', 'ato': 'Intimação expedido(a) (P/ Advgs. de PAULO CESAR AGUIAR NETO) Prazo: 15 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de paulo cesar aguiar neto) prazo: 15 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '16/04/26', 'data_obj': '2026-04-16', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'ANTONIO JUVENCIO DA SILVA NETO', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 
 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'DJEN CNJ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_c ...
# ref: Intimação à disposição
# data referência 27/04/26
#
# Ev FILHO: Ev:112 - 08/05/26 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 07/05/26 *Referente ao evento Intimação à disposição(27/04/26)
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 07/05/26
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Intimação expedido(a)
# data referência 09/03/26
#
# Ev FILHO: Ev:103 - 20/03/26 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 19/03/26 *Referente ao evento Intimação expedido(a)(09/03/26)
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 19/03/26
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Documento analisado
# data referência 07/11/25
#
# Ev FILHO: Ev:72 - 18/11/25 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 17/11/25 *Referente ao evento Documento analisado(07/11/25)
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 17/11/25
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# Ev FILHO: Ev:38 - 20/05/25 - Intimação lido(a) (Para BRUNO HENRIQUE GOMES BEZERRA) em 09/05/25 *Referente ao evento Informações prestadas pela autoridade coatora expedido(a)(05/05/25)
# destinatário: BRUNO HENRIQUE GOMES BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 09/05/25
# ---------------------------------
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# Ev FILHO: Ev:36 - 06/05/25 - Intimação lido(a) (Para BANCO SANTANDER BRASIL S A) em 06/05/25 *Referente ao evento Informações prestadas pela autoridade coatora expedido(a)(05/05/25)
# destinatário: BANCO SANTANDER BRASIL S A
# documento: Intimação
# situação: lido(a)
# data leitura: 06/05/25
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# Processo:  {'partes': [{'nome': 'JOSE HILTON MATOS DOS SANTOS', 'nome_normalizado': 'jose hilton matos dos santos', 'cpf/cnpj': '486.435.485-53', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'INTIMACOESBANCOS@GMAIL.COM', 'tel': '74988739031', 'logradouro': 'ENDEREÇO RUA CHICO MENDES', 'numero': '1430', 'complemento': 'BTN 2', 'bairro': 'TANCREDO NEVES II', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48609310'}, {'nome': 'BANCO MASTER S/A - EM LIQUIDACAO EXTRAJUDICIAL', 'nome_normalizado': 'banco master s/a - em liquidacao extrajudicial', 'cpf/cnpj': '33.923.798/0001-00', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': True, 'domicilio_cnj': True, 'tem_advogado': True, 'email': 'CORREIOELETRONICO@BANCOMASTER.COM.BR', 'tel': None, 'logradouro': 'ENDEREÇO PRAIA BOTAFOGO 228', 'numero': '228', 'complemento': 'BOTAFOGO', 'bairro': None, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'cep': '22250906'}], 'movimentacoes': [{'evento': '22', 'ato': 'Citação lido(a) P/ BANCO MASTER S A em 29/04/26', 'ato_normalizado': 'citação lido(a) p/ banco master s a em 29/04/26', 'data_texto': '09/05/26', 'data_obj': '2026-05-09', 'data_leitura_str': '2026-04-29', 'data_referencia_str': None, 'autor': 'ECT', 'observacao': '', 'categoria': 'citacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinatario': 'banco master s a em 29/04/26'}, {'evento': '20', 'ato': 'Audiência de Conciliação Realizada (Telepresencial) Conduzida por Juiz MARTINHO FERRAZ DA NOBREGA JUNIOR Realizada em/para 07/05/2026 16:07, PAULO AFONSO', 'ato_normalizado': 'audiência de conciliação realizada (telepresencial) conduzida por juiz martinho ferraz da nobrega junior realizada em/para 07/05/2026 16:07, paulo afonso', 'data_texto': '07/05/26', 'data_obj': '2026-05-07', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'WALKER LOPES RODRIGUES', 'observacao': '', 'categoria': 'audiencia', 'meio_comunicacao': None, 'situacao_comunicacao': 'realizada', 'destinatario': '07/05/2026 16:07, paulo afonso'}, {'evento': '18', 'ato': 'Citação expedido(a) Para BANCO MASTER S A', 'ato_normalizado': 'citação expedido(a) para banco master s a', 'data_texto': '13/04/26', 'data_obj': '2026-04-13', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MARCELO PEREIRA DA SILVAA', 'observacao': '', 'categoria': 'citacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'expedida', 'destinatario': 'banco master s a'}, {'evento': '13', 'ato': 'Disponibilização no Diário da Justiça Eletrônico - DJEN Disponibilização no Diário da Justiça Eletrônico em (10/04/26) para JOSE HILTON MATOS DOS SANTOS *Referente ao evento Intimação expedido(a)', 'ato_normalizado': 'disponibilização no diário da justiça eletrônico - djen disponibilização no diário da justiça eletrônico em (10/04/26) para jose hilton matos dos santos *referente ao evento intimação expedido(a)', 'data_texto': '08/04/26', 'data_obj': '2026-04-08', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'DJEN CNJ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'jose hilton matos dos santos'}, {'evento': '12', 'ato': 'Intimação expedido(a) (P/ Advgs. de JOSE HILTON MATOS DOS SANTOS) Sem prazo Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de jose hilton matos dos santos) sem prazo aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '08/04/26', 'data_obj': '2026-04-08', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MAURO EMILIO VIANA DA SILVA MOREIRA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'jose hilton matos dos santos'}, {'evento': '11', 'ato': 'Intimação expedido(a ...
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 07/04/26
#
# Ev PAI: Ev:6 - 07/04/26 - Intimação lido(a) (Para JOSE HILTON MATOS DOS SANTOS) em 07/04/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(07/04/26)
# documento: Intimação
# situacão: lido(a)
# destinatário: JOSE HILTON MATOS DOS SANTOS
# meio: parte
#
# Ev FILHO: Ev:6 - 07/04/26 - Intimação lido(a) (Para JOSE HILTON MATOS DOS SANTOS) em 07/04/26 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(07/04/26)
# destinatário: JOSE HILTON MATOS DOS SANTOS
# documento: Intimação
# situação: lido(a)
# data leitura: 07/04/26
# ---------------------------------
#
# ...
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 24/10/25
#
# Ev FILHO: Ev:22 - 04/11/25 - Intimação lido(a) (Para BANCO BRADESCO FINANCIAMENTOS S A) em 03/11/25 *Referente ao evento Intimação à disposição(24/10/25)
# destinatário: BANCO BRADESCO FINANCIAMENTOS S A
# documento: Intimação
# situação: lido(a)
# data leitura: 03/11/25
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 24/10/25
#
# Ev PAI: Ev:6 - 24/10/25 - Intimação lido(a) (Para MARIA JOSE BEZERRA) em 24/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(24/10/25)
# documento: Intimação
# situacão: lido(a)
# destinatário: MARIA JOSE BEZERRA
# meio: parte
#
# Ev FILHO: Ev:6 - 24/10/25 - Intimação lido(a) (Para MARIA JOSE BEZERRA) em 24/10/25 *Referente ao evento Audiência de Conciliação Designada (Telepresencial)(24/10/25)
# destinatário: MARIA JOSE BEZERRA
# documento: Intimação
# situação: lido(a)
# data leitura: 24/10/25
# ---------------------------------
#
# Processo:  {'partes': [{'nome': 'EDMILSON LOPES CABRAL', 'nome_normalizado': 'edmilson lopes cabral', 'cpf/cnpj': '176.478.195-34', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': 'ADV.BRUNAPSS@GMAIL.COM', 'tel': '75988696615', 'logradouro': 'ENDEREÇO RUA ARARI', 'numero': '122', 'complemento': 'FAZENDA CHESF', 'bairro': '(CONTATO:', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48606520'}, {'nome': 'PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA', 'nome_normalizado': 'prevebene administradora de beneficios e promocoes de vendas ltda', 'cpf/cnpj': '30.109.943/0001-18', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': False, 'domicilio_cnj': True, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO AVENIDA REPÚBLICA ARGENTINA', 'numero': '452', 'complemento': 'CONJ 704', 'bairro': '7 ANDAR', 'cidade': 'CURITIBA', 'uf': 'PR', 'cep': '80240210'}], 'movimentacoes': [{'evento': '72', 'ato': 'Intimação expedido(a) (P/ Advgs. de PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA) Sem prazo Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de prevebene administradora de beneficios e promocoes de vendas ltda) sem prazo aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '23/10/25', 'data_obj': '2025-10-23', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MARIA DO SOCORRO FIRMINO DINIZ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'prevebene administradora de beneficios e promocoes de vendas ltda'}, {'evento': '71', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edmilson lopes cabral) sem prazo aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '23/10/25', 'data_obj': '2025-10-23', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'MARIA DO SOCORRO FIRMINO DINIZ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'edmilson lopes cabral'}, {'evento': '55', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Prazo: 5 dias; Aguardando disponibilização no Diário da Justiça Eletrônico Nacional - DJEN (CNJ)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edmilson lopes cabral) prazo: 5 dias; aguardando disponibilização no diário da justiça eletrônico nacional - djen (cnj)', 'data_texto': '04/08/25', 'data_obj': '2025-08-04', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'SELMA PEREIRA DIAS', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'edmilson lopes cabral'}, {'evento': '34', 'ato': 'Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 01/04/25 *Referente ao evento Intimação à disposição(01/04/25)', 'ato_normalizado': 'intimação lido(a) (para edmilson lopes cabral) em 01/04/25 *referente ao evento intimação à disposição(01/04/25)', 'data_texto': '01/04/25', 'data_obj': '2025-04-01', 'data_leitura_str': '2025-04-01', 'data_referencia_str': '01/04/25', 'autor': 'BRUNA PEREIRA DE SOUZA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinatario': 'edmilson lopes cabral'}, {'evento': '33', 'ato': 'Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Prazo: 5 dias;', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de edmilson lopes cabral) prazo: 5 dias;', 'data_texto': '01/04/25', 'data_obj': '2025-04-01', 'data_leitura_str': None, 'data_referenc ...
# ---------------------------------
#
# ---------------------------------
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 01/04/25
#
# Ev PAI: Ev:33 - 01/04/25 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# Ev FILHO: Ev:34 - 01/04/25 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 01/04/25 *Referente ao evento Intimação à disposição(01/04/25)
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 01/04/25
# ---------------------------------
#
# Ev PAI: Ev:33 - 01/04/25 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Prazo: 5 dias;
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# ref: Proferido despacho de mero expediente
# data referência 26/02/25
#
# Ev FILHO: Ev:30 - 11/03/25 - Intimação lido(a) (Para PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA) em 10/03/25 *Referente ao evento  Proferido despacho de mero expediente(26/02/25)
# destinatário: PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 10/03/25
# ---------------------------------
#
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# Ev FILHO: Ev:22 - 20/12/24 - Intimação lido(a) (Para PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA) em 19/12/24 *Referente ao evento Intimação à disposição(09/12/24)
# destinatário: PREVEBENE ADMINISTRADORA DE BENEFICIOS E PROMOCOES DE VENDAS LTDA
# documento: Intimação
# situação: lido(a)
# data leitura: 19/12/24
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# Ev FILHO: Ev:21 - 09/12/24 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 09/12/24 *Referente ao evento Intimação à disposição(09/12/24)
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 09/12/24
# ---------------------------------
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:19 - 09/12/24 - Intimação expedido(a) (P/ Advgs. de EDMILSON LOPES CABRAL) Sem prazo
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: advogado
#
# ---------------------------------
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 03/11/24
#
# Ev PAI: Ev:5 - 03/11/24 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 03/11/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (03/11/24)
# documento: Intimação
# situacão: lido(a)
# destinatário: EDMILSON LOPES CABRAL
# meio: parte
#
# Ev FILHO: Ev:5 - 03/11/24 - Intimação lido(a) (Para EDMILSON LOPES CABRAL) em 03/11/24 *Referente ao evento Audiência  de Conciliação Designada (Telepresencial) (03/11/24)
# destinatário: EDMILSON LOPES CABRAL
# documento: Intimação
# situação: lido(a)
# data leitura: 03/11/24
# ---------------------------------
#
# Processo:  {'partes': [{'nome': 'SEVERINO ALVES DE OLIVEIRA LIMA', 'nome_normalizado': 'severino alves de oliveira lima', 'cpf/cnpj': '010.080.565-53', 'tipo': 'EXEQUENTE', 'papel': 'PROMOVENTE', 'recebe_intimacao_email': False, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO RUA\xa0\r\n                            RORAIMA', 'numero': '75', 'complemento': '(75 3281-3954', 'bairro': 'PANORAMA', 'cidade': 'PAULO AFONSO', 'uf': 'BA', 'cep': '48600000'}, {'nome': 'OI MOVEL S A EM RECUPERACAO JUDICIAL', 'nome_normalizado': 'oi movel s a em recuperacao judicial', 'cpf/cnpj': '05.423.963/0001-11', 'tipo': 'EXECUTADO', 'papel': 'PROMOVIDO', 'recebe_intimacao_email': True, 'domicilio_cnj': False, 'tem_advogado': True, 'email': None, 'tel': None, 'logradouro': 'ENDEREÇO SETOR\xa0\r\n                            COMERCIAL NORTE QUADRA 03', 'numero': 'S N', 'complemento': 'SETOR COMERCIAL NRTE QUADRA 03', 'bairro': 'SETOR COMERCIAL NORTE', 'cidade': 'BRASILIA', 'uf': 'DF', 'cep': '70713900'}], 'movimentacoes': [{'evento': '20', 'ato': 'Intimação lido(a) (Para OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)', 'ato_normalizado': 'intimação lido(a) (para oi movel s a sociedade empresaria em recuperacao judicial) em 21/01/19 *referente ao evento intimação à disposição(17/12/18)', 'data_texto': '21/01/19', 'data_obj': '2019-01-21', 'data_leitura_str': '2019-01-21', 'data_referencia_str': '17/12/18', 'autor': 'SISTEMA CNJ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinatario': 'oi movel s a sociedade empresaria em recuperacao judicial'}, {'evento': '19', 'ato': 'Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)', 'ato_normalizado': 'intimação lido(a) (para severino alves de oliveira lima) em 21/01/19 *referente ao evento intimação à disposição(17/12/18)', 'data_texto': '21/01/19', 'data_obj': '2019-01-21', 'data_leitura_str': '2019-01-21', 'data_referencia_str': '17/12/18', 'autor': 'SISTEMA CNJ', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': None, 'situacao_comunicacao': 'lida', 'destinatario': 'severino alves de oliveira lima'}, {'evento': '17', 'ato': 'Intimação expedido(a) (P/ Advgs. de OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de oi movel s a sociedade empresaria em recuperacao judicial)', 'data_texto': '17/12/18', 'data_obj': '2018-12-17', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'oi movel s a sociedade empresaria em recuperacao judicial'}, {'evento': '16', 'ato': 'Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)', 'ato_normalizado': 'intimação expedido(a) (p/ advgs. de severino alves de oliveira lima)', 'data_texto': '17/12/18', 'data_obj': '2018-12-17', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'IVAN GUEDES DA SILVA', 'observacao': '', 'categoria': 'intimacao', 'meio_comunicacao': 'domicilio_cnj', 'situacao_comunicacao': 'expedida', 'destinatario': 'severino alves de oliveira lima'}, {'evento': '12', 'ato': 'Audiência Conciliação Realizada Sem conciliação', 'ato_normalizado': 'audiência conciliação realizada sem conciliação', 'data_texto': '30/11/18', 'data_obj': '2018-11-30', 'data_leitura_str': None, 'data_referencia_str': None, 'autor': 'CATARINE SA SANTOS E LIMA', 'observacao': '', 'categoria': 'audiencia', 'meio_comunicacao': None, 'situacao_comunicacao': 'realizada', 'destinatario': None}, {'evento': '8', 'ato': 'Citação lido(a) P/ OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL em 08/11/18', 'ato_normalizado': 'citação lido(a) p/ oi movel s a sociedade empr ...
# ref: Intimação à disposição
# data referência 17/12/18
#
# Ev FILHO: Ev:20 - 21/01/19 - Intimação lido(a) (Para OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)
# destinatário: OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL
# documento: Intimação
# situação: lido(a)
# data leitura: 21/01/19
# ---------------------------------
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# Ev FILHO: Ev:19 - 21/01/19 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 21/01/19
# ---------------------------------
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# ---------------------------------
#
# Ev PAI: Ev:16 - 17/12/18 - Intimação expedido(a) (P/ Advgs. de SEVERINO ALVES DE OLIVEIRA LIMA)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: advogado
#
# ---------------------------------
#
# ref: Audiência  de Conciliação Designada
# data referência 31/10/18
#
# Ev PAI: Ev:4 - 31/10/18 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 31/10/18 *Referente ao evento Audiência  de Conciliação Designada(31/10/18)
# documento: Intimação
# situacão: lido(a)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# meio: parte
#
# Ev FILHO: Ev:4 - 31/10/18 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 31/10/18 *Referente ao evento Audiência  de Conciliação Designada(31/10/18)
# destinatário: SEVERINO ALVES DE OLIVEIRA LIMA
# documento: Intimação
# situação: lido(a)
# data leitura: 31/10/18
# ---------------------------------

# %%
eventos_encadeados = []

for processo in processos:

    for mov in processo["movimentacoes"]:

        # if "lido(a)" not in mov["ato"]:
        #     continue

        evento_relacionado = buscar_relacao_evento(mov["ato"])

        if not evento_relacionado:
            continue

        destinatario = evento_relacionado.group(2)
        data_leitura = evento_relacionado.group(3)
        ato_referencia = evento_relacionado.group(4)
        # data_ato_ref = evento_relacionado.group(5)

        for mov_ref in processo["movimentacoes"]:

            # if (
            #     mov_ref["data_texto"] == data_ato_ref
            #     and ato_referencia.lower() in mov_ref["ato"].lower()
            # ):

            eventos_encadeados.append({
                    "evento_filho": mov["evento"],
                    "ato_filho": mov["ato"],

                    "evento_pai": mov_ref["evento"],
                    "ato_pai": mov_ref["ato"],

                    "destinatario": destinatario,
                    "data_leitura": data_leitura,
                    # "data_referencia": data_ato_ref,
            })
                
            break
# print(eventos_encadeados['evento_pai'])
# print(eventos_encadeados['ato_filho'])

# %%
# for rel in eventos_encadeados:
#     print(
#         f'Evento {rel["evento_filho"]} '
#         f'-> Evento {rel["evento_pai"]}'
#     )

# %%
decisao_sentenca = (
    'Inexistência de bens penhoráveis','Procedência em Parte', 'Procedência', 'Improcedência',
    'Extinção da execução ou do cumprimento da sentença', 'Ausência do autor à audiência', 'Homologada a Transação',
    'Inadmissibilidade do procedimento sumaríssimo', 'Liminar', 'Acolhimento e Embargos de Declaração',
)
for e in eventos_encadeados:
    if e in decisao_sentenca:
        print(f"[FILHO] {e['evento_filho']} | {e['ato_filho']}")
        print(f"[PAI  ] {e['evento_pai']} | {e['ato_pai']}")
        print(f"Destinatário: {e['destinatario']}  | Leitura: {e['data_leitura']}  | Ref: {e['data_referencia']}")
        print("-" * 80)

# %%
padroes_sentenca = (
    'procedente',
    'procedência',
    'improcedente',
    'liminar',
    'extinta a execução',
    'extinto o processo',
    'homologada a transação',
)


for e in eventos_encadeados:
    evento = e['evento_filho'].lower()

    if any(p.lower() in evento for p in padroes_sentenca):
        print(f"[FILHO] {e['evento_filho']} | {e['ato_filho']}")
        print(f"[PAI  ] {e['evento_pai']} | {e['ato_pai']}")
        print(f"Destinatário: {e['destinatario']}")
        print("-" * 80)

# %%
eventos_encadeados = []

for processo in processos:

    for mov in processo["movimentacoes"]:

        if "lido(a)" not in mov["ato"]:
            continue

        evento_relacionado = buscar_relacao_evento(mov["ato"])

        if not evento_relacionado:
            continue

        destinatario = evento_relacionado.group(2)
        data_leitura = evento_relacionado.group(3)
        ato_referencia = evento_relacionado.group(4)
        data_ato_ref = evento_relacionado.group(5)

        for mov_ref in processo["movimentacoes"]:

            if (
                mov_ref["data_texto"] == data_ato_ref
                and ato_referencia.lower() in mov_ref["ato"].lower()
            ):

                eventos_encadeados.append({
                    "evento_filho": mov["evento"],
                    "ato_filho": mov["ato"],

                    "evento_pai": mov_ref["evento"],
                    "ato_pai": mov_ref["ato"],

                    "destinatario": destinatario,
                    "data_leitura": data_leitura,
                    "data_referencia": data_ato_ref,
                })
                
                break
# print(eventos_encadeados['evento_pai'])
# print(eventos_encadeados['ato_filho'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 18
#      14
#      15         destinatario = evento_relacionado.group(2)
#      16         data_leitura = evento_relacionado.group(3)
#      17         ato_referencia = evento_relacionado.group(4)
# ---> 18         data_ato_ref = evento_relacionado.group(5)
#      19
#      20         for mov_ref in processo["movimentacoes"]:
#      21
#
# IndexError: no such group

# %%
for processo in processos:

    for mov_lido in processo['movimentacoes']:

        # 1. Precisa ser uma leitura
        rel_lido = buscar_relacao_evento(mov_lido['ato'])

        if not rel_lido:
            continue

        if rel_lido.group(2) != 'lido(a)':
            continue

        # 2. Precisa ter referência ao evento principal
        ref = referencia(mov_lido['ato'])

        if not ref:
            continue

        nome_evento = ref.group(1)
        data_referencia = ref.group(2)

        destinatario = rel_lido.group(3)

        # 3. Encontrar o evento principal
        evento_principal = next(
            (
                m for m in processo['movimentacoes']
                if m['data_texto'] == data_referencia
            ),
            None
        )

        if not evento_principal:
            continue

        # 4. Encontrar a expedição correspondente
        evento_expedido = None

        for mov_exp in processo['movimentacoes']:

            rel_exp = buscar_relacao_evento(mov_exp['ato'])

            if not rel_exp:
                continue

            if rel_exp.group(2) != 'expedido(a)':
                continue

            if rel_exp.group(3) == destinatario:
                evento_expedido = mov_exp
                break

        # 5. Montar o encadeamento
        eventos_encadeados.append({
            'evento_principal': evento_principal,
            'evento_expedido': evento_expedido,
            'evento_lido': mov_lido,

            'nome_evento': nome_evento,
            'destinatario': destinatario,
            'data_referencia': data_referencia,
            'data_leitura': rel_lido.group(4),
        })
# Out:
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Ato ordinatório praticado
# data referência 28/04/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Intimação à disposição
# data referência 21/01/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 15/01/26
#
# ref: Concedida a Medida Liminar
# data referência 09/03/26
#
# ref: Extinta a execução ou o cumprimento da sentença
# data referência 10/10/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Julgada procedente a ação
# data referência 06/05/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Intimação à disposição
# data referência 17/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Não Concedida a Medida Liminar a RAQUEL LEMOS DE OLIVEIRA
# data referência 06/02/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/02/25
#
# ref: Intimação à disposição
# data referência 30/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 16/10/24
#
# ref: Intimação à disposição
# data referência 05/06/24
#
# ref: Intimação à disposição
# data referência 17/04/23
#
# ref: Julgada procedente em parte a ação
# data referência 22/03/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 16/02/23
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 12/03/26
#
# ref: Intimação à disposição
# data referência 27/04/26
#
# ref: Intimação expedido(a)
# data referência 09/03/26
#
# ref: Documento analisado
# data referência 07/11/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Informações prestadas pela autoridade coatora expedido(a)
# data referência 05/05/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 07/04/26
#
# ref: Julgada procedente a ação
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 02/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 24/04/26
#
# ref: Proferido despacho de mero expediente
# data referência 01/04/26
#
# ref: Intimação à disposição
# data referência 28/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Ato ordinatório praticado
# data referência 15/04/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 12/04/25
#
# ref: Ato ordinatório praticado
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 20/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 25/05/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 02/06/26
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 03/06/26
#
# ref: Intimação expedido(a)
# data referência 15/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Intimação para Videoconferência à disposição
# data referência 07/07/25
#
# ref: Intimação à disposição
# data referência 07/07/25
#
# ref: Extinto o processo por Perempção, litispendência ou coisa julgada
# data referência 13/05/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/05/25
#
# ref: Proferido despacho de mero expediente
# data referência 04/09/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Julgada procedente em parte a ação
# data referência 11/07/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 06/06/25
#
# ref: Intimação à disposição
# data referência 12/05/25
#
# ref: Documento analisado
# data referência 03/12/24
#
# ref: Intimação à disposição
# data referência 25/11/24
#
# ref: Intimação à disposição
# data referência 01/10/24
#
# ref: Proferido despacho de mero expediente
# data referência 10/07/24
#
# ref: Documento analisado
# data referência 24/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Julgada procedente em parte a ação
# data referência 26/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 21/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 21/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/11/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 03/10/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Intimação para Videoconferência à disposição
# data referência 24/08/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/23
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 13/06/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 14/07/25
#
# ref: Intimação à disposição
# data referência 12/09/25
#
# ref: Intimação à disposição
# data referência 01/09/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 18/07/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Intimação à disposição
# data referência 14/01/25
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 28/08/24
#
# ref: Intimação à disposição
# data referência 10/06/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Julgada procedente em parte a ação
# data referência 25/04/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Intimação para Videoconferência à disposição
# data referência 06/03/24
#
# ref: Proferido despacho de mero expediente
# data referência 06/03/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 01/11/23
#
# ref: Proferido despacho de mero expediente
# data referência 06/02/26
#
# ref: Intimação à disposição
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 14/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 23/10/25
#
# ref: Intimação à disposição
# data referência 24/10/25
#
# ref: Audiência de Conciliação Designada (Telepresencial)
# data referência 24/10/25
#
# ref: Intimação à disposição
# data referência 01/04/25
#
# ref: Proferido despacho de mero expediente
# data referência 26/02/25
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Intimação à disposição
# data referência 09/12/24
#
# ref: Audiência  de Conciliação Designada (Telepresencial)
# data referência 03/11/24
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Intimação à disposição
# data referência 17/12/18
#
# ref: Audiência  de Conciliação Designada
# data referência 31/10/18

# %%
for e in eventos_encadeados:

    print(
        f"PRINCIPAL: {e['evento_principal']['evento']} - "
        f"{e['evento_principal']['ato']}"
    )

    if e['evento_expedido']:
        print(
            f"EXPEDIDO : {e['evento_expedido']['evento']} - "
            f"{e['evento_expedido']['ato']}"
        )

    print(
        f"LIDO     : {e['evento_lido']['evento']} - "
        f"{e['evento_lido']['ato']}"
    )

    print('-' * 80)
# Out:
# PRINCIPAL: 60 - Intimação expedido(a) Para TV VINHOS LTDA *Referente ao evento  Ato ordinatório praticado(28/04/26)
# LIDO     : 62 - Intimação lido(a) (Para TV VINHOS LTDA) em 11/05/26 *Referente ao evento  Ato ordinatório praticado(28/04/26)
# --------------------------------------------------------------------------------
# PRINCIPAL: 60 - Intimação expedido(a) Para TV VINHOS LTDA *Referente ao evento  Ato ordinatório praticado(28/04/26)
# LIDO     : 61 - Intimação lido(a) (Para PAYOUT PAGAMENTOS INTELIGENTES LTDA) em
- Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 21/01/19 *Referente ao evento Intimação à disposição(17/12/18)
# --------------------------------------------------------------------------------
# PRINCIPAL: 6 - Citação expedido(a) Para OI MOVEL S A SOCIEDADE EMPRESARIA EM RECUPERACAO JUDICIAL
# LIDO     : 4 - Intimação lido(a) (Para SEVERINO ALVES DE OLIVEIRA LIMA) em 31/10/18 *Referente ao evento Audiência  de Conciliação Designada(31/10/18)
# --------------------------------------------------------------------------------

# %%
rel_lido = buscar_relacao_evento(mov['ato'])

if not rel_lido:
    continue

if rel_lido.group(2) != 'lido(a)':
    continue

# %%
ato_origem = None

for mov_ref in processo['movimentacoes']:

    if mov_ref['data_texto'] != data_origem:
        continue

    if evento_origem_nome.lower() not in mov_ref['ato'].lower():
        continue

    ato_origem = mov_ref
    break

# %%
processos = {}
atos_relacionados = {}
df_relacoes = pd.DataFrame()
for process_json in pasta.glob('*.json'):
    with open(process_json, 'r', encoding='utf-8') as f:
        dados = json.load(f)
        # padrao_revelia = r'\(rev\.\s*arg\.?\)'
        # partes = dados['partes']
        # nome = dados['partes']['nome']
        # nome = re.sub(padrao_revelia,'',nome,flags=re.I).strip()
        # nome_normalizado = dados['partes']['nome_normalizado']
        # nome_normalizado = re.sub(padrao_revelia,'',nome_normalizado, flags=re.I).strip()
        # revelia = bool(re.search(padrao_revelia, nome, re.I))
        
        df_partes = pd.DataFrame(partes)
        df_partes['nome_normalizado_2'] = df_partes['nome'].apply(normalizar_nome)

        df_partes['canais_disponiveis'] = (df_partes.apply(canais_disponiveis, axis=1))
        df_partes['canais_disponiveis_lista'] = (df_partes.apply(lista_canais_disponiveis, axis=1))
        df_partes['habilitada_receber'] = (df_partes['tem_advogado'].fillna(False) | df_partes['domicilio_cnj'].fillna(False)
                                           | df_partes['recebe_intimacao_email'].fillna(False))
        processo_ok = df_partes['habilitada_receber'].all()
        autores_ok = (df_partes.loc[df_partes['papel'] == 'PROMOVENTE','habilitada_receber'].all())
        autores_pendentes = df_partes[(df_partes['papel'] == 'PROMOVENTE')& (~df_partes['habilitada_receber'])]
        acusados_ok = (df_partes.loc[df_partes['papel'] == 'PROMOVIDO','habilitada_receber'].all())
        acusados_pendentes = df_partes[(df_partes['papel'] == 'PROMOVIDO')& (~df_partes['habilitada_receber'])]
        
        df_partes['all_autors'] = df_partes['papel'] == 'PROMOVENTE' 
        df_partes['all_accused'] = df_partes['papel'] == 'PROMOVIDO'
        # status_processo = True if processo_ok else False
        
        
        
        # pprint(partes_resumo)
        p = process_json.stem
        processos[p] = pd.DataFrame(dados['movimentacoes'])
        df = processos[p]
            
       
        df_expedidas = expedidas(processos[p])
        df_expedidas = expedidas(df)
        print("ANTES")
        print(df_partes.columns.tolist())

        canais_historicos = (df_expedidas.groupby('destinatario')['meio_real'].unique().reset_index())
        canais_historicos['canais_historicos'] = (canais_historicos['meio_real'].apply(
        lambda x: ', '.join(sorted(set(i for i in x if pd.notna(i))))))

        # df_partes['canais_historicos'] = (canais_historicos['meio_real'].apply(lambda x: ', '.join(
        #             sorted(set(i for i in x if pd.notna(i))))))
        
        print(canais_historicos.columns.tolist())

        df_partes = df_partes.merge(canais_historicos[['destinatario', 'canais_historicos']],
                                    left_on='nome_normalizado',right_on='destinatario',how='left')
        print("DEPOIS")
        print(df_partes.columns.tolist())
        # print(df_partes)
        # canais_historicos['canais_historicos'] = (canais_historicos['meio_real'].apply(lambda x: ', '.join(
        #             sorted(set(i for i in x if pd.notna(i))))))
        # print(canais_historicos.head())
        

        df_expedidas['tipo'] = df_expedidas['ato'].apply(tipo_comunicacao)
        df_lidas = lidas(processos[p])
        df_lidas['tipo'] = df_lidas['ato'].apply(tipo_comunicacao)
        
        chave(df_expedidas, df_lidas)
        _relacoes = relacoes(df_expedidas, df_lidas)
        # print(_relacoes.columns.tolist())
        df_relacoes = pd.DataFrame({
            
            'evento_expedido': _relacoes['evento_expedido'],
            'data_expedicao': _relacoes['data_texto_expedido'],
            'ato_expedido': _relacoes['ato_expedido'],
            'destinatario': _relacoes['destinatario'],

            'meio': _relacoes['meio_real'],
            'canal': _relacoes['meio_comunicacao_expedido'],

            'ato_lido': _relacoes['ato_lido'],
            'data_leitura': _relacoes['data_leitura_str_lido'],
            'evento_lido': _relacoes['evento_lido'],

            'prazo': _relacoes['ato_expedido'].str.extract(
                r'(\d+\s*dias?)',
                expand=False
            )
        })
        

        df_relacoes = origem(df_relacoes)
        df_relacoes['destinatario_norm'] = df_relacoes['destinatario'].apply(normalizar_nome)
        df_relacoes['automatiza'] = status_processo(autores_ok, acusados_ok)
        # df_relacoes = df_relacoes.merge(canais_historicos[['destinatario', 'canais_historicos']],
        #                                 on='destinatario',how='left')
        df_relacoes = df_relacoes.merge(
            df_partes[
                [
                    'nome_normalizado',
                    'revelia',
                    # 'domicilio_cnj',
                    # 'recebe_intimacao_email',
                    'email',
                    'canais_historicos',
                    'tel',
                ]
            ],
            left_on='destinatario_norm',
            right_on='nome_normalizado_2',
            how='left'
        )#.drop(columns=['nome_normalizado'], errors='ignore')
        # df_relacoes['canais_disponiveis'] = (df_relacoes.apply(canais_disponiveis, axis=1))
        # df_relacoes['possui_email'] = (df_relacoes['email'].notna())
        canais_confirmados = (df_relacoes.groupby('destinatario')['meio'].unique().reset_index())
        print(df_relacoes.columns.tolist())
        print(df_partes.columns.tolist())
        print(canais_historicos.columns.tolist())
        canais_confirmados['canal_confirmado'] = (canais_confirmados['meio'].apply(lambda x: ', '.join(
            sorted(set(i for i in x if pd.notna(i))))))
        df_partes = df_partes.merge(canais_confirmados[['destinatario', 'canal_confirmado']],
                                    left_on='nome_normalizado',right_on='destinatario',how='left')
        # df_partes = df_partes.merge(canais_confirmados[['destinatario', 'canais_confirmado']],
        #                             left_on='nome_normalizado',right_on='destinatario',how='left')

        # df_relacoes['status_comunicacao'] = df_relacoes.apply(status_comunicacao, axis=1)
        # df_relacoes['automatiza'] = status_processo(autores_ok, acusados_ok)
        # df_relacoes['autores_ok'] = autores_ok
        # df_relacoes['acusados_ok'] = acusados_ok
        # print(df_relacoes[df_relacoes['tem_advogado'].isna()][['destinatario']].drop_duplicates())
        # print(
        #     df_partes[
        #         df_partes['nome_normalizado']
        #         .str.contains('tv vinhos', case=False, na=False)
        #     ]
        # )

        atos_relacionados[p] = df_relacoes
        display(atos_relacionados[p])
